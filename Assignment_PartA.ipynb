# %% [markdown]
# ## FIT3182 - Assignment 2
# ---
# ### Part A
#
# **Information:**
# - Filename: Assignment_PartA.ipynb
# - Student Name: Nicholas Mandylas
# - Student Number: 27840328
# - Student Email: nman48@student.monash.edu

# %% [markdown]
# ---
#
# ### Task 1
#
# **Q1:**
#
# Based on the two data sets provided i.e. hotspot_historic.csv and climate_historic.csv, design a suitable data model to support the efficient quering of the two data sets in MongoDB. Justify your data model design.
#   - An example of the data model.
#   - The justification for choosing that data model.
#
# **A1:**
#
# Justification:
#
# The first step in the process is to look at the indvidual datasets, and identify any relationships that occur between each dataset. Looking at the dataset 'climate_historic', we can observe that only one record is produced per day. Whilst on the otherhand, we can observe that the dataset 'hotspot_historic' can have zero to many records on a single day. As a result, using the date as the connecting data point between to the two collections, we can model a one-to-many relationship, where a climate record, can have many hotspot records.
#
# Taking into consideration above, I've choosen to create an embedded database model. Embedding the hotspot data into a document, will reduce the number of read operations required to obtain the data. This allows the model to be more efficient, as the general principle is to request all information with the least number of read operations as possible. Thus, this eliminates the needs for joins, which can be quite a taxing operation to perform. Another important benefit, is that operations peformed on a embedded model is always atomic, whilst in a reference model, atomic operations can never be assumed.
#
# A potential problem with this approach is that this can lead to large documents, especially when in this case, a 'climate' may have a large subset of 'hotspots'. This won't be an issue
# MongoDB has a 4MB size limit on a single document, which more than enough to account for 2000+ hotspot records in the dataset, which will be split up into each individual climate. The 4MB limit is the equivalent of holding 30,000+ comments on a webpage, which in this case, there isn't a realistic possibility of 30,000+ widespread fires occurring accross Victoria on a single given day.
#
# Model:
#
# ```
# {
#   '_id': ObjectId('1a2b3c4d5f6g7h8i9j0k'),
#   'date': '2/11/2018',
#   'station': 948700,
#   'air_temperature_celcius': 15,
#   'relative_humidity': 50.7,
#   'windspeed_knots': 9.2,
#   'max_wind_speed': 13,
#   'precipitation': 0.02,
#   'precipitation_type': 'G',
#   'ghi': 128,
#   'hotspots': [
#     {
#       'time': '04:16:51',
#       'latitude': -37.966,
#       'longitude': 145.051,
#       'confidence': 78,
#       'surface_temperature_celcius': 68,
#     },
#     {
#       'time': '05:13:31',
#       'latitude': -34.966,
#       'longitude': 144.051,
#       'confidence': 91,
#       'surface_temperature_celcius': 72,
#     },
#   ]
# }
# ```

# %% [markdown]
# ---
#
# ### Task 2
#
# **Q1:**
#
# Write a python program that will read the data from hotspot_historic.sv and climate_historic.csv and load them to the new database (e.g. fit3182_assignment_db). The collections will be based on the document model shown above.

# %%
from datetime import datetime
from pprint import pprint
import pymongo
import pandas

# Connect to MongoClient & get/create assignment database
client = pymongo.MongoClient()
db = client.fit3182_assignment_db
collection = db.climate

# Drop existing collection, to reload data from CSV
collection.drop()

# Read data from CSV using pandas
hotspot_data = pandas.read_csv('hotspot_historic.csv')
climate_data = pandas.read_csv('climate_historic.csv')

collection_data = []

for index, row in climate_data.iterrows():
    document = {}

    # Format data appropriately for document object.
    document['date'] = datetime.strptime(row['date'], '%d/%m/%y')
    document['station'] = int(row['station'])
    document["air_temperature_celcius"] = float(
        row["air_temperature_celcius"])
    document['relative_humidity'] = float(row['relative_humidity'])
    document['windspeed_knots'] = float(row['windspeed_knots'])
    document['max_wind_speed'] = float(row['max_wind_speed'])

    # Unncessary space at beginning of value is removed.
    # Also split precipation type and amount, to make it easier for sorting/searching later.
    precipitation = str(row['precipitation ']).replace(" ", "")
    document['precipitation_type'] = precipitation[-1]

    document['precipitation'] = float(precipitation[0:-1])
    document['ghi'] = float(row['GHI_w/m2'])

    # Get all hotspot records that match climate date & append to document.
    hotspot_date = document['date'].strftime("%-d/%m/%Y")
    hotspots = hotspot_data[hotspot_data['date'] == hotspot_date]

    # If there is a match, we clean up data & append records to document.
    if len(hotspots) > 0:
        document['hotspots'] = []
        for index, row in hotspots.iterrows():
            hotspot = {}
            hotspot['time'] = datetime.strptime(
                row['datetime'], '%Y-%m-%dT%H:%M:%S')
            hotspot['latitude'] = float(row['latitude'])
            hotspot['longitude'] = float(row['longitude'])
            hotspot['confidence'] = float(row['confidence'])
            hotspot['surface_temperature_celcius'] = float(
                row['surface_temperature_celcius'])
            document['hotspots'].append(hotspot)

    collection_data.append(document)

# Insert collection into database
collection.insert_many(collection_data)

# %% [markdown]
# ---
#
# ### Task 2
#
# **Q2:**
#
# Write queries to answer the following tasks on fit3182_assignment_db and corresponding collection(s). You need to write the queries as python program using the pymongo library in Jupyter Notebook.

# %% [markdown]
# A. Find climate data on 12th December 2018.

# %%
result = collection.find_one({'date': datetime(2018, 12, 12)})
pprint(result)
# Out:
# {'_id': ObjectId('60aa4d77f1c7e6844f090d16'),
#  'air_temperature_celcius': 19.0,
#  'date': datetime.datetime(2018, 12, 12, 0, 0),
#  'ghi': 156.0,
#  'hotspots': [{'confidence': 53.0,
#                'latitude': -37.903,
#                'longitude': 145.25,
#                'surface_temperature_celcius': 44.0,
#                'time': datetime.datetime(2018, 12, 12, 0, 45, 38)}],
#  'max_wind_speed': 12.0,
#  'precipitation': 0.0,
#  'precipitation_type': 'I',
#  'relative_humidity': 55.3,
#  'station': 948702,
#  'windspeed_knots': 6.2}

# %% [markdown]
# B. Find latitude, longitude, surface temperature, and confidence when the surfance temperature was between 65 and 100.

# %%
result = collection.aggregate([{'$unwind': '$hotspots'}, {'$match': {'hotspots.surface_temperature_celcius': {'$gte': 65, '$lte': 100}}}, {
    '$project': {'_id': 0, 'hotspots.longitude': 1, 'hotspots.latitude': 1, 'hotspots.surface_temperature_celcius': 1}}])

for each in result:
    pprint(each)
# Out:
# {'hotspots': {'latitude': -37.2284,
#               'longitude': 147.9187,
#               'surface_temperature_celcius': 73.0}}
# {'hotspots': {'latitude': -37.6572,
#               'longitude': 142.0703,
#               'surface_temperature_celcius': 80.0}}
# {'hotspots': {'latitude': -37.0193,
#               'longitude': 148.1459,
#               'surface_temperature_celcius': 71.0}}
# {'hotspots': {'latitude': -37.4229,
#               'longitude': 147.027,
#               'surface_temperature_celcius': 99.0}}
# {'hotspots': {'latitude': -37.0055,
#               'longitude': 148.1582,
#               'surface_temperature_celcius': 68.0}}
# {'hotspots': {'latitude': -37.4128,
#               'longitude': 147.0242,
#               'surface_temperature_celcius': 98.0}}
# {'hotspots': {'latitude': -34.357,
#               'longitude': 141.5361,
#               'surface_temperature_celcius': 67.0}}
# {'hotspots': {'latitude': -34.3539,
#               'longitude': 141.5547,
#               'surface_temperature_celcius': 72.0}}
# {'hotspots': {'latitude': -36.9939,
#               'longitude': 148.2244,
#               'surface_temperature_celcius': 68.0}}
# {'hotspots': {'latitude': -36.9959,
#               'longitude': 148.2118,
#               'surface_temperature_celcius': 75.0}}
# {'hotspots': {'latitude': -34.3654,
#               'longitude': 141.543,
#               'surface_temperature_celcius': 65.0}}
# {'hotspots': {'latitude': -34.3554,
#               'longitude': 141.5413,
#               'surface_temperature_celcius': 79.0}}
# {'hotspots': {'latitude': -34.3555,
#               'longitude': 141.5495,
#               'surface_temperature_celcius': 75.0}}
# {'hotspots': {'latitude': -36.7152,
#               'longitude': 141.3853,
#               'surface_temperature_celcius': 74.0}}
# {'hotspots': {'latitude': -37.0155,
#               'longitude': 148.1432,
#               'surface_temperature_celcius': 80.0}}
# {'hotspots': {'latitude': -37.6622,
#               'longitude': 142.1001,
#               'surface_temperature_celcius': 79.0}}
# {'hotspots': {'latitude': -37.4523,
#               'longitude': 147.0175,
#               'surface_temperature_celcius': 66.0}}
# {'hotspots': {'latitude': -37.4261,
#               'longitude': 147.0323,
#               'surface_temperature_celcius': 83.0}}
# {'hotspots': {'latitude': -37.3949,
#               'longitude': 147.0175,
#               'surface_temperature_celcius': 91.0}}
# {'hotspots': {'latitude': -37.6625,
#               'longitude': 144.287,
#               'surface_temperature_celcius': 70.0}}
# {'hotspots': {'latitude': -37.8973,
#               'longitude': 143.4754,
#               'surface_temperature_celcius': 65.0}}
# {'hotspots': {'latitude': -37.7805,
#               'longitude': 143.5003,
#               'surface_temperature_celcius': 75.0}}
# {'hotspots': {'latitude': -37.8774,
#               'longitude': 145.8213,
#               'surface_temperature_celcius': 77.0}}
# {'hotspots': {'latitude': -37.8881,
#               'longitude': 145.8229,
#               'surface_temperature_celcius': 99.0}}
# {'hotspots': {'latitude': -37.522,
#               'longitude': 143.3874,
#               'surface_temperature_celcius': 73.0}}
# {'hotspots': {'latitude': -38.0674,
#               'longitude': 142.965,
#               'surface_temperature_celcius': 68.0}}
# {'hotspots': {'latitude': -38.0715,
#               'longitude': 142.9591,
#               'surface_temperature_celcius': 70.0}}
# {'hotspots': {'latitude': -38.0693,
#               'longitude': 142.9722,
#               'surface_temperature_celcius': 89.0}}
# {'hotspots': {'latitude': -36.4557,
#               'longitude': 142.2434,
#               'surface_temperature_celcius': 71.0}}
# {'hotspots': {'latitude': -36.8009,
#               'longitude': 142.7259,
#               'surface_temperature_celcius': 76.0}}
# {'hotspots': {'latitude': -36.8099,
#               'longitude': 142.728,
#               'surface_temperature_celcius': 73.0}}
# {'hotspots': {'latitude': -36.7806,
#               'longitude': 141.5597,
#               'surface_temperature_celcius': 74.0}}
# {'hotspots': {'latitude': -34.3526,
#               'longitude': 141.6458,
#               'surface_temperature_celcius': 82.0}}
# {'hotspots': {'latitude': -37.0924,
#               'longitude': 141.897,
#               'surface_temperature_celcius': 80.0}}
# {'hotspots': {'latitude': -37.9452,
#               'longitude': 143.5834,
#               'surface_temperature_celcius': 80.0}}
# {'hotspots': {'latitude': -34.351,
#               'longitude': 141.6567,
#               'surface_temperature_celcius': 86.0}}
# {'hotspots': {'latitude': -37.5012,
#               'longitude': 142.5853,
#               'surface_temperature_celcius': 90.0}}
# {'hotspots': {'latitude': -37.9247,
#               'longitude': 142.8999,
#               'surface_temperature_celcius': 81.0}}
# {'hotspots': {'latitude': -35.0805,
#               'longitude': 142.4642,
#               'surface_temperature_celcius': 81.0}}
# {'hotspots': {'latitude': -37.3735,
#               'longitude': 145.886,
#               'surface_temperature_celcius': 96.0}}
# {'hotspots': {'latitude': -37.7465,
#               'longitude': 143.3806,
#               'surface_temperature_celcius': 72.0}}
# {'hotspots': {'latitude': -37.8072,
#               'longitude': 145.9738,
#               'surface_temperature_celcius': 77.0}}
# {'hotspots': {'latitude': -37.3704,
#               'longitude': 145.8942,
#               'surface_temperature_celcius': 78.0}}
# {'hotspots': {'latitude': -37.297,
#               'longitude': 143.5753,
#               'surface_temperature_celcius': 93.0}}
# {'hotspots': {'latitude': -37.2988,
#               'longitude': 143.5487,
#               'surface_temperature_celcius': 90.0}}
# {'hotspots': {'latitude': -37.3025,
#               'longitude': 143.5714,
#               'surface_temperature_celcius': 98.0}}
# {'hotspots': {'latitude': -37.383,
#               'longitude': 145.9089,
#               'surface_temperature_celcius': 89.0}}
# {'hotspots': {'latitude': -37.7446,
#               'longitude': 143.4085,
#               'surface_temperature_celcius': 66.0}}
# {'hotspots': {'latitude': -37.7509,
#               'longitude': 143.4023,
#               'surface_temperature_celcius': 82.0}}
# {'hotspots': {'latitude': -37.7974,
#               'longitude': 145.9535,
#               'surface_temperature_celcius': 97.0}}
# {'hotspots': {'latitude': -35.7657,
#               'longitude': 142.0906,
#               'surface_temperature_celcius': 66.0}}
# {'hotspots': {'latitude': -37.7236,
#               'longitude': 143.3995,
#               'surface_temperature_celcius': 86.0}}
# {'hotspots': {'latitude': -37.3046,
#               'longitude': 143.5448,
#               'surface_temperature_celcius': 72.0}}
# {'hotspots': {'latitude': -36.4312,
#               'longitude': 141.2064,
#               'surface_temperature_celcius': 76.0}}
# {'hotspots': {'latitude': -36.1556,
#               'longitude': 141.5904,
#               'surface_temperature_celcius': 65.0}}
# {'hotspots': {'latitude': -35.7647,
#               'longitude': 142.0858,
#               'surface_temperature_celcius': 65.0}}
# {'hotspots': {'latitude': -35.4033,
#               'longitude': 143.267,
#               'surface_temperature_celcius': 67.0}}
# {'hotspots': {'latitude': -36.6281,
#               'longitude': 142.4349,
#               'surface_temperature_celcius': 68.0}}
# {'hotspots': {'latitude': -36.111,
#               'longitude': 145.124,
#               'surface_temperature_celcius': 66.0}}
# {'hotspots': {'latitude': -36.1615,
#               'longitude': 141.8728,
#               'surface_temperature_celcius': 66.0}}
# {'hotspots': {'latitude': -36.1122,
#               'longitude': 142.1491,
#               'surface_temperature_celcius': 76.0}}
# {'hotspots': {'latitude': -37.3735,
#               'longitude': 145.8384,
#               'surface_temperature_celcius': 95.0}}
# {'hotspots': {'latitude': -35.4255,
#               'longitude': 143.6306,
#               'surface_temperature_celcius': 65.0}}
# {'hotspots': {'latitude': -36.1955,
#               'longitude': 145.914,
#               'surface_temperature_celcius': 78.0}}
# {'hotspots': {'latitude': -35.4533,
#               'longitude': 143.2029,
#               'surface_temperature_celcius': 66.0}}
# {'hotspots': {'latitude': -36.5989,
#               'longitude': 141.9771,
#               'surface_temperature_celcius': 81.0}}
# {'hotspots': {'latitude': -36.6299,
#               'longitude': 142.4234,
#               'surface_temperature_celcius': 71.0}}
# {'hotspots': {'latitude': -36.1925,
#               'longitude': 145.93,
#               'surface_temperature_celcius': 79.0}}
# {'hotspots': {'latitude': -36.095,
#               'longitude': 141.7699,
#               'surface_temperature_celcius': 82.0}}
# {'hotspots': {'latitude': -36.6006,
#               'longitude': 141.9657,
#               'surface_temperature_celcius': 78.0}}
# {'hotspots': {'latitude': -37.0769,
#               'longitude': 141.042,
#               'surface_temperature_celcius': 72.0}}
# {'hotspots': {'latitude': -36.883,
#               'longitude': 142.1637,
#               'surface_temperature_celcius': 67.0}}
# {'hotspots': {'latitude': -36.0973,
#               'longitude': 143.4279,
#               'surface_temperature_celcius': 92.0}}
# {'hotspots': {'latitude': -36.1819,
#               'longitude': 145.9269,
#               'surface_temperature_celcius': 98.0}}
# {'hotspots': {'latitude': -37.6387,
#               'longitude': 142.9032,
#               'surface_temperature_celcius': 88.0}}
# {'hotspots': {'latitude': -37.6439,
#               'longitude': 142.913,
#               'surface_temperature_celcius': 83.0}}
# {'hotspots': {'latitude': -37.3165,
#               'longitude': 147.4932,
#               'surface_temperature_celcius': 72.0}}
# {'hotspots': {'latitude': -37.3158,
#               'longitude': 147.4986,
#               'surface_temperature_celcius': 76.0}}
# {'hotspots': {'latitude': -37.4471,
#               'longitude': 147.6331,
#               'surface_temperature_celcius': 65.0}}
# {'hotspots': {'latitude': -37.7835,
#               'longitude': 148.4138,
#               'surface_temperature_celcius': 66.0}}
# {'hotspots': {'latitude': -37.4449,
#               'longitude': 147.6594,
#               'surface_temperature_celcius': 65.0}}
# {'hotspots': {'latitude': -37.4323,
#               'longitude': 147.6583,
#               'surface_temperature_celcius': 76.0}}
# {'hotspots': {'latitude': -37.4343,
#               'longitude': 147.6327,
#               'surface_temperature_celcius': 92.0}}
# {'hotspots': {'latitude': -37.5816,
#               'longitude': 148.5862,
#               'surface_temperature_celcius': 65.0}}
# {'hotspots': {'latitude': -36.6334,
#               'longitude': 142.2244,
#               'surface_temperature_celcius': 69.0}}
# {'hotspots': {'latitude': -37.7966,
#               'longitude': 142.3196,
#               'surface_temperature_celcius': 66.0}}
# {'hotspots': {'latitude': -35.805,
#               'longitude': 142.1326,
#               'surface_temperature_celcius': 95.0}}
# {'hotspots': {'latitude': -37.8429,
#               'longitude': 143.8366,
#               'surface_temperature_celcius': 88.0}}
# {'hotspots': {'latitude': -37.8062,
#               'longitude': 143.3598,
#               'surface_temperature_celcius': 65.0}}
# {'hotspots': {'latitude': -36.9918,
#               'longitude': 141.8667,
#               'surface_temperature_celcius': 97.0}}
# {'hotspots': {'latitude': -36.1104,
#               'longitude': 145.9829,
#               'surface_temperature_celcius': 76.0}}
# {'hotspots': {'latitude': -37.782,
#               'longitude': 148.3844,
#               'surface_temperature_celcius': 99.0}}
# {'hotspots': {'latitude': -36.9902,
#               'longitude': 141.879,
#               'surface_temperature_celcius': 65.0}}
# {'hotspots': {'latitude': -37.745,
#               'longitude': 142.993,
#               'surface_temperature_celcius': 65.0}}
# {'hotspots': {'latitude': -36.0157,
#               'longitude': 145.9414,
#               'surface_temperature_celcius': 70.0}}
# {'hotspots': {'latitude': -37.777,
#               'longitude': 148.4128,
#               'surface_temperature_celcius': 85.0}}
# {'hotspots': {'latitude': -37.5888,
#               'longitude': 148.5949,
#               'surface_temperature_celcius': 72.0}}
# {'hotspots': {'latitude': -34.3943,
#               'longitude': 141.7567,
#               'surface_temperature_celcius': 65.0}}
# {'hotspots': {'latitude': -36.0844,
#               'longitude': 141.4934,
#               'surface_temperature_celcius': 71.0}}
# {'hotspots': {'latitude': -36.031,
#               'longitude': 145.6824,
#               'surface_temperature_celcius': 69.0}}
# {'hotspots': {'latitude': -37.5814,
#               'longitude': 148.5777,
#               'surface_temperature_celcius': 68.0}}
# {'hotspots': {'latitude': -37.5788,
#               'longitude': 148.592,
#               'surface_temperature_celcius': 67.0}}
# {'hotspots': {'latitude': -36.6384,
#               'longitude': 142.4075,
#               'surface_temperature_celcius': 66.0}}
# {'hotspots': {'latitude': -35.811,
#               'longitude': 142.1403,
#               'surface_temperature_celcius': 96.0}}
# {'hotspots': {'latitude': -36.9034,
#               'longitude': 141.0013,
#               'surface_temperature_celcius': 95.0}}
# {'hotspots': {'latitude': -37.7746,
#               'longitude': 148.3673,
#               'surface_temperature_celcius': 65.0}}
# {'hotspots': {'latitude': -37.803,
#               'longitude': 142.3151,
#               'surface_temperature_celcius': 78.0}}
# {'hotspots': {'latitude': -37.7542,
#               'longitude': 142.9949,
#               'surface_temperature_celcius': 77.0}}
# {'hotspots': {'latitude': -37.3803,
#               'longitude': 145.611,
#               'surface_temperature_celcius': 68.0}}
# {'hotspots': {'latitude': -37.7617,
#               'longitude': 143.081,
#               'surface_temperature_celcius': 81.0}}
# {'hotspots': {'latitude': -37.8161,
#               'longitude': 142.9286,
#               'surface_temperature_celcius': 71.0}}
# {'hotspots': {'latitude': -36.0387,
#               'longitude': 145.6787,
#               'surface_temperature_celcius': 67.0}}
# {'hotspots': {'latitude': -36.6349,
#               'longitude': 142.2125,
#               'surface_temperature_celcius': 86.0}}
# {'hotspots': {'latitude': -36.9018,
#               'longitude': 141.0146,
#               'surface_temperature_celcius': 100.0}}
# {'hotspots': {'latitude': -36.6986,
#               'longitude': 142.7259,
#               'surface_temperature_celcius': 72.0}}
# {'hotspots': {'latitude': -38.0052,
#               'longitude': 142.6179,
#               'surface_temperature_celcius': 89.0}}
# {'hotspots': {'latitude': -37.2168,
#               'longitude': 147.4748,
#               'surface_temperature_celcius': 89.0}}
# {'hotspots': {'latitude': -37.222,
#               'longitude': 147.4689,
#               'surface_temperature_celcius': 78.0}}
# {'hotspots': {'latitude': -37.2063,
#               'longitude': 147.4713,
#               'surface_temperature_celcius': 70.0}}
# {'hotspots': {'latitude': -37.2082,
#               'longitude': 147.4368,
#               'surface_temperature_celcius': 70.0}}
# {'hotspots': {'latitude': -37.224,
#               'longitude': 147.4347,
#               'surface_temperature_celcius': 76.0}}
# {'hotspots': {'latitude': -37.34,
#               'longitude': 149.3668,
#               'surface_temperature_celcius': 74.0}}
# {'hotspots': {'latitude': -36.7287,
#               'longitude': 142.6017,
#               'surface_temperature_celcius': 85.0}}
# {'hotspots': {'latitude': -35.2363,
#               'longitude': 143.0004,
#               'surface_temperature_celcius': 69.0}}
# {'hotspots': {'latitude': -35.2378,
#               'longitude': 142.9864,
#               'surface_temperature_celcius': 94.0}}
# {'hotspots': {'latitude': -35.2381,
#               'longitude': 142.994,
#               'surface_temperature_celcius': 83.0}}
# {'hotspots': {'latitude': -37.3493,
#               'longitude': 149.3691,
#               'surface_temperature_celcius': 80.0}}
# {'hotspots': {'latitude': -36.7165,
#               'longitude': 142.6155,
#               'surface_temperature_celcius': 66.0}}
# {'hotspots': {'latitude': -37.5812,
#               'longitude': 142.7374,
#               'surface_temperature_celcius': 75.0}}
# {'hotspots': {'latitude': -37.5949,
#               'longitude': 142.6857,
#               'surface_temperature_celcius': 98.0}}
# {'hotspots': {'latitude': -37.8247,
#               'longitude': 143.6243,
#               'surface_temperature_celcius': 77.0}}
# {'hotspots': {'latitude': -37.4028,
#               'longitude': 143.6932,
#               'surface_temperature_celcius': 75.0}}
# {'hotspots': {'latitude': -37.4033,
#               'longitude': 143.6884,
#               'surface_temperature_celcius': 70.0}}
# {'hotspots': {'latitude': -37.8249,
#               'longitude': 143.6174,
#               'surface_temperature_celcius': 98.0}}
# {'hotspots': {'latitude': -36.6823,
#               'longitude': 142.5024,
#               'surface_temperature_celcius': 71.0}}
# {'hotspots': {'latitude': -36.4489,
#               'longitude': 144.7685,
#               'surface_temperature_celcius': 73.0}}
# {'hotspots': {'latitude': -36.9498,
#               'longitude': 142.2012,
#               'surface_temperature_celcius': 78.0}}
# {'hotspots': {'latitude': -36.1941,
#               'longitude': 143.1604,
#               'surface_temperature_celcius': 72.0}}
# {'hotspots': {'latitude': -36.4142,
#               'longitude': 143.1077,
#               'surface_temperature_celcius': 97.0}}
# {'hotspots': {'latitude': -36.1924,
#               'longitude': 143.1716,
#               'surface_temperature_celcius': 70.0}}
# {'hotspots': {'latitude': -36.0295,
#               'longitude': 143.6409,
#               'surface_temperature_celcius': 65.0}}
# {'hotspots': {'latitude': -37.0761,
#               'longitude': 141.0574,
#               'surface_temperature_celcius': 89.0}}
# {'hotspots': {'latitude': -35.0616,
#               'longitude': 141.4417,
#               'surface_temperature_celcius': 73.0}}
# {'hotspots': {'latitude': -36.3999,
#               'longitude': 144.737,
#               'surface_temperature_celcius': 88.0}}
# {'hotspots': {'latitude': -36.1748,
#               'longitude': 145.7582,
#               'surface_temperature_celcius': 69.0}}
# {'hotspots': {'latitude': -36.0691,
#               'longitude': 145.7797,
#               'surface_temperature_celcius': 85.0}}
# {'hotspots': {'latitude': -35.1949,
#               'longitude': 141.0622,
#               'surface_temperature_celcius': 66.0}}
# {'hotspots': {'latitude': -36.91,
#               'longitude': 141.2705,
#               'surface_temperature_celcius': 96.0}}
# {'hotspots': {'latitude': -35.8071,
#               'longitude': 142.7318,
#               'surface_temperature_celcius': 66.0}}
# {'hotspots': {'latitude': -36.7787,
#               'longitude': 141.4449,
#               'surface_temperature_celcius': 80.0}}
# {'hotspots': {'latitude': -36.2948,
#               'longitude': 141.3486,
#               'surface_temperature_celcius': 82.0}}
# {'hotspots': {'latitude': -38.1561,
#               'longitude': 143.7846,
#               'surface_temperature_celcius': 65.0}}
# {'hotspots': {'latitude': -37.8185,
#               'longitude': 142.5609,
#               'surface_temperature_celcius': 66.0}}
# {'hotspots': {'latitude': -36.1771,
#               'longitude': 145.7451,
#               'surface_temperature_celcius': 93.0}}
# {'hotspots': {'latitude': -38.027,
#               'longitude': 142.3844,
#               'surface_temperature_celcius': 95.0}}
# {'hotspots': {'latitude': -35.7642,
#               'longitude': 143.3321,
#               'surface_temperature_celcius': 65.0}}
# {'hotspots': {'latitude': -36.429,
#               'longitude': 141.5759,
#               'surface_temperature_celcius': 67.0}}
# {'hotspots': {'latitude': -36.1346,
#               'longitude': 145.2196,
#               'surface_temperature_celcius': 71.0}}
# {'hotspots': {'latitude': -37.0899,
#               'longitude': 141.0238,
#               'surface_temperature_celcius': 90.0}}
# {'hotspots': {'latitude': -36.3823,
#               'longitude': 141.3146,
#               'surface_temperature_celcius': 77.0}}
# {'hotspots': {'latitude': -36.1462,
#               'longitude': 145.2096,
#               'surface_temperature_celcius': 66.0}}
# {'hotspots': {'latitude': -36.5243,
#               'longitude': 142.0839,
#               'surface_temperature_celcius': 72.0}}
# {'hotspots': {'latitude': -37.618,
#               'longitude': 143.0013,
#               'surface_temperature_celcius': 82.0}}
# {'hotspots': {'latitude': -36.8867,
#               'longitude': 142.1873,
#               'surface_temperature_celcius': 66.0}}
# {'hotspots': {'latitude': -36.9364,
#               'longitude': 143.4996,
#               'surface_temperature_celcius': 70.0}}
# {'hotspots': {'latitude': -37.3847,
#               'longitude': 142.8935,
#               'surface_temperature_celcius': 88.0}}
# {'hotspots': {'latitude': -35.6374,
#               'longitude': 142.3787,
#               'surface_temperature_celcius': 95.0}}
# {'hotspots': {'latitude': -36.8835,
#               'longitude': 142.2098,
#               'surface_temperature_celcius': 67.0}}
# {'hotspots': {'latitude': -36.4125,
#               'longitude': 143.1189,
#               'surface_temperature_celcius': 92.0}}
# {'hotspots': {'latitude': -37.0669,
#               'longitude': 141.0556,
#               'surface_temperature_celcius': 80.0}}
# {'hotspots': {'latitude': -36.0714,
#               'longitude': 145.7665,
#               'surface_temperature_celcius': 71.0}}
# {'hotspots': {'latitude': -36.2933,
#               'longitude': 141.36,
#               'surface_temperature_celcius': 75.0}}
# {'hotspots': {'latitude': -37.4591,
#               'longitude': 144.9492,
#               'surface_temperature_celcius': 89.0}}
# {'hotspots': {'latitude': -36.3487,
#               'longitude': 145.5315,
#               'surface_temperature_celcius': 68.0}}
# {'hotspots': {'latitude': -36.5399,
#               'longitude': 144.678,
#               'surface_temperature_celcius': 66.0}}
# {'hotspots': {'latitude': -36.8158,
#               'longitude': 142.6229,
#               'surface_temperature_celcius': 80.0}}
# {'hotspots': {'latitude': -36.4518,
#               'longitude': 144.7752,
#               'surface_temperature_celcius': 97.0}}
# {'hotspots': {'latitude': -36.7903,
#               'longitude': 141.618,
#               'surface_temperature_celcius': 67.0}}
# {'hotspots': {'latitude': -36.1067,
#               'longitude': 143.7948,
#               'surface_temperature_celcius': 79.0}}
# {'hotspots': {'latitude': -36.1441,
#               'longitude': 145.2221,
#               'surface_temperature_celcius': 65.0}}
# {'hotspots': {'latitude': -36.4816,
#               'longitude': 141.6635,
#               'surface_temperature_celcius': 75.0}}
# {'hotspots': {'latitude': -36.0837,
#               'longitude': 144.2448,
#               'surface_temperature_celcius': 87.0}}
# {'hotspots': {'latitude': -36.782,
#               'longitude': 141.8851,
#               'surface_temperature_celcius': 67.0}}
# {'hotspots': {'latitude': -36.5586,
#               'longitude': 144.0423,
#               'surface_temperature_celcius': 71.0}}
# {'hotspots': {'latitude': -36.5568,
#               'longitude': 144.0538,
#               'surface_temperature_celcius': 68.0}}
# {'hotspots': {'latitude': -36.4538,
#               'longitude': 144.763,
#               'surface_temperature_celcius': 81.0}}
# {'hotspots': {'latitude': -36.4612,
#               'longitude': 144.7775,
#               'surface_temperature_celcius': 80.0}}
# {'hotspots': {'latitude': -36.7089,
#               'longitude': 143.3518,
#               'surface_temperature_celcius': 93.0}}
# {'hotspots': {'latitude': -36.601,
#               'longitude': 144.6378,
#               'surface_temperature_celcius': 80.0}}
# {'hotspots': {'latitude': -36.8681,
#               'longitude': 143.5186,
#               'surface_temperature_celcius': 76.0}}
# {'hotspots': {'latitude': -37.1999,
#               'longitude': 143.8231,
#               'surface_temperature_celcius': 90.0}}
# {'hotspots': {'latitude': -37.6171,
#               'longitude': 142.9426,
#               'surface_temperature_celcius': 68.0}}
# {'hotspots': {'latitude': -37.7587,
#               'longitude': 142.8521,
#               'surface_temperature_celcius': 80.0}}
# {'hotspots': {'latitude': -37.4611,
#               'longitude': 144.9371,
#               'surface_temperature_celcius': 69.0}}
# {'hotspots': {'latitude': -38.0254,
#               'longitude': 142.3959,
#               'surface_temperature_celcius': 99.0}}
# {'hotspots': {'latitude': -37.88,
#               'longitude': 143.7233,
#               'surface_temperature_celcius': 65.0}}
# {'hotspots': {'latitude': -37.8885,
#               'longitude': 143.9157,
#               'surface_temperature_celcius': 85.0}}
# {'hotspots': {'latitude': -35.0706,
#               'longitude': 141.4435,
#               'surface_temperature_celcius': 75.0}}
# {'hotspots': {'latitude': -38.0795,
#               'longitude': 143.2449,
#               'surface_temperature_celcius': 91.0}}
# {'hotspots': {'latitude': -35.1857,
#               'longitude': 141.0604,
#               'surface_temperature_celcius': 92.0}}
# {'hotspots': {'latitude': -35.6469,
#               'longitude': 142.376,
#               'surface_temperature_celcius': 93.0}}
# {'hotspots': {'latitude': -35.6453,
#               'longitude': 142.387,
#               'surface_temperature_celcius': 69.0}}
# {'hotspots': {'latitude': -36.4409,
#               'longitude': 141.6948,
#               'surface_temperature_celcius': 92.0}}
# {'hotspots': {'latitude': -37.9174,
#               'longitude': 145.8678,
#               'surface_temperature_celcius': 93.0}}
# {'hotspots': {'latitude': -37.9152,
#               'longitude': 145.8808,
#               'surface_temperature_celcius': 77.0}}
# {'hotspots': {'latitude': -37.8906,
#               'longitude': 146.2035,
#               'surface_temperature_celcius': 75.0}}
# {'hotspots': {'latitude': -35.8182,
#               'longitude': 143.8739,
#               'surface_temperature_celcius': 92.0}}
# {'hotspots': {'latitude': -37.9246,
#               'longitude': 146.2464,
#               'surface_temperature_celcius': 96.0}}
# {'hotspots': {'latitude': -36.3313,
#               'longitude': 141.0017,
#               'surface_temperature_celcius': 73.0}}
# {'hotspots': {'latitude': -36.2857,
#               'longitude': 141.3467,
#               'surface_temperature_celcius': 67.0}}
# {'hotspots': {'latitude': -36.0749,
#               'longitude': 143.4058,
#               'surface_temperature_celcius': 70.0}}
# {'hotspots': {'latitude': -36.4449,
#               'longitude': 140.9836,
#               'surface_temperature_celcius': 68.0}}
# {'hotspots': {'latitude': -36.3972,
#               'longitude': 141.6041,
#               'surface_temperature_celcius': 90.0}}
# {'hotspots': {'latitude': -36.5532,
#               'longitude': 142.5349,
#               'surface_temperature_celcius': 67.0}}
# {'hotspots': {'latitude': -36.1367,
#               'longitude': 145.2071,
#               'surface_temperature_celcius': 71.0}}
# {'hotspots': {'latitude': -36.1518,
#               'longitude': 144.0233,
#               'surface_temperature_celcius': 79.0}}
# {'hotspots': {'latitude': -36.1418,
#               'longitude': 144.0261,
#               'surface_temperature_celcius': 76.0}}
# {'hotspots': {'latitude': -36.7499,
#               'longitude': 141.3006,
#               'surface_temperature_celcius': 99.0}}
# {'hotspots': {'latitude': -36.7432,
#               'longitude': 141.3296,
#               'surface_temperature_celcius': 79.0}}
# {'hotspots': {'latitude': -36.7531,
#               'longitude': 141.3253,
#               'surface_temperature_celcius': 78.0}}
# {'hotspots': {'latitude': -36.7943,
#               'longitude': 143.9571,
#               'surface_temperature_celcius': 84.0}}
# {'hotspots': {'latitude': -36.7957,
#               'longitude': 143.9652,
#               'surface_temperature_celcius': 87.0}}
# {'hotspots': {'latitude': -36.9329,
#               'longitude': 143.7796,
#               'surface_temperature_celcius': 82.0}}
# {'hotspots': {'latitude': -35.8276,
#               'longitude': 143.7549,
#               'surface_temperature_celcius': 85.0}}
# {'hotspots': {'latitude': -35.9326,
#               'longitude': 141.958,
#               'surface_temperature_celcius': 66.0}}
# {'hotspots': {'latitude': -36.6892,
#               'longitude': 145.2775,
#               'surface_temperature_celcius': 69.0}}
# {'hotspots': {'latitude': -36.73,
#               'longitude': 143.935,
#               'surface_temperature_celcius': 65.0}}
# {'hotspots': {'latitude': -36.8283,
#               'longitude': 143.4605,
#               'surface_temperature_celcius': 93.0}}
# {'hotspots': {'latitude': -36.6527,
#               'longitude': 142.7392,
#               'surface_temperature_celcius': 81.0}}
# {'hotspots': {'latitude': -36.1898,
#               'longitude': 145.0922,
#               'surface_temperature_celcius': 78.0}}
# {'hotspots': {'latitude': -36.8298,
#               'longitude': 143.4483,
#               'surface_temperature_celcius': 79.0}}
# {'hotspots': {'latitude': -36.6615,
#               'longitude': 144.6014,
#               'surface_temperature_celcius': 90.0}}
# {'hotspots': {'latitude': -36.8238,
#               'longitude': 143.5724,
#               'surface_temperature_celcius': 73.0}}
# {'hotspots': {'latitude': -36.1988,
#               'longitude': 145.0941,
#               'surface_temperature_celcius': 100.0}}
# {'hotspots': {'latitude': -36.7651,
#               'longitude': 143.5801,
#               'surface_temperature_celcius': 68.0}}
# {'hotspots': {'latitude': -36.5199,
#               'longitude': 144.7311,
#               'surface_temperature_celcius': 77.0}}
# {'hotspots': {'latitude': -37.0782,
#               'longitude': 145.3625,
#               'surface_temperature_celcius': 68.0}}
# {'hotspots': {'latitude': -36.3966,
#               'longitude': 141.406,
#               'surface_temperature_celcius': 74.0}}
# {'hotspots': {'latitude': -37.1349,
#               'longitude': 141.9491,
#               'surface_temperature_celcius': 67.0}}
# {'hotspots': {'latitude': -37.6397,
#               'longitude': 142.5968,
#               'surface_temperature_celcius': 68.0}}
# {'hotspots': {'latitude': -37.6267,
#               'longitude': 142.9993,
#               'surface_temperature_celcius': 66.0}}
# {'hotspots': {'latitude': -36.5871,
#               'longitude': 144.4958,
#               'surface_temperature_celcius': 72.0}}
# {'hotspots': {'latitude': -36.2618,
#               'longitude': 141.8783,
#               'surface_temperature_celcius': 65.0}}
# {'hotspots': {'latitude': -36.6828,
#               'longitude': 144.784,
#               'surface_temperature_celcius': 66.0}}
# {'hotspots': {'latitude': -37.4843,
#               'longitude': 143.0592,
#               'surface_temperature_celcius': 66.0}}
# {'hotspots': {'latitude': -37.7274,
#               'longitude': 142.9536,
#               'surface_temperature_celcius': 73.0}}
# {'hotspots': {'latitude': -37.6964,
#               'longitude': 142.8583,
#               'surface_temperature_celcius': 69.0}}
# {'hotspots': {'latitude': -38.0509,
#               'longitude': 143.9423,
#               'surface_temperature_celcius': 82.0}}
# {'hotspots': {'latitude': -37.9284,
#               'longitude': 143.108,
#               'surface_temperature_celcius': 70.0}}
# {'hotspots': {'latitude': -37.5701,
#               'longitude': 142.6497,
#               'surface_temperature_celcius': 94.0}}
# {'hotspots': {'latitude': -36.7101,
#               'longitude': 142.3865,
#               'surface_temperature_celcius': 67.0}}
# {'hotspots': {'latitude': -38.1693,
#               'longitude': 143.0466,
#               'surface_temperature_celcius': 73.0}}
# {'hotspots': {'latitude': -36.7128,
#               'longitude': 142.3717,
#               'surface_temperature_celcius': 77.0}}
# {'hotspots': {'latitude': -37.4885,
#               'longitude': 142.0658,
#               'surface_temperature_celcius': 81.0}}
# {'hotspots': {'latitude': -36.7101,
#               'longitude': 142.981,
#               'surface_temperature_celcius': 68.0}}
# {'hotspots': {'latitude': -37.0959,
#               'longitude': 143.8206,
#               'surface_temperature_celcius': 65.0}}
# {'hotspots': {'latitude': -37.9594,
#               'longitude': 143.5638,
#               'surface_temperature_celcius': 87.0}}
# {'hotspots': {'latitude': -36.5921,
#               'longitude': 144.4905,
#               'surface_temperature_celcius': 82.0}}
# {'hotspots': {'latitude': -36.6787,
#               'longitude': 144.8042,
#               'surface_temperature_celcius': 79.0}}
# {'hotspots': {'latitude': -38.0423,
#               'longitude': 146.4048,
#               'surface_temperature_celcius': 66.0}}
# {'hotspots': {'latitude': -38.1224,
#               'longitude': 143.7553,
#               'surface_temperature_celcius': 73.0}}
# {'hotspots': {'latitude': -38.0792,
#               'longitude': 143.7361,
#               'surface_temperature_celcius': 93.0}}
# {'hotspots': {'latitude': -37.9157,
#               'longitude': 143.3544,
#               'surface_temperature_celcius': 72.0}}
# {'hotspots': {'latitude': -37.7935,
#               'longitude': 143.1606,
#               'surface_temperature_celcius': 78.0}}
# {'hotspots': {'latitude': -37.7756,
#               'longitude': 143.1388,
#               'surface_temperature_celcius': 67.0}}
# {'hotspots': {'latitude': -37.7171,
#               'longitude': 142.9505,
#               'surface_temperature_celcius': 68.0}}
# {'hotspots': {'latitude': -37.7236,
#               'longitude': 142.947,
#               'surface_temperature_celcius': 73.0}}
# {'hotspots': {'latitude': -37.7002,
#               'longitude': 142.9562,
#               'surface_temperature_celcius': 89.0}}
# {'hotspots': {'latitude': -37.6498,
#               'longitude': 142.5997,
#               'surface_temperature_celcius': 70.0}}
# {'hotspots': {'latitude': -37.5728,
#               'longitude': 142.6348,
#               'surface_temperature_celcius': 98.0}}
# {'hotspots': {'latitude': -37.4352,
#               'longitude': 143.1444,
#               'surface_temperature_celcius': 96.0}}
# {'hotspots': {'latitude': -36.5828,
#               'longitude': 144.5775,
#               'surface_temperature_celcius': 70.0}}
# {'hotspots': {'latitude': -36.5987,
#               'longitude': 144.4995,
#               'surface_temperature_celcius': 79.0}}
# {'hotspots': {'latitude': -36.5262,
#               'longitude': 144.5737,
#               'surface_temperature_celcius': 84.0}}
# {'hotspots': {'latitude': -36.6995,
#               'longitude': 142.978,
#               'surface_temperature_celcius': 76.0}}
# {'hotspots': {'latitude': -36.8879,
#               'longitude': 141.6647,
#               'surface_temperature_celcius': 72.0}}
# {'hotspots': {'latitude': -35.8768,
#               'longitude': 145.4627,
#               'surface_temperature_celcius': 86.0}}
# {'hotspots': {'latitude': -36.4899,
#               'longitude': 142.2805,
#               'surface_temperature_celcius': 73.0}}
# {'hotspots': {'latitude': -36.663,
#               'longitude': 141.3038,
#               'surface_temperature_celcius': 72.0}}
# {'hotspots': {'latitude': -36.092,
#               'longitude': 141.7306,
#               'surface_temperature_celcius': 75.0}}
# {'hotspots': {'latitude': -34.9023,
#               'longitude': 142.0557,
#               'surface_temperature_celcius': 65.0}}
# {'hotspots': {'latitude': -36.2637,
#               'longitude': 145.3649,
#               'surface_temperature_celcius': 69.0}}
# {'hotspots': {'latitude': -37.2609,
#               'longitude': 141.7999,
#               'surface_temperature_celcius': 66.0}}
# {'hotspots': {'latitude': -36.91,
#               'longitude': 141.0704,
#               'surface_temperature_celcius': 73.0}}
# {'hotspots': {'latitude': -36.2652,
#               'longitude': 145.3769,
#               'surface_temperature_celcius': 70.0}}
# {'hotspots': {'latitude': -36.738,
#               'longitude': 142.1177,
#               'surface_temperature_celcius': 77.0}}
# {'hotspots': {'latitude': -37.876,
#               'longitude': 143.7804,
#               'surface_temperature_celcius': 65.0}}
# {'hotspots': {'latitude': -36.1546,
#               'longitude': 141.8146,
#               'surface_temperature_celcius': 74.0}}
# {'hotspots': {'latitude': -37.9091,
#               'longitude': 143.5105,
#               'surface_temperature_celcius': 70.0}}
# {'hotspots': {'latitude': -36.1559,
#               'longitude': 141.8102,
#               'surface_temperature_celcius': 66.0}}
# {'hotspots': {'latitude': -37.9071,
#               'longitude': 143.538,
#               'surface_temperature_celcius': 88.0}}
# {'hotspots': {'latitude': -37.3902,
#               'longitude': 148.2955,
#               'surface_temperature_celcius': 98.0}}
# {'hotspots': {'latitude': -37.5027,
#               'longitude': 146.347,
#               'surface_temperature_celcius': 95.0}}
# {'hotspots': {'latitude': -37.5043,
#               'longitude': 146.3299,
#               'surface_temperature_celcius': 93.0}}
# {'hotspots': {'latitude': -36.1964,
#               'longitude': 144.5217,
#               'surface_temperature_celcius': 72.0}}
# {'hotspots': {'latitude': -37.769,
#               'longitude': 147.94,
#               'surface_temperature_celcius': 72.0}}
# {'hotspots': {'latitude': -36.1303,
#               'longitude': 146.3606,
#               'surface_temperature_celcius': 67.0}}
# {'hotspots': {'latitude': -36.1345,
#               'longitude': 146.351,
#               'surface_temperature_celcius': 84.0}}
# {'hotspots': {'latitude': -36.1586,
#               'longitude': 145.6666,
#               'surface_temperature_celcius': 85.0}}
# {'hotspots': {'latitude': -36.5847,
#               'longitude': 145.1968,
#               'surface_temperature_celcius': 78.0}}
# {'hotspots': {'latitude': -36.9111,
#               'longitude': 142.692,
#               'surface_temperature_celcius': 72.0}}
# {'hotspots': {'latitude': -37.5115,
#               'longitude': 143.14,
#               'surface_temperature_celcius': 86.0}}
# {'hotspots': {'latitude': -37.6775,
#               'longitude': 148.5131,
#               'surface_temperature_celcius': 78.0}}
# {'hotspots': {'latitude': -36.3332,
#               'longitude': 145.8594,
#               'surface_temperature_celcius': 90.0}}
# {'hotspots': {'latitude': -36.9303,
#               'longitude': 143.1034,
#               'surface_temperature_celcius': 72.0}}
# {'hotspots': {'latitude': -36.3195,
#               'longitude': 146.0601,
#               'surface_temperature_celcius': 77.0}}
# {'hotspots': {'latitude': -36.5839,
#               'longitude': 143.0588,
#               'surface_temperature_celcius': 99.0}}
# {'hotspots': {'latitude': -36.5854,
#               'longitude': 143.0462,
#               'surface_temperature_celcius': 94.0}}
# {'hotspots': {'latitude': -36.3014,
#               'longitude': 143.203,
#               'surface_temperature_celcius': 76.0}}
# {'hotspots': {'latitude': -38.1917,
#               'longitude': 147.0745,
#               'surface_temperature_celcius': 94.0}}
# {'hotspots': {'latitude': -38.1987,
#               'longitude': 147.0666,
#               'surface_temperature_celcius': 76.0}}
# {'hotspots': {'latitude': -36.5454,
#               'longitude': 144.7402,
#               'surface_temperature_celcius': 96.0}}
# {'hotspots': {'latitude': -36.7593,
#               'longitude': 142.895,
#               'surface_temperature_celcius': 69.0}}
# {'hotspots': {'latitude': -36.3435,
#               'longitude': 141.5513,
#               'surface_temperature_celcius': 67.0}}
# {'hotspots': {'latitude': -36.6942,
#               'longitude': 143.8021,
#               'surface_temperature_celcius': 72.0}}
# {'hotspots': {'latitude': -36.3459,
#               'longitude': 141.5586,
#               'surface_temperature_celcius': 91.0}}
# {'hotspots': {'latitude': -36.4046,
#               'longitude': 141.1534,
#               'surface_temperature_celcius': 73.0}}
# {'hotspots': {'latitude': -36.0594,
#               'longitude': 141.5907,
#               'surface_temperature_celcius': 79.0}}
# {'hotspots': {'latitude': -36.0576,
#               'longitude': 141.6122,
#               'surface_temperature_celcius': 94.0}}
# {'hotspots': {'latitude': -36.388,
#               'longitude': 141.8309,
#               'surface_temperature_celcius': 73.0}}
# {'hotspots': {'latitude': -36.094,
#               'longitude': 145.7646,
#               'surface_temperature_celcius': 67.0}}
# {'hotspots': {'latitude': -36.5438,
#               'longitude': 144.7548,
#               'surface_temperature_celcius': 84.0}}
# {'hotspots': {'latitude': -36.6537,
#               'longitude': 143.8781,
#               'surface_temperature_celcius': 76.0}}
# {'hotspots': {'latitude': -36.663,
#               'longitude': 142.8567,
#               'surface_temperature_celcius': 71.0}}
# {'hotspots': {'latitude': -37.6982,
#               'longitude': 143.0549,
#               'surface_temperature_celcius': 73.0}}
# {'hotspots': {'latitude': -36.7187,
#               'longitude': 143.805,
#               'surface_temperature_celcius': 76.0}}
# {'hotspots': {'latitude': -36.7742,
#               'longitude': 145.1991,
#               'surface_temperature_celcius': 89.0}}
# {'hotspots': {'latitude': -36.5061,
#               'longitude': 144.5675,
#               'surface_temperature_celcius': 68.0}}
# {'hotspots': {'latitude': -36.4035,
#               'longitude': 140.9935,
#               'surface_temperature_celcius': 95.0}}
# {'hotspots': {'latitude': -36.4286,
#               'longitude': 141.1567,
#               'surface_temperature_celcius': 84.0}}
# {'hotspots': {'latitude': -36.3635,
#               'longitude': 142.2809,
#               'surface_temperature_celcius': 68.0}}
# {'hotspots': {'latitude': -36.664,
#               'longitude': 142.8802,
#               'surface_temperature_celcius': 87.0}}
# {'hotspots': {'latitude': -36.6564,
#               'longitude': 142.8615,
#               'surface_temperature_celcius': 69.0}}
# {'hotspots': {'latitude': -36.6657,
#               'longitude': 143.1675,
#               'surface_temperature_celcius': 72.0}}
# {'hotspots': {'latitude': -36.8742,
#               'longitude': 142.7177,
#               'surface_temperature_celcius': 84.0}}
# {'hotspots': {'latitude': -36.7751,
#               'longitude': 145.1696,
#               'surface_temperature_celcius': 68.0}}
# {'hotspots': {'latitude': -36.3961,
#               'longitude': 140.9781,
#               'surface_temperature_celcius': 69.0}}
# {'hotspots': {'latitude': -36.7708,
#               'longitude': 145.1908,
#               'surface_temperature_celcius': 98.0}}
# {'hotspots': {'latitude': -37.758,
#               'longitude': 143.179,
#               'surface_temperature_celcius': 82.0}}
# {'hotspots': {'latitude': -37.7609,
#               'longitude': 143.1633,
#               'surface_temperature_celcius': 74.0}}
# {'hotspots': {'latitude': -36.5116,
#               'longitude': 144.562,
#               'surface_temperature_celcius': 66.0}}
# {'hotspots': {'latitude': -36.803,
#               'longitude': 142.9261,
#               'surface_temperature_celcius': 70.0}}
# {'hotspots': {'latitude': -36.4143,
#               'longitude': 143.272,
#               'surface_temperature_celcius': 65.0}}
# {'hotspots': {'latitude': -36.7153,
#               'longitude': 143.8226,
#               'surface_temperature_celcius': 86.0}}
# {'hotspots': {'latitude': -36.8791,
#               'longitude': 142.7261,
#               'surface_temperature_celcius': 93.0}}
# {'hotspots': {'latitude': -36.7309,
#               'longitude': 142.3633,
#               'surface_temperature_celcius': 88.0}}
# {'hotspots': {'latitude': -36.882,
#               'longitude': 142.7108,
#               'surface_temperature_celcius': 70.0}}
# {'hotspots': {'latitude': -37.5135,
#               'longitude': 142.7238,
#               'surface_temperature_celcius': 72.0}}
# {'hotspots': {'latitude': -36.2121,
#               'longitude': 144.6885,
#               'surface_temperature_celcius': 74.0}}
# {'hotspots': {'latitude': -36.2206,
#               'longitude': 144.6856,
#               'surface_temperature_celcius': 80.0}}
# {'hotspots': {'latitude': -38.0132,
#               'longitude': 146.5269,
#               'surface_temperature_celcius': 73.0}}
# {'hotspots': {'latitude': -38.0148,
#               'longitude': 146.5413,
#               'surface_temperature_celcius': 71.0}}
# {'hotspots': {'latitude': -37.8412,
#               'longitude': 147.2536,
#               'surface_temperature_celcius': 87.0}}
# {'hotspots': {'latitude': -37.8429,
#               'longitude': 147.2691,
#               'surface_temperature_celcius': 78.0}}
# {'hotspots': {'latitude': -36.6139,
#               'longitude': 143.501,
#               'surface_temperature_celcius': 77.0}}
# {'hotspots': {'latitude': -37.9509,
#               'longitude': 143.9599,
#               'surface_temperature_celcius': 76.0}}
# {'hotspots': {'latitude': -36.6224,
#               'longitude': 143.5092,
#               'surface_temperature_celcius': 80.0}}
# {'hotspots': {'latitude': -38.0933,
#               'longitude': 143.9824,
#               'surface_temperature_celcius': 78.0}}
# {'hotspots': {'latitude': -35.6138,
#               'longitude': 143.8666,
#               'surface_temperature_celcius': 68.0}}
# {'hotspots': {'latitude': -36.0885,
#               'longitude': 145.0359,
#               'surface_temperature_celcius': 76.0}}
# {'hotspots': {'latitude': -36.3193,
#               'longitude': 145.9162,
#               'surface_temperature_celcius': 78.0}}
# {'hotspots': {'latitude': -36.0652,
#               'longitude': 146.0764,
#               'surface_temperature_celcius': 82.0}}
# {'hotspots': {'latitude': -36.0682,
#               'longitude': 146.0602,
#               'surface_temperature_celcius': 90.0}}
# {'hotspots': {'latitude': -37.7889,
#               'longitude': 143.1324,
#               'surface_temperature_celcius': 71.0}}
# {'hotspots': {'latitude': -36.2306,
#               'longitude': 143.6408,
#               'surface_temperature_celcius': 72.0}}
# {'hotspots': {'latitude': -36.4168,
#               'longitude': 141.6939,
#               'surface_temperature_celcius': 68.0}}
# {'hotspots': {'latitude': -36.4211,
#               'longitude': 141.6875,
#               'surface_temperature_celcius': 81.0}}
# {'hotspots': {'latitude': -36.8094,
#               'longitude': 142.8885,
#               'surface_temperature_celcius': 77.0}}
# {'hotspots': {'latitude': -37.8323,
#               'longitude': 147.2232,
#               'surface_temperature_celcius': 68.0}}
# {'hotspots': {'latitude': -38.2853,
#               'longitude': 145.9519,
#               'surface_temperature_celcius': 83.0}}
# {'hotspots': {'latitude': -38.2375,
#               'longitude': 142.8363,
#               'surface_temperature_celcius': 82.0}}
# {'hotspots': {'latitude': -37.4463,
#               'longitude': 142.7829,
#               'surface_temperature_celcius': 70.0}}
# {'hotspots': {'latitude': -37.6854,
#               'longitude': 143.4543,
#               'surface_temperature_celcius': 76.0}}
# {'hotspots': {'latitude': -38.0881,
#               'longitude': 143.9391,
#               'surface_temperature_celcius': 84.0}}
# {'hotspots': {'latitude': -38.0866,
#               'longitude': 143.9534,
#               'surface_temperature_celcius': 78.0}}
# {'hotspots': {'latitude': -38.2391,
#               'longitude': 142.82,
#               'surface_temperature_celcius': 71.0}}
# {'hotspots': {'latitude': -38.5123,
#               'longitude': 146.4007,
#               'surface_temperature_celcius': 89.0}}
# {'hotspots': {'latitude': -36.3438,
#               'longitude': 141.5832,
#               'surface_temperature_celcius': 78.0}}
# {'hotspots': {'latitude': -37.4357,
#               'longitude': 142.7813,
#               'surface_temperature_celcius': 74.0}}
# {'hotspots': {'latitude': -37.5867,
#               'longitude': 143.6256,
#               'surface_temperature_celcius': 85.0}}
# {'hotspots': {'latitude': -36.2911,
#               'longitude': 141.1664,
#               'surface_temperature_celcius': 67.0}}
# {'hotspots': {'latitude': -36.2842,
#               'longitude': 141.1741,
#               'surface_temperature_celcius': 79.0}}
# {'hotspots': {'latitude': -36.7218,
#               'longitude': 141.6411,
#               'surface_temperature_celcius': 65.0}}
# {'hotspots': {'latitude': -37.3656,
#               'longitude': 141.3903,
#               'surface_temperature_celcius': 78.0}}
# {'hotspots': {'latitude': -36.4179,
#               'longitude': 144.2924,
#               'surface_temperature_celcius': 75.0}}
# {'hotspots': {'latitude': -36.3207,
#               'longitude': 140.9737,
#               'surface_temperature_celcius': 70.0}}
# {'hotspots': {'latitude': -36.2882,
#               'longitude': 141.1821,
#               'surface_temperature_celcius': 86.0}}
# {'hotspots': {'latitude': -36.3153,
#               'longitude': 140.9789,
#               'surface_temperature_celcius': 69.0}}
# {'hotspots': {'latitude': -36.4169,
#               'longitude': 144.2994,
#               'surface_temperature_celcius': 81.0}}
# {'hotspots': {'latitude': -37.4671,
#               'longitude': 145.9962,
#               'surface_temperature_celcius': 73.0}}
# {'hotspots': {'latitude': -36.3254,
#               'longitude': 144.3638,
#               'surface_temperature_celcius': 77.0}}
# {'hotspots': {'latitude': -36.0816,
#               'longitude': 145.859,
#               'surface_temperature_celcius': 98.0}}
# {'hotspots': {'latitude': -36.1532,
#               'longitude': 143.5527,
#               'surface_temperature_celcius': 90.0}}
# {'hotspots': {'latitude': -36.0077,
#               'longitude': 141.7747,
#               'surface_temperature_celcius': 93.0}}
# {'hotspots': {'latitude': -36.0828,
#               'longitude': 145.873,
#               'surface_temperature_celcius': 75.0}}
# {'hotspots': {'latitude': -36.5541,
#               'longitude': 144.1321,
#               'surface_temperature_celcius': 69.0}}
# {'hotspots': {'latitude': -35.6819,
#               'longitude': 143.5275,
#               'surface_temperature_celcius': 69.0}}
# {'hotspots': {'latitude': -35.6871,
#               'longitude': 143.5235,
#               'surface_temperature_celcius': 68.0}}
# {'hotspots': {'latitude': -36.1506,
#               'longitude': 143.5671,
#               'surface_temperature_celcius': 95.0}}
# {'hotspots': {'latitude': -37.4984,
#               'longitude': 142.9739,
#               'surface_temperature_celcius': 73.0}}
# {'hotspots': {'latitude': -37.253,
#               'longitude': 144.3681,
#               'surface_temperature_celcius': 78.0}}
# {'hotspots': {'latitude': -36.9396,
#               'longitude': 143.1462,
#               'surface_temperature_celcius': 70.0}}
# {'hotspots': {'latitude': -36.3387,
#               'longitude': 141.7542,
#               'surface_temperature_celcius': 77.0}}
# {'hotspots': {'latitude': -36.3433,
#               'longitude': 143.4369,
#               'surface_temperature_celcius': 94.0}}
# {'hotspots': {'latitude': -36.345,
#               'longitude': 143.4256,
#               'surface_temperature_celcius': 87.0}}
# {'hotspots': {'latitude': -36.7032,
#               'longitude': 144.0992,
#               'surface_temperature_celcius': 66.0}}
# {'hotspots': {'latitude': -36.3402,
#               'longitude': 141.7429,
#               'surface_temperature_celcius': 77.0}}
# {'hotspots': {'latitude': -36.5661,
#               'longitude': 142.2956,
#               'surface_temperature_celcius': 65.0}}
# {'hotspots': {'latitude': -36.5023,
#               'longitude': 143.6038,
#               'surface_temperature_celcius': 66.0}}
# {'hotspots': {'latitude': -36.8616,
#               'longitude': 142.8025,
#               'surface_temperature_celcius': 78.0}}
# {'hotspots': {'latitude': -38.0372,
#               'longitude': 146.0616,
#               'surface_temperature_celcius': 67.0}}
# {'hotspots': {'latitude': -38.049,
#               'longitude': 146.0513,
#               'surface_temperature_celcius': 74.0}}
# {'hotspots': {'latitude': -35.4666,
#               'longitude': 142.0749,
#               'surface_temperature_celcius': 65.0}}
# {'hotspots': {'latitude': -36.0396,
#               'longitude': 141.7183,
#               'surface_temperature_celcius': 76.0}}
# {'hotspots': {'latitude': -36.2775,
#               'longitude': 146.1026,
#               'surface_temperature_celcius': 74.0}}
# {'hotspots': {'latitude': -38.0361,
#               'longitude': 146.0567,
#               'surface_temperature_celcius': 90.0}}
# {'hotspots': {'latitude': -36.7746,
#               'longitude': 146.6642,
#               'surface_temperature_celcius': 68.0}}
# {'hotspots': {'latitude': -36.8359,
#               'longitude': 146.6448,
#               'surface_temperature_celcius': 78.0}}
# {'hotspots': {'latitude': -37.9085,
#               'longitude': 141.1038,
#               'surface_temperature_celcius': 82.0}}
# {'hotspots': {'latitude': -38.4349,
#               'longitude': 146.3122,
#               'surface_temperature_celcius': 93.0}}
# {'hotspots': {'latitude': -38.4792,
#               'longitude': 146.3081,
#               'surface_temperature_celcius': 65.0}}
# {'hotspots': {'latitude': -37.9047,
#               'longitude': 141.0945,
#               'surface_temperature_celcius': 90.0}}
# {'hotspots': {'latitude': -36.7685,
#               'longitude': 142.7134,
#               'surface_temperature_celcius': 69.0}}
# {'hotspots': {'latitude': -36.7801,
#               'longitude': 142.7151,
#               'surface_temperature_celcius': 68.0}}
# {'hotspots': {'latitude': -36.1002,
#               'longitude': 142.3405,
#               'surface_temperature_celcius': 78.0}}
# {'hotspots': {'latitude': -36.4325,
#               'longitude': 144.3142,
#               'surface_temperature_celcius': 67.0}}
# {'hotspots': {'latitude': -36.2693,
#               'longitude': 143.1768,
#               'surface_temperature_celcius': 85.0}}
# {'hotspots': {'latitude': -36.3774,
#               'longitude': 143.7079,
#               'surface_temperature_celcius': 68.0}}
# {'hotspots': {'latitude': -36.3756,
#               'longitude': 143.7243,
#               'surface_temperature_celcius': 88.0}}
# {'hotspots': {'latitude': -36.369,
#               'longitude': 143.7132,
#               'surface_temperature_celcius': 80.0}}
# {'hotspots': {'latitude': -36.3799,
#               'longitude': 143.7149,
#               'surface_temperature_celcius': 89.0}}
# {'hotspots': {'latitude': -37.8644,
#               'longitude': 143.4263,
#               'surface_temperature_celcius': 69.0}}
# {'hotspots': {'latitude': -38.3998,
#               'longitude': 147.064,
#               'surface_temperature_celcius': 65.0}}
# {'hotspots': {'latitude': -37.4796,
#               'longitude': 141.9403,
#               'surface_temperature_celcius': 87.0}}
# {'hotspots': {'latitude': -37.379,
#               'longitude': 148.126,
#               'surface_temperature_celcius': 82.0}}
# {'hotspots': {'latitude': -37.379,
#               'longitude': 148.132,
#               'surface_temperature_celcius': 78.0}}
# {'hotspots': {'latitude': -37.396,
#               'longitude': 148.086,
#               'surface_temperature_celcius': 65.0}}
# {'hotspots': {'latitude': -37.399,
#               'longitude': 148.081,
#               'surface_temperature_celcius': 84.0}}
# {'hotspots': {'latitude': -37.401,
#               'longitude': 148.067,
#               'surface_temperature_celcius': 79.0}}
# {'hotspots': {'latitude': -37.446,
#               'longitude': 148.102,
#               'surface_temperature_celcius': 65.0}}
# {'hotspots': {'latitude': -37.406,
#               'longitude': 148.123,
#               'surface_temperature_celcius': 88.0}}
# {'hotspots': {'latitude': -37.452,
#               'longitude': 148.115,
#               'surface_temperature_celcius': 77.0}}
# {'hotspots': {'latitude': -37.45,
#               'longitude': 148.126,
#               'surface_temperature_celcius': 69.0}}
# {'hotspots': {'latitude': -37.436,
#               'longitude': 148.088,
#               'surface_temperature_celcius': 76.0}}
# {'hotspots': {'latitude': -37.444,
#               'longitude': 148.101,
#               'surface_temperature_celcius': 66.0}}
# {'hotspots': {'latitude': -37.562,
#               'longitude': 148.05,
#               'surface_temperature_celcius': 72.0}}
# {'hotspots': {'latitude': -37.462,
#               'longitude': 148.089,
#               'surface_temperature_celcius': 90.0}}
# {'hotspots': {'latitude': -37.46,
#               'longitude': 148.102,
#               'surface_temperature_celcius': 65.0}}
# {'hotspots': {'latitude': -38.127,
#               'longitude': 143.82,
#               'surface_temperature_celcius': 77.0}}
# {'hotspots': {'latitude': -37.294,
#               'longitude': 141.232,
#               'surface_temperature_celcius': 87.0}}
# {'hotspots': {'latitude': -37.293,
#               'longitude': 141.245,
#               'surface_temperature_celcius': 85.0}}
# {'hotspots': {'latitude': -37.247,
#               'longitude': 141.278,
#               'surface_temperature_celcius': 68.0}}
# {'hotspots': {'latitude': -36.098,
#               'longitude': 143.74,
#               'surface_temperature_celcius': 67.0}}
# {'hotspots': {'latitude': -37.331,
#               'longitude': 143.122,
#               'surface_temperature_celcius': 65.0}}
# {'hotspots': {'latitude': -37.477,
#               'longitude': 143.352,
#               'surface_temperature_celcius': 93.0}}
# {'hotspots': {'latitude': -37.475,
#               'longitude': 143.365,
#               'surface_temperature_celcius': 77.0}}
# {'hotspots': {'latitude': -37.69,
#               'longitude': 143.605,
#               'surface_temperature_celcius': 80.0}}
# {'hotspots': {'latitude': -36.94,
#               'longitude': 143.281,
#               'surface_temperature_celcius': 69.0}}
# {'hotspots': {'latitude': -37.862,
#               'longitude': 144.175,
#               'surface_temperature_celcius': 65.0}}
# {'hotspots': {'latitude': -37.945,
#               'longitude': 144.354,
#               'surface_temperature_celcius': 73.0}}
# {'hotspots': {'latitude': -37.606,
#               'longitude': 149.312,
#               'surface_temperature_celcius': 87.0}}
# {'hotspots': {'latitude': -37.61,
#               'longitude': 149.307,
#               'surface_temperature_celcius': 80.0}}
# {'hotspots': {'latitude': -37.609,
#               'longitude': 149.32,
#               'surface_temperature_celcius': 84.0}}
# {'hotspots': {'latitude': -37.642,
#               'longitude': 149.263,
#               'surface_temperature_celcius': 65.0}}
# {'hotspots': {'latitude': -37.634,
#               'longitude': 149.237,
#               'surface_temperature_celcius': 71.0}}
# {'hotspots': {'latitude': -37.605,
#               'longitude': 149.302,
#               'surface_temperature_celcius': 83.0}}
# {'hotspots': {'latitude': -37.6,
#               'longitude': 149.325,
#               'surface_temperature_celcius': 86.0}}
# {'hotspots': {'latitude': -37.618,
#               'longitude': 149.281,
#               'surface_temperature_celcius': 76.0}}
# {'hotspots': {'latitude': -36.282,
#               'longitude': 146.157,
#               'surface_temperature_celcius': 71.0}}
# {'hotspots': {'latitude': -37.95,
#               'longitude': 142.366,
#               'surface_temperature_celcius': 70.0}}
# {'hotspots': {'latitude': -37.875,
#               'longitude': 142.51,
#               'surface_temperature_celcius': 73.0}}
# {'hotspots': {'latitude': -37.613,
#               'longitude': 149.305,
#               'surface_temperature_celcius': 75.0}}
# {'hotspots': {'latitude': -37.624,
#               'longitude': 149.314,
#               'surface_temperature_celcius': 66.0}}
# {'hotspots': {'latitude': -38.057,
#               'longitude': 144.211,
#               'surface_temperature_celcius': 73.0}}
# {'hotspots': {'latitude': -37.966,
#               'longitude': 145.051,
#               'surface_temperature_celcius': 68.0}}
# {'hotspots': {'latitude': -35.543,
#               'longitude': 143.316,
#               'surface_temperature_celcius': 67.0}}

# %% [markdown]
# C. Find date, surface temperature, air temperature, relative humidity and max wind speed on 15th and 16th of December 2018.

# %%
result = collection.find({'date': {'$in': [datetime(2018, 12, 15), datetime(2018, 12, 16)]}}, {
    '_id': 0, 'date': 1, 'hotspots.surface_temperature_celcius': 1, 'air_temperature_celcius': 1, 'relative_humidity': 1, 'max_wind_speed': 1})

for each in result:
    pprint(each)
# Out:
# {'air_temperature_celcius': 18.0,
#  'date': datetime.datetime(2018, 12, 15, 0, 0),
#  'hotspots': [{'surface_temperature_celcius': 42.0},
#               {'surface_temperature_celcius': 36.0},
#               {'surface_temperature_celcius': 38.0},
#               {'surface_temperature_celcius': 40.0}],
#  'max_wind_speed': 14.0,
#  'relative_humidity': 52.0}
# {'air_temperature_celcius': 18.0,
#  'date': datetime.datetime(2018, 12, 16, 0, 0),
#  'hotspots': [{'surface_temperature_celcius': 43.0},
#               {'surface_temperature_celcius': 33.0},
#               {'surface_temperature_celcius': 54.0},
#               {'surface_temperature_celcius': 73.0},
#               {'surface_temperature_celcius': 55.0},
#               {'surface_temperature_celcius': 75.0},
#               {'surface_temperature_celcius': 55.0},
#               {'surface_temperature_celcius': 66.0},
#               {'surface_temperature_celcius': 56.0},
#               {'surface_temperature_celcius': 60.0},
#               {'surface_temperature_celcius': 73.0},
#               {'surface_temperature_celcius': 48.0},
#               {'surface_temperature_celcius': 55.0},
#               {'surface_temperature_celcius': 64.0},
#               {'surface_temperature_celcius': 57.0}],
#  'max_wind_speed': 13.0,
#  'relative_humidity': 53.7}

# %% [markdown]
# D. Find datetime, air temperature, surface temperature and confidence when the confidence is between 80 and 100.

# %%
result = collection.aggregate([{'$unwind': '$hotspots'}, {'$match': {'hotspots.confidence': {'$gte': 80, '$lte': 100}}}, {
    '$project': {'_id': 0, 'hotspots.time': 1, 'air_temperature_celcius': 1, 'hotspots.surface_temperature_celcius': 1, 'hotspots.confidence': 1}}])

for each in result:
    pprint(each)
# Out:
# {'air_temperature_celcius': 20.0,
#  'hotspots': {'confidence': 87.0,
#               'surface_temperature_celcius': 62.0,
#               'time': datetime.datetime(2018, 3, 6, 5, 6, 30)}}
# {'air_temperature_celcius': 20.0,
#  'hotspots': {'confidence': 85.0,
#               'surface_temperature_celcius': 59.0,
#               'time': datetime.datetime(2018, 3, 6, 5, 6, 20)}}
# {'air_temperature_celcius': 19.0,
#  'hotspots': {'confidence': 88.0,
#               'surface_temperature_celcius': 64.0,
#               'time': datetime.datetime(2018, 3, 7, 4, 16, 10)}}
# {'air_temperature_celcius': 23.0,
#  'hotspots': {'confidence': 86.0,
#               'surface_temperature_celcius': 41.0,
#               'time': datetime.datetime(2018, 3, 9, 13, 23, 40)}}
# {'air_temperature_celcius': 19.0,
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 105.0,
#               'time': datetime.datetime(2018, 3, 10, 4, 48, 40)}}
# {'air_temperature_celcius': 19.0,
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 109.0,
#               'time': datetime.datetime(2018, 3, 10, 4, 46, 20)}}
# {'air_temperature_celcius': 19.0,
#  'hotspots': {'confidence': 94.0,
#               'surface_temperature_celcius': 73.0,
#               'time': datetime.datetime(2018, 3, 10, 4, 45, 30)}}
# {'air_temperature_celcius': 19.0,
#  'hotspots': {'confidence': 97.0,
#               'surface_temperature_celcius': 80.0,
#               'time': datetime.datetime(2018, 3, 10, 4, 45, 30)}}
# {'air_temperature_celcius': 19.0,
#  'hotspots': {'confidence': 81.0,
#               'surface_temperature_celcius': 55.0,
#               'time': datetime.datetime(2018, 3, 10, 4, 43, 50)}}
# {'air_temperature_celcius': 21.0,
#  'hotspots': {'confidence': 94.0,
#               'surface_temperature_celcius': 105.0,
#               'time': datetime.datetime(2018, 3, 12, 4, 33, 50)}}
# {'air_temperature_celcius': 21.0,
#  'hotspots': {'confidence': 84.0,
#               'surface_temperature_celcius': 71.0,
#               'time': datetime.datetime(2018, 3, 12, 4, 29, 50)}}
# {'air_temperature_celcius': 21.0,
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 99.0,
#               'time': datetime.datetime(2018, 3, 12, 4, 28, 20)}}
# {'air_temperature_celcius': 21.0,
#  'hotspots': {'confidence': 80.0,
#               'surface_temperature_celcius': 68.0,
#               'time': datetime.datetime(2018, 3, 12, 4, 28)}}
# {'air_temperature_celcius': 21.0,
#  'hotspots': {'confidence': 85.0,
#               'surface_temperature_celcius': 98.0,
#               'time': datetime.datetime(2018, 3, 12, 4, 27, 20)}}
# {'air_temperature_celcius': 25.0,
#  'hotspots': {'confidence': 90.0,
#               'surface_temperature_celcius': 67.0,
#               'time': datetime.datetime(2018, 3, 14, 4, 24, 40)}}
# {'air_temperature_celcius': 25.0,
#  'hotspots': {'confidence': 93.0,
#               'surface_temperature_celcius': 72.0,
#               'time': datetime.datetime(2018, 3, 14, 4, 22, 20)}}
# {'air_temperature_celcius': 25.0,
#  'hotspots': {'confidence': 90.0,
#               'surface_temperature_celcius': 68.0,
#               'time': datetime.datetime(2018, 3, 14, 4, 20, 50)}}
# {'air_temperature_celcius': 25.0,
#  'hotspots': {'confidence': 95.0,
#               'surface_temperature_celcius': 75.0,
#               'time': datetime.datetime(2018, 3, 14, 4, 16, 30)}}
# {'air_temperature_celcius': 25.0,
#  'hotspots': {'confidence': 89.0,
#               'surface_temperature_celcius': 65.0,
#               'time': datetime.datetime(2018, 3, 14, 4, 16, 20)}}
# {'air_temperature_celcius': 25.0,
#  'hotspots': {'confidence': 81.0,
#               'surface_temperature_celcius': 55.0,
#               'time': datetime.datetime(2018, 3, 14, 4, 14, 40)}}
# {'air_temperature_celcius': 25.0,
#  'hotspots': {'confidence': 96.0,
#               'surface_temperature_celcius': 79.0,
#               'time': datetime.datetime(2018, 3, 14, 4, 14, 30)}}
# {'air_temperature_celcius': 25.0,
#  'hotspots': {'confidence': 94.0,
#               'surface_temperature_celcius': 75.0,
#               'time': datetime.datetime(2018, 3, 14, 4, 14, 30)}}
# {'air_temperature_celcius': 18.0,
#  'hotspots': {'confidence': 94.0,
#               'surface_temperature_celcius': 74.0,
#               'time': datetime.datetime(2018, 3, 17, 4, 48, 20)}}
# {'air_temperature_celcius': 18.0,
#  'hotspots': {'confidence': 84.0,
#               'surface_temperature_celcius': 59.0,
#               'time': datetime.datetime(2018, 3, 17, 4, 45, 10)}}
# {'air_temperature_celcius': 18.0,
#  'hotspots': {'confidence': 86.0,
#               'surface_temperature_celcius': 60.0,
#               'time': datetime.datetime(2018, 3, 17, 4, 45)}}
# {'air_temperature_celcius': 21.0,
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 121.0,
#               'time': datetime.datetime(2018, 3, 18, 3, 50, 50)}}
# {'air_temperature_celcius': 21.0,
#  'hotspots': {'confidence': 97.0,
#               'surface_temperature_celcius': 80.0,
#               'time': datetime.datetime(2018, 3, 18, 3, 50, 40)}}
# {'air_temperature_celcius': 24.0,
#  'hotspots': {'confidence': 85.0,
#               'surface_temperature_celcius': 60.0,
#               'time': datetime.datetime(2018, 3, 19, 4, 39, 50)}}
# {'air_temperature_celcius': 24.0,
#  'hotspots': {'confidence': 96.0,
#               'surface_temperature_celcius': 79.0,
#               'time': datetime.datetime(2018, 3, 19, 4, 39, 20)}}
# {'air_temperature_celcius': 24.0,
#  'hotspots': {'confidence': 90.0,
#               'surface_temperature_celcius': 66.0,
#               'time': datetime.datetime(2018, 3, 19, 4, 36)}}
# {'air_temperature_celcius': 24.0,
#  'hotspots': {'confidence': 98.0,
#               'surface_temperature_celcius': 83.0,
#               'time': datetime.datetime(2018, 3, 19, 4, 33)}}
# {'air_temperature_celcius': 24.0,
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 91.0,
#               'time': datetime.datetime(2018, 3, 19, 4, 32, 50)}}
# {'air_temperature_celcius': 24.0,
#  'hotspots': {'confidence': 84.0,
#               'surface_temperature_celcius': 58.0,
#               'time': datetime.datetime(2018, 3, 19, 4, 32, 50)}}
# {'air_temperature_celcius': 24.0,
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 113.0,
#               'time': datetime.datetime(2018, 3, 19, 4, 32, 40)}}
# {'air_temperature_celcius': 24.0,
#  'hotspots': {'confidence': 92.0,
#               'surface_temperature_celcius': 70.0,
#               'time': datetime.datetime(2018, 3, 19, 4, 32, 40)}}
# {'air_temperature_celcius': 24.0,
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 106.0,
#               'time': datetime.datetime(2018, 3, 19, 4, 32, 40)}}
# {'air_temperature_celcius': 23.0,
#  'hotspots': {'confidence': 82.0,
#               'surface_temperature_celcius': 65.0,
#               'time': datetime.datetime(2018, 3, 25, 3, 59, 50)}}
# {'air_temperature_celcius': 23.0,
#  'hotspots': {'confidence': 87.0,
#               'surface_temperature_celcius': 62.0,
#               'time': datetime.datetime(2018, 3, 25, 3, 58, 10)}}
# {'air_temperature_celcius': 23.0,
#  'hotspots': {'confidence': 95.0,
#               'surface_temperature_celcius': 75.0,
#               'time': datetime.datetime(2018, 3, 25, 3, 58, 10)}}
# {'air_temperature_celcius': 23.0,
#  'hotspots': {'confidence': 85.0,
#               'surface_temperature_celcius': 59.0,
#               'time': datetime.datetime(2018, 3, 25, 3, 57, 10)}}
# {'air_temperature_celcius': 23.0,
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 111.0,
#               'time': datetime.datetime(2018, 3, 25, 3, 57, 10)}}
# {'air_temperature_celcius': 23.0,
#  'hotspots': {'confidence': 95.0,
#               'surface_temperature_celcius': 77.0,
#               'time': datetime.datetime(2018, 3, 25, 3, 57, 10)}}
# {'air_temperature_celcius': 23.0,
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 99.0,
#               'time': datetime.datetime(2018, 3, 25, 3, 56, 40)}}
# {'air_temperature_celcius': 23.0,
#  'hotspots': {'confidence': 81.0,
#               'surface_temperature_celcius': 54.0,
#               'time': datetime.datetime(2018, 3, 26, 4, 43, 20)}}
# {'air_temperature_celcius': 23.0,
#  'hotspots': {'confidence': 80.0,
#               'surface_temperature_celcius': 53.0,
#               'time': datetime.datetime(2018, 3, 26, 4, 40, 50)}}
# {'air_temperature_celcius': 23.0,
#  'hotspots': {'confidence': 81.0,
#               'surface_temperature_celcius': 54.0,
#               'time': datetime.datetime(2018, 3, 26, 4, 39, 50)}}
# {'air_temperature_celcius': 23.0,
#  'hotspots': {'confidence': 91.0,
#               'surface_temperature_celcius': 68.0,
#               'time': datetime.datetime(2018, 3, 26, 4, 39, 10)}}
# {'air_temperature_celcius': 23.0,
#  'hotspots': {'confidence': 92.0,
#               'surface_temperature_celcius': 70.0,
#               'time': datetime.datetime(2018, 3, 26, 4, 39, 10)}}
# {'air_temperature_celcius': 23.0,
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 89.0,
#               'time': datetime.datetime(2018, 3, 26, 4, 39, 10)}}
# {'air_temperature_celcius': 23.0,
#  'hotspots': {'confidence': 82.0,
#               'surface_temperature_celcius': 55.0,
#               'time': datetime.datetime(2018, 3, 26, 4, 39, 10)}}
# {'air_temperature_celcius': 23.0,
#  'hotspots': {'confidence': 87.0,
#               'surface_temperature_celcius': 62.0,
#               'time': datetime.datetime(2018, 3, 26, 4, 39, 10)}}
# {'air_temperature_celcius': 23.0,
#  'hotspots': {'confidence': 84.0,
#               'surface_temperature_celcius': 58.0,
#               'time': datetime.datetime(2018, 3, 26, 4, 39, 10)}}
# {'air_temperature_celcius': 18.0,
#  'hotspots': {'confidence': 88.0,
#               'surface_temperature_celcius': 64.0,
#               'time': datetime.datetime(2018, 3, 28, 4, 38)}}
# {'air_temperature_celcius': 18.0,
#  'hotspots': {'confidence': 86.0,
#               'surface_temperature_celcius': 60.0,
#               'time': datetime.datetime(2018, 3, 28, 4, 33, 40)}}
# {'air_temperature_celcius': 18.0,
#  'hotspots': {'confidence': 92.0,
#               'surface_temperature_celcius': 71.0,
#               'time': datetime.datetime(2018, 3, 28, 4, 33, 30)}}
# {'air_temperature_celcius': 18.0,
#  'hotspots': {'confidence': 95.0,
#               'surface_temperature_celcius': 76.0,
#               'time': datetime.datetime(2018, 3, 28, 4, 33, 30)}}
# {'air_temperature_celcius': 18.0,
#  'hotspots': {'confidence': 93.0,
#               'surface_temperature_celcius': 73.0,
#               'time': datetime.datetime(2018, 3, 28, 4, 32, 20)}}
# {'air_temperature_celcius': 18.0,
#  'hotspots': {'confidence': 83.0,
#               'surface_temperature_celcius': 56.0,
#               'time': datetime.datetime(2018, 3, 28, 4, 30, 50)}}
# {'air_temperature_celcius': 18.0,
#  'hotspots': {'confidence': 80.0,
#               'surface_temperature_celcius': 54.0,
#               'time': datetime.datetime(2018, 3, 28, 4, 30, 20)}}
# {'air_temperature_celcius': 18.0,
#  'hotspots': {'confidence': 94.0,
#               'surface_temperature_celcius': 74.0,
#               'time': datetime.datetime(2018, 3, 28, 4, 30, 10)}}
# {'air_temperature_celcius': 18.0,
#  'hotspots': {'confidence': 98.0,
#               'surface_temperature_celcius': 82.0,
#               'time': datetime.datetime(2018, 3, 28, 4, 30, 10)}}
# {'air_temperature_celcius': 18.0,
#  'hotspots': {'confidence': 81.0,
#               'surface_temperature_celcius': 54.0,
#               'time': datetime.datetime(2018, 3, 28, 4, 30, 10)}}
# {'air_temperature_celcius': 18.0,
#  'hotspots': {'confidence': 97.0,
#               'surface_temperature_celcius': 80.0,
#               'time': datetime.datetime(2018, 3, 28, 4, 30, 10)}}
# {'air_temperature_celcius': 18.0,
#  'hotspots': {'confidence': 81.0,
#               'surface_temperature_celcius': 54.0,
#               'time': datetime.datetime(2018, 3, 28, 4, 28, 30)}}
# {'air_temperature_celcius': 18.0,
#  'hotspots': {'confidence': 88.0,
#               'surface_temperature_celcius': 63.0,
#               'time': datetime.datetime(2018, 3, 28, 4, 28, 30)}}
# {'air_temperature_celcius': 18.0,
#  'hotspots': {'confidence': 87.0,
#               'surface_temperature_celcius': 62.0,
#               'time': datetime.datetime(2018, 3, 28, 4, 28, 30)}}
# {'air_temperature_celcius': 18.0,
#  'hotspots': {'confidence': 97.0,
#               'surface_temperature_celcius': 80.0,
#               'time': datetime.datetime(2018, 3, 28, 4, 27, 40)}}
# {'air_temperature_celcius': 18.0,
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 107.0,
#               'time': datetime.datetime(2018, 3, 28, 4, 27, 20)}}
# {'air_temperature_celcius': 18.0,
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 108.0,
#               'time': datetime.datetime(2018, 3, 28, 4, 27, 10)}}
# {'air_temperature_celcius': 18.0,
#  'hotspots': {'confidence': 82.0,
#               'surface_temperature_celcius': 55.0,
#               'time': datetime.datetime(2018, 3, 28, 4, 27)}}
# {'air_temperature_celcius': 18.0,
#  'hotspots': {'confidence': 99.0,
#               'surface_temperature_celcius': 86.0,
#               'time': datetime.datetime(2018, 3, 28, 4, 27)}}
# {'air_temperature_celcius': 18.0,
#  'hotspots': {'confidence': 81.0,
#               'surface_temperature_celcius': 55.0,
#               'time': datetime.datetime(2018, 3, 28, 4, 26, 50)}}
# {'air_temperature_celcius': 18.0,
#  'hotspots': {'confidence': 80.0,
#               'surface_temperature_celcius': 53.0,
#               'time': datetime.datetime(2018, 3, 28, 4, 26, 50)}}
# {'air_temperature_celcius': 18.0,
#  'hotspots': {'confidence': 83.0,
#               'surface_temperature_celcius': 57.0,
#               'time': datetime.datetime(2018, 3, 28, 4, 26, 50)}}
# {'air_temperature_celcius': 18.0,
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 90.0,
#               'time': datetime.datetime(2018, 3, 28, 4, 26, 50)}}
# {'air_temperature_celcius': 18.0,
#  'hotspots': {'confidence': 87.0,
#               'surface_temperature_celcius': 62.0,
#               'time': datetime.datetime(2018, 3, 28, 4, 26, 50)}}
# {'air_temperature_celcius': 18.0,
#  'hotspots': {'confidence': 97.0,
#               'surface_temperature_celcius': 81.0,
#               'time': datetime.datetime(2018, 3, 28, 4, 26, 50)}}
# {'air_temperature_celcius': 18.0,
#  'hotspots': {'confidence': 85.0,
#               'surface_temperature_celcius': 59.0,
#               'time': datetime.datetime(2018, 3, 28, 4, 26, 50)}}
# {'air_temperature_celcius': 18.0,
#  'hotspots': {'confidence': 88.0,
#               'surface_temperature_celcius': 63.0,
#               'time': datetime.datetime(2018, 3, 28, 4, 26, 50)}}
# {'air_temperature_celcius': 18.0,
#  'hotspots': {'confidence': 87.0,
#               'surface_temperature_celcius': 62.0,
#               'time': datetime.datetime(2018, 3, 28, 4, 26, 50)}}
# {'air_temperature_celcius': 18.0,
#  'hotspots': {'confidence': 84.0,
#               'surface_temperature_celcius': 58.0,
#               'time': datetime.datetime(2018, 3, 28, 4, 26, 50)}}
# {'air_temperature_celcius': 18.0,
#  'hotspots': {'confidence': 97.0,
#               'surface_temperature_celcius': 81.0,
#               'time': datetime.datetime(2018, 3, 28, 4, 26, 50)}}
# {'air_temperature_celcius': 18.0,
#  'hotspots': {'confidence': 83.0,
#               'surface_temperature_celcius': 57.0,
#               'time': datetime.datetime(2018, 3, 28, 4, 26, 50)}}
# {'air_temperature_celcius': 18.0,
#  'hotspots': {'confidence': 85.0,
#               'surface_temperature_celcius': 60.0,
#               'time': datetime.datetime(2018, 3, 28, 4, 26, 50)}}
# {'air_temperature_celcius': 14.0,
#  'hotspots': {'confidence': 82.0,
#               'surface_temperature_celcius': 55.0,
#               'time': datetime.datetime(2018, 3, 31, 5, 7, 10)}}
# {'air_temperature_celcius': 14.0,
#  'hotspots': {'confidence': 87.0,
#               'surface_temperature_celcius': 62.0,
#               'time': datetime.datetime(2018, 3, 31, 5, 1, 20)}}
# {'air_temperature_celcius': 14.0,
#  'hotspots': {'confidence': 82.0,
#               'surface_temperature_celcius': 56.0,
#               'time': datetime.datetime(2018, 3, 31, 4, 58, 30)}}
# {'air_temperature_celcius': 14.0,
#  'hotspots': {'confidence': 80.0,
#               'surface_temperature_celcius': 53.0,
#               'time': datetime.datetime(2018, 3, 31, 4, 58)}}
# {'air_temperature_celcius': 14.0,
#  'hotspots': {'confidence': 86.0,
#               'surface_temperature_celcius': 61.0,
#               'time': datetime.datetime(2018, 3, 31, 4, 57, 10)}}
# {'air_temperature_celcius': 14.0,
#  'hotspots': {'confidence': 81.0,
#               'surface_temperature_celcius': 54.0,
#               'time': datetime.datetime(2018, 3, 31, 0, 36, 30)}}
# {'air_temperature_celcius': 15.0,
#  'hotspots': {'confidence': 91.0,
#               'surface_temperature_celcius': 43.0,
#               'time': datetime.datetime(2018, 4, 3, 13, 17)}}
# {'air_temperature_celcius': 15.0,
#  'hotspots': {'confidence': 83.0,
#               'surface_temperature_celcius': 40.0,
#               'time': datetime.datetime(2018, 4, 3, 13, 15, 30)}}
# {'air_temperature_celcius': 15.0,
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 62.0,
#               'time': datetime.datetime(2018, 4, 3, 13, 15, 10)}}
# {'air_temperature_celcius': 15.0,
#  'hotspots': {'confidence': 96.0,
#               'surface_temperature_celcius': 45.0,
#               'time': datetime.datetime(2018, 4, 3, 13, 15, 10)}}
# {'air_temperature_celcius': 15.0,
#  'hotspots': {'confidence': 87.0,
#               'surface_temperature_celcius': 96.0,
#               'time': datetime.datetime(2018, 4, 3, 3, 59, 10)}}
# {'air_temperature_celcius': 15.0,
#  'hotspots': {'confidence': 93.0,
#               'surface_temperature_celcius': 72.0,
#               'time': datetime.datetime(2018, 4, 3, 3, 57, 50)}}
# {'air_temperature_celcius': 15.0,
#  'hotspots': {'confidence': 82.0,
#               'surface_temperature_celcius': 55.0,
#               'time': datetime.datetime(2018, 4, 3, 3, 56, 20)}}
# {'air_temperature_celcius': 15.0,
#  'hotspots': {'confidence': 88.0,
#               'surface_temperature_celcius': 64.0,
#               'time': datetime.datetime(2018, 4, 3, 3, 55, 10)}}
# {'air_temperature_celcius': 15.0,
#  'hotspots': {'confidence': 95.0,
#               'surface_temperature_celcius': 77.0,
#               'time': datetime.datetime(2018, 4, 3, 3, 55, 10)}}
# {'air_temperature_celcius': 15.0,
#  'hotspots': {'confidence': 96.0,
#               'surface_temperature_celcius': 78.0,
#               'time': datetime.datetime(2018, 4, 3, 3, 54)}}
# {'air_temperature_celcius': 15.0,
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 93.0,
#               'time': datetime.datetime(2018, 4, 3, 3, 53, 50)}}
# {'air_temperature_celcius': 15.0,
#  'hotspots': {'confidence': 85.0,
#               'surface_temperature_celcius': 59.0,
#               'time': datetime.datetime(2018, 4, 3, 3, 53, 30)}}
# {'air_temperature_celcius': 15.0,
#  'hotspots': {'confidence': 84.0,
#               'surface_temperature_celcius': 58.0,
#               'time': datetime.datetime(2018, 4, 3, 3, 52, 30)}}
# {'air_temperature_celcius': 15.0,
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 90.0,
#               'time': datetime.datetime(2018, 4, 3, 3, 52, 30)}}
# {'air_temperature_celcius': 15.0,
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 115.0,
#               'time': datetime.datetime(2018, 4, 3, 3, 52, 20)}}
# {'air_temperature_celcius': 15.0,
#  'hotspots': {'confidence': 86.0,
#               'surface_temperature_celcius': 61.0,
#               'time': datetime.datetime(2018, 4, 3, 3, 52, 10)}}
# {'air_temperature_celcius': 15.0,
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 98.0,
#               'time': datetime.datetime(2018, 4, 3, 3, 52, 10)}}
# {'air_temperature_celcius': 15.0,
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 89.0,
#               'time': datetime.datetime(2018, 4, 3, 3, 52, 10)}}
# {'air_temperature_celcius': 15.0,
#  'hotspots': {'confidence': 85.0,
#               'surface_temperature_celcius': 59.0,
#               'time': datetime.datetime(2018, 4, 3, 3, 52, 10)}}
# {'air_temperature_celcius': 15.0,
#  'hotspots': {'confidence': 83.0,
#               'surface_temperature_celcius': 63.0,
#               'time': datetime.datetime(2018, 4, 3, 3, 51, 30)}}
# {'air_temperature_celcius': 15.0,
#  'hotspots': {'confidence': 89.0,
#               'surface_temperature_celcius': 66.0,
#               'time': datetime.datetime(2018, 4, 3, 3, 51, 30)}}
# {'air_temperature_celcius': 15.0,
#  'hotspots': {'confidence': 87.0,
#               'surface_temperature_celcius': 62.0,
#               'time': datetime.datetime(2018, 4, 3, 3, 51, 10)}}
# {'air_temperature_celcius': 15.0,
#  'hotspots': {'confidence': 81.0,
#               'surface_temperature_celcius': 54.0,
#               'time': datetime.datetime(2018, 4, 3, 3, 51)}}
# {'air_temperature_celcius': 15.0,
#  'hotspots': {'confidence': 98.0,
#               'surface_temperature_celcius': 82.0,
#               'time': datetime.datetime(2018, 4, 3, 3, 51)}}
# {'air_temperature_celcius': 15.0,
#  'hotspots': {'confidence': 80.0,
#               'surface_temperature_celcius': 53.0,
#               'time': datetime.datetime(2018, 4, 3, 3, 51)}}
# {'air_temperature_celcius': 15.0,
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 103.0,
#               'time': datetime.datetime(2018, 4, 3, 3, 51)}}
# {'air_temperature_celcius': 15.0,
#  'hotspots': {'confidence': 87.0,
#               'surface_temperature_celcius': 97.0,
#               'time': datetime.datetime(2018, 4, 3, 3, 50, 50)}}
# {'air_temperature_celcius': 15.0,
#  'hotspots': {'confidence': 90.0,
#               'surface_temperature_celcius': 66.0,
#               'time': datetime.datetime(2018, 4, 3, 3, 50, 50)}}
# {'air_temperature_celcius': 15.0,
#  'hotspots': {'confidence': 85.0,
#               'surface_temperature_celcius': 61.0,
#               'time': datetime.datetime(2018, 4, 3, 3, 50, 40)}}
# {'air_temperature_celcius': 15.0,
#  'hotspots': {'confidence': 99.0,
#               'surface_temperature_celcius': 86.0,
#               'time': datetime.datetime(2018, 4, 3, 3, 50, 40)}}
# {'air_temperature_celcius': 15.0,
#  'hotspots': {'confidence': 93.0,
#               'surface_temperature_celcius': 72.0,
#               'time': datetime.datetime(2018, 4, 3, 3, 50, 40)}}
# {'air_temperature_celcius': 15.0,
#  'hotspots': {'confidence': 95.0,
#               'surface_temperature_celcius': 76.0,
#               'time': datetime.datetime(2018, 4, 3, 3, 50, 40)}}
# {'air_temperature_celcius': 15.0,
#  'hotspots': {'confidence': 86.0,
#               'surface_temperature_celcius': 60.0,
#               'time': datetime.datetime(2018, 4, 3, 3, 50, 40)}}
# {'air_temperature_celcius': 15.0,
#  'hotspots': {'confidence': 89.0,
#               'surface_temperature_celcius': 65.0,
#               'time': datetime.datetime(2018, 4, 3, 3, 50, 40)}}
# {'air_temperature_celcius': 15.0,
#  'hotspots': {'confidence': 82.0,
#               'surface_temperature_celcius': 55.0,
#               'time': datetime.datetime(2018, 4, 3, 3, 50, 40)}}
# {'air_temperature_celcius': 15.0,
#  'hotspots': {'confidence': 89.0,
#               'surface_temperature_celcius': 65.0,
#               'time': datetime.datetime(2018, 4, 3, 3, 50, 40)}}
# {'air_temperature_celcius': 15.0,
#  'hotspots': {'confidence': 81.0,
#               'surface_temperature_celcius': 54.0,
#               'time': datetime.datetime(2018, 4, 3, 1, 7, 20)}}
# {'air_temperature_celcius': 16.0,
#  'hotspots': {'confidence': 93.0,
#               'surface_temperature_celcius': 44.0,
#               'time': datetime.datetime(2018, 4, 4, 15, 31)}}
# {'air_temperature_celcius': 16.0,
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 64.0,
#               'time': datetime.datetime(2018, 4, 4, 15, 30, 40)}}
# {'air_temperature_celcius': 16.0,
#  'hotspots': {'confidence': 88.0,
#               'surface_temperature_celcius': 63.0,
#               'time': datetime.datetime(2018, 4, 4, 4, 41, 50)}}
# {'air_temperature_celcius': 16.0,
#  'hotspots': {'confidence': 82.0,
#               'surface_temperature_celcius': 62.0,
#               'time': datetime.datetime(2018, 4, 4, 4, 41, 10)}}
# {'air_temperature_celcius': 16.0,
#  'hotspots': {'confidence': 88.0,
#               'surface_temperature_celcius': 64.0,
#               'time': datetime.datetime(2018, 4, 4, 4, 41)}}
# {'air_temperature_celcius': 16.0,
#  'hotspots': {'confidence': 86.0,
#               'surface_temperature_celcius': 61.0,
#               'time': datetime.datetime(2018, 4, 4, 4, 41)}}
# {'air_temperature_celcius': 16.0,
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 120.0,
#               'time': datetime.datetime(2018, 4, 4, 4, 40)}}
# {'air_temperature_celcius': 16.0,
#  'hotspots': {'confidence': 90.0,
#               'surface_temperature_celcius': 67.0,
#               'time': datetime.datetime(2018, 4, 4, 4, 39, 50)}}
# {'air_temperature_celcius': 16.0,
#  'hotspots': {'confidence': 85.0,
#               'surface_temperature_celcius': 66.0,
#               'time': datetime.datetime(2018, 4, 4, 4, 39, 50)}}
# {'air_temperature_celcius': 16.0,
#  'hotspots': {'confidence': 90.0,
#               'surface_temperature_celcius': 66.0,
#               'time': datetime.datetime(2018, 4, 4, 4, 39, 40)}}
# {'air_temperature_celcius': 16.0,
#  'hotspots': {'confidence': 81.0,
#               'surface_temperature_celcius': 54.0,
#               'time': datetime.datetime(2018, 4, 4, 4, 39, 40)}}
# {'air_temperature_celcius': 16.0,
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 107.0,
#               'time': datetime.datetime(2018, 4, 4, 4, 39, 20)}}
# {'air_temperature_celcius': 16.0,
#  'hotspots': {'confidence': 88.0,
#               'surface_temperature_celcius': 64.0,
#               'time': datetime.datetime(2018, 4, 4, 4, 37, 10)}}
# {'air_temperature_celcius': 16.0,
#  'hotspots': {'confidence': 88.0,
#               'surface_temperature_celcius': 63.0,
#               'time': datetime.datetime(2018, 4, 4, 4, 36, 10)}}
# {'air_temperature_celcius': 16.0,
#  'hotspots': {'confidence': 87.0,
#               'surface_temperature_celcius': 62.0,
#               'time': datetime.datetime(2018, 4, 4, 4, 36, 10)}}
# {'air_temperature_celcius': 16.0,
#  'hotspots': {'confidence': 90.0,
#               'surface_temperature_celcius': 76.0,
#               'time': datetime.datetime(2018, 4, 4, 4, 36)}}
# {'air_temperature_celcius': 16.0,
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 95.0,
#               'time': datetime.datetime(2018, 4, 4, 4, 35)}}
# {'air_temperature_celcius': 16.0,
#  'hotspots': {'confidence': 83.0,
#               'surface_temperature_celcius': 57.0,
#               'time': datetime.datetime(2018, 4, 4, 4, 34, 50)}}
# {'air_temperature_celcius': 16.0,
#  'hotspots': {'confidence': 89.0,
#               'surface_temperature_celcius': 65.0,
#               'time': datetime.datetime(2018, 4, 4, 4, 34, 20)}}
# {'air_temperature_celcius': 16.0,
#  'hotspots': {'confidence': 96.0,
#               'surface_temperature_celcius': 78.0,
#               'time': datetime.datetime(2018, 4, 4, 4, 34, 20)}}
# {'air_temperature_celcius': 16.0,
#  'hotspots': {'confidence': 85.0,
#               'surface_temperature_celcius': 66.0,
#               'time': datetime.datetime(2018, 4, 4, 4, 34, 20)}}
# {'air_temperature_celcius': 16.0,
#  'hotspots': {'confidence': 84.0,
#               'surface_temperature_celcius': 57.0,
#               'time': datetime.datetime(2018, 4, 4, 4, 34)}}
# {'air_temperature_celcius': 16.0,
#  'hotspots': {'confidence': 92.0,
#               'surface_temperature_celcius': 81.0,
#               'time': datetime.datetime(2018, 4, 4, 4, 33, 50)}}
# {'air_temperature_celcius': 16.0,
#  'hotspots': {'confidence': 81.0,
#               'surface_temperature_celcius': 54.0,
#               'time': datetime.datetime(2018, 4, 4, 4, 33, 40)}}
# {'air_temperature_celcius': 16.0,
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 113.0,
#               'time': datetime.datetime(2018, 4, 4, 4, 33, 30)}}
# {'air_temperature_celcius': 16.0,
#  'hotspots': {'confidence': 80.0,
#               'surface_temperature_celcius': 58.0,
#               'time': datetime.datetime(2018, 4, 4, 4, 33, 30)}}
# {'air_temperature_celcius': 16.0,
#  'hotspots': {'confidence': 85.0,
#               'surface_temperature_celcius': 59.0,
#               'time': datetime.datetime(2018, 4, 4, 4, 33, 30)}}
# {'air_temperature_celcius': 16.0,
#  'hotspots': {'confidence': 82.0,
#               'surface_temperature_celcius': 62.0,
#               'time': datetime.datetime(2018, 4, 4, 4, 33, 10)}}
# {'air_temperature_celcius': 16.0,
#  'hotspots': {'confidence': 82.0,
#               'surface_temperature_celcius': 62.0,
#               'time': datetime.datetime(2018, 4, 4, 4, 33, 10)}}
# {'air_temperature_celcius': 16.0,
#  'hotspots': {'confidence': 97.0,
#               'surface_temperature_celcius': 79.0,
#               'time': datetime.datetime(2018, 4, 4, 4, 33)}}
# {'air_temperature_celcius': 16.0,
#  'hotspots': {'confidence': 86.0,
#               'surface_temperature_celcius': 61.0,
#               'time': datetime.datetime(2018, 4, 4, 4, 33)}}
# {'air_temperature_celcius': 16.0,
#  'hotspots': {'confidence': 98.0,
#               'surface_temperature_celcius': 82.0,
#               'time': datetime.datetime(2018, 4, 4, 4, 32, 50)}}
# {'air_temperature_celcius': 16.0,
#  'hotspots': {'confidence': 85.0,
#               'surface_temperature_celcius': 61.0,
#               'time': datetime.datetime(2018, 4, 4, 4, 32, 50)}}
# {'air_temperature_celcius': 16.0,
#  'hotspots': {'confidence': 84.0,
#               'surface_temperature_celcius': 58.0,
#               'time': datetime.datetime(2018, 4, 4, 4, 32, 50)}}
# {'air_temperature_celcius': 16.0,
#  'hotspots': {'confidence': 82.0,
#               'surface_temperature_celcius': 55.0,
#               'time': datetime.datetime(2018, 4, 4, 4, 32, 50)}}
# {'air_temperature_celcius': 16.0,
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 123.0,
#               'time': datetime.datetime(2018, 4, 4, 4, 32, 50)}}
# {'air_temperature_celcius': 16.0,
#  'hotspots': {'confidence': 82.0,
#               'surface_temperature_celcius': 55.0,
#               'time': datetime.datetime(2018, 4, 4, 4, 32, 50)}}
# {'air_temperature_celcius': 16.0,
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 118.0,
#               'time': datetime.datetime(2018, 4, 4, 4, 32, 50)}}
# {'air_temperature_celcius': 16.0,
#  'hotspots': {'confidence': 80.0,
#               'surface_temperature_celcius': 54.0,
#               'time': datetime.datetime(2018, 4, 4, 4, 32, 40)}}
# {'air_temperature_celcius': 16.0,
#  'hotspots': {'confidence': 96.0,
#               'surface_temperature_celcius': 78.0,
#               'time': datetime.datetime(2018, 4, 4, 4, 32, 40)}}
# {'air_temperature_celcius': 16.0,
#  'hotspots': {'confidence': 93.0,
#               'surface_temperature_celcius': 72.0,
#               'time': datetime.datetime(2018, 4, 4, 4, 32, 40)}}
# {'air_temperature_celcius': 16.0,
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 120.0,
#               'time': datetime.datetime(2018, 4, 4, 4, 32, 40)}}
# {'air_temperature_celcius': 16.0,
#  'hotspots': {'confidence': 87.0,
#               'surface_temperature_celcius': 92.0,
#               'time': datetime.datetime(2018, 4, 4, 4, 32, 40)}}
# {'air_temperature_celcius': 16.0,
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 101.0,
#               'time': datetime.datetime(2018, 4, 4, 4, 32, 40)}}
# {'air_temperature_celcius': 16.0,
#  'hotspots': {'confidence': 81.0,
#               'surface_temperature_celcius': 54.0,
#               'time': datetime.datetime(2018, 4, 4, 4, 32, 40)}}
# {'air_temperature_celcius': 16.0,
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 98.0,
#               'time': datetime.datetime(2018, 4, 4, 4, 32, 40)}}
# {'air_temperature_celcius': 16.0,
#  'hotspots': {'confidence': 80.0,
#               'surface_temperature_celcius': 53.0,
#               'time': datetime.datetime(2018, 4, 4, 0, 12, 50)}}
# {'air_temperature_celcius': 17.0,
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 58.0,
#               'time': datetime.datetime(2018, 4, 5, 13, 9)}}
# {'air_temperature_celcius': 17.0,
#  'hotspots': {'confidence': 81.0,
#               'surface_temperature_celcius': 39.0,
#               'time': datetime.datetime(2018, 4, 5, 13, 9)}}
# {'air_temperature_celcius': 17.0,
#  'hotspots': {'confidence': 93.0,
#               'surface_temperature_celcius': 44.0,
#               'time': datetime.datetime(2018, 4, 5, 13, 8, 40)}}
# {'air_temperature_celcius': 17.0,
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 47.0,
#               'time': datetime.datetime(2018, 4, 5, 13, 8, 40)}}
# {'air_temperature_celcius': 17.0,
#  'hotspots': {'confidence': 82.0,
#               'surface_temperature_celcius': 40.0,
#               'time': datetime.datetime(2018, 4, 5, 13, 7)}}
# {'air_temperature_celcius': 17.0,
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 49.0,
#               'time': datetime.datetime(2018, 4, 5, 13, 4, 20)}}
# {'air_temperature_celcius': 17.0,
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 55.0,
#               'time': datetime.datetime(2018, 4, 5, 13, 3, 20)}}
# {'air_temperature_celcius': 17.0,
#  'hotspots': {'confidence': 98.0,
#               'surface_temperature_celcius': 45.0,
#               'time': datetime.datetime(2018, 4, 5, 13, 3)}}
# {'air_temperature_celcius': 17.0,
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 55.0,
#               'time': datetime.datetime(2018, 4, 5, 13, 3)}}
# {'air_temperature_celcius': 17.0,
#  'hotspots': {'confidence': 81.0,
#               'surface_temperature_celcius': 39.0,
#               'time': datetime.datetime(2018, 4, 5, 13, 3)}}
# {'air_temperature_celcius': 17.0,
#  'hotspots': {'confidence': 88.0,
#               'surface_temperature_celcius': 42.0,
#               'time': datetime.datetime(2018, 4, 5, 13, 2, 40)}}
# {'air_temperature_celcius': 17.0,
#  'hotspots': {'confidence': 80.0,
#               'surface_temperature_celcius': 39.0,
#               'time': datetime.datetime(2018, 4, 5, 13, 2, 40)}}
# {'air_temperature_celcius': 17.0,
#  'hotspots': {'confidence': 87.0,
#               'surface_temperature_celcius': 88.0,
#               'time': datetime.datetime(2018, 4, 5, 5, 16, 50)}}
# {'air_temperature_celcius': 17.0,
#  'hotspots': {'confidence': 93.0,
#               'surface_temperature_celcius': 83.0,
#               'time': datetime.datetime(2018, 4, 5, 5, 15, 30)}}
# {'air_temperature_celcius': 17.0,
#  'hotspots': {'confidence': 93.0,
#               'surface_temperature_celcius': 72.0,
#               'time': datetime.datetime(2018, 4, 5, 3, 40, 50)}}
# {'air_temperature_celcius': 17.0,
#  'hotspots': {'confidence': 95.0,
#               'surface_temperature_celcius': 76.0,
#               'time': datetime.datetime(2018, 4, 5, 3, 40, 30)}}
# {'air_temperature_celcius': 17.0,
#  'hotspots': {'confidence': 81.0,
#               'surface_temperature_celcius': 54.0,
#               'time': datetime.datetime(2018, 4, 5, 3, 40, 20)}}
# {'air_temperature_celcius': 17.0,
#  'hotspots': {'confidence': 89.0,
#               'surface_temperature_celcius': 65.0,
#               'time': datetime.datetime(2018, 4, 5, 3, 39, 30)}}
# {'air_temperature_celcius': 17.0,
#  'hotspots': {'confidence': 82.0,
#               'surface_temperature_celcius': 62.0,
#               'time': datetime.datetime(2018, 4, 5, 3, 39, 30)}}
# {'air_temperature_celcius': 17.0,
#  'hotspots': {'confidence': 90.0,
#               'surface_temperature_celcius': 66.0,
#               'time': datetime.datetime(2018, 4, 5, 3, 39, 20)}}
# {'air_temperature_celcius': 17.0,
#  'hotspots': {'confidence': 83.0,
#               'surface_temperature_celcius': 56.0,
#               'time': datetime.datetime(2018, 4, 5, 3, 39, 20)}}
# {'air_temperature_celcius': 17.0,
#  'hotspots': {'confidence': 89.0,
#               'surface_temperature_celcius': 65.0,
#               'time': datetime.datetime(2018, 4, 5, 3, 39, 10)}}
# {'air_temperature_celcius': 17.0,
#  'hotspots': {'confidence': 83.0,
#               'surface_temperature_celcius': 64.0,
#               'time': datetime.datetime(2018, 4, 5, 3, 39, 10)}}
# {'air_temperature_celcius': 17.0,
#  'hotspots': {'confidence': 95.0,
#               'surface_temperature_celcius': 76.0,
#               'time': datetime.datetime(2018, 4, 5, 3, 39, 10)}}
# {'air_temperature_celcius': 17.0,
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 92.0,
#               'time': datetime.datetime(2018, 4, 5, 3, 39, 10)}}
# {'air_temperature_celcius': 17.0,
#  'hotspots': {'confidence': 88.0,
#               'surface_temperature_celcius': 63.0,
#               'time': datetime.datetime(2018, 4, 5, 3, 39, 10)}}
# {'air_temperature_celcius': 17.0,
#  'hotspots': {'confidence': 89.0,
#               'surface_temperature_celcius': 64.0,
#               'time': datetime.datetime(2018, 4, 5, 3, 39, 10)}}
# {'air_temperature_celcius': 19.0,
#  'hotspots': {'confidence': 97.0,
#               'surface_temperature_celcius': 45.0,
#               'time': datetime.datetime(2018, 4, 6, 13, 45, 30)}}
# {'air_temperature_celcius': 19.0,
#  'hotspots': {'confidence': 84.0,
#               'surface_temperature_celcius': 65.0,
#               'time': datetime.datetime(2018, 4, 6, 4, 32, 20)}}
# {'air_temperature_celcius': 19.0,
#  'hotspots': {'confidence': 92.0,
#               'surface_temperature_celcius': 69.0,
#               'time': datetime.datetime(2018, 4, 6, 4, 31, 10)}}
# {'air_temperature_celcius': 19.0,
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 95.0,
#               'time': datetime.datetime(2018, 4, 6, 4, 27, 50)}}
# {'air_temperature_celcius': 19.0,
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 88.0,
#               'time': datetime.datetime(2018, 4, 6, 4, 27, 50)}}
# {'air_temperature_celcius': 19.0,
#  'hotspots': {'confidence': 81.0,
#               'surface_temperature_celcius': 54.0,
#               'time': datetime.datetime(2018, 4, 6, 4, 27, 10)}}
# {'air_temperature_celcius': 19.0,
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 97.0,
#               'time': datetime.datetime(2018, 4, 6, 4, 27)}}
# {'air_temperature_celcius': 19.0,
#  'hotspots': {'confidence': 86.0,
#               'surface_temperature_celcius': 60.0,
#               'time': datetime.datetime(2018, 4, 6, 4, 27)}}
# {'air_temperature_celcius': 19.0,
#  'hotspots': {'confidence': 90.0,
#               'surface_temperature_celcius': 76.0,
#               'time': datetime.datetime(2018, 4, 6, 4, 27)}}
# {'air_temperature_celcius': 19.0,
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 99.0,
#               'time': datetime.datetime(2018, 4, 6, 4, 27)}}
# {'air_temperature_celcius': 19.0,
#  'hotspots': {'confidence': 83.0,
#               'surface_temperature_celcius': 57.0,
#               'time': datetime.datetime(2018, 4, 6, 4, 27)}}
# {'air_temperature_celcius': 19.0,
#  'hotspots': {'confidence': 83.0,
#               'surface_temperature_celcius': 64.0,
#               'time': datetime.datetime(2018, 4, 6, 4, 24, 40)}}
# {'air_temperature_celcius': 19.0,
#  'hotspots': {'confidence': 89.0,
#               'surface_temperature_celcius': 65.0,
#               'time': datetime.datetime(2018, 4, 6, 4, 24, 20)}}
# {'air_temperature_celcius': 19.0,
#  'hotspots': {'confidence': 89.0,
#               'surface_temperature_celcius': 65.0,
#               'time': datetime.datetime(2018, 4, 6, 4, 24, 20)}}
# {'air_temperature_celcius': 19.0,
#  'hotspots': {'confidence': 89.0,
#               'surface_temperature_celcius': 64.0,
#               'time': datetime.datetime(2018, 4, 6, 4, 24)}}
# {'air_temperature_celcius': 19.0,
#  'hotspots': {'confidence': 92.0,
#               'surface_temperature_celcius': 70.0,
#               'time': datetime.datetime(2018, 4, 6, 4, 23, 50)}}
# {'air_temperature_celcius': 19.0,
#  'hotspots': {'confidence': 99.0,
#               'surface_temperature_celcius': 85.0,
#               'time': datetime.datetime(2018, 4, 6, 4, 23, 50)}}
# {'air_temperature_celcius': 19.0,
#  'hotspots': {'confidence': 93.0,
#               'surface_temperature_celcius': 72.0,
#               'time': datetime.datetime(2018, 4, 6, 4, 23, 30)}}
# {'air_temperature_celcius': 19.0,
#  'hotspots': {'confidence': 89.0,
#               'surface_temperature_celcius': 65.0,
#               'time': datetime.datetime(2018, 4, 6, 4, 23, 10)}}
# {'air_temperature_celcius': 19.0,
#  'hotspots': {'confidence': 87.0,
#               'surface_temperature_celcius': 62.0,
#               'time': datetime.datetime(2018, 4, 6, 4, 23)}}
# {'air_temperature_celcius': 19.0,
#  'hotspots': {'confidence': 85.0,
#               'surface_temperature_celcius': 60.0,
#               'time': datetime.datetime(2018, 4, 6, 4, 22, 40)}}
# {'air_temperature_celcius': 19.0,
#  'hotspots': {'confidence': 83.0,
#               'surface_temperature_celcius': 56.0,
#               'time': datetime.datetime(2018, 4, 6, 4, 22, 20)}}
# {'air_temperature_celcius': 19.0,
#  'hotspots': {'confidence': 81.0,
#               'surface_temperature_celcius': 71.0,
#               'time': datetime.datetime(2018, 4, 6, 4, 22, 20)}}
# {'air_temperature_celcius': 19.0,
#  'hotspots': {'confidence': 85.0,
#               'surface_temperature_celcius': 60.0,
#               'time': datetime.datetime(2018, 4, 6, 4, 22, 20)}}
# {'air_temperature_celcius': 19.0,
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 103.0,
#               'time': datetime.datetime(2018, 4, 6, 4, 22, 20)}}
# {'air_temperature_celcius': 19.0,
#  'hotspots': {'confidence': 91.0,
#               'surface_temperature_celcius': 69.0,
#               'time': datetime.datetime(2018, 4, 6, 4, 22, 20)}}
# {'air_temperature_celcius': 19.0,
#  'hotspots': {'confidence': 86.0,
#               'surface_temperature_celcius': 68.0,
#               'time': datetime.datetime(2018, 4, 6, 4, 22, 10)}}
# {'air_temperature_celcius': 19.0,
#  'hotspots': {'confidence': 85.0,
#               'surface_temperature_celcius': 59.0,
#               'time': datetime.datetime(2018, 4, 6, 4, 22, 10)}}
# {'air_temperature_celcius': 19.0,
#  'hotspots': {'confidence': 90.0,
#               'surface_temperature_celcius': 67.0,
#               'time': datetime.datetime(2018, 4, 6, 4, 22, 10)}}
# {'air_temperature_celcius': 19.0,
#  'hotspots': {'confidence': 90.0,
#               'surface_temperature_celcius': 66.0,
#               'time': datetime.datetime(2018, 4, 6, 4, 21, 30)}}
# {'air_temperature_celcius': 19.0,
#  'hotspots': {'confidence': 94.0,
#               'surface_temperature_celcius': 96.0,
#               'time': datetime.datetime(2018, 4, 6, 4, 21, 10)}}
# {'air_temperature_celcius': 19.0,
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 115.0,
#               'time': datetime.datetime(2018, 4, 6, 4, 21)}}
# {'air_temperature_celcius': 19.0,
#  'hotspots': {'confidence': 84.0,
#               'surface_temperature_celcius': 58.0,
#               'time': datetime.datetime(2018, 4, 6, 4, 21)}}
# {'air_temperature_celcius': 19.0,
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 95.0,
#               'time': datetime.datetime(2018, 4, 6, 4, 20, 50)}}
# {'air_temperature_celcius': 19.0,
#  'hotspots': {'confidence': 88.0,
#               'surface_temperature_celcius': 65.0,
#               'time': datetime.datetime(2018, 4, 6, 4, 20, 50)}}
# {'air_temperature_celcius': 19.0,
#  'hotspots': {'confidence': 83.0,
#               'surface_temperature_celcius': 63.0,
#               'time': datetime.datetime(2018, 4, 6, 4, 20, 50)}}
# {'air_temperature_celcius': 19.0,
#  'hotspots': {'confidence': 81.0,
#               'surface_temperature_celcius': 60.0,
#               'time': datetime.datetime(2018, 4, 6, 4, 20, 40)}}
# {'air_temperature_celcius': 19.0,
#  'hotspots': {'confidence': 83.0,
#               'surface_temperature_celcius': 78.0,
#               'time': datetime.datetime(2018, 4, 6, 4, 20, 40)}}
# {'air_temperature_celcius': 19.0,
#  'hotspots': {'confidence': 96.0,
#               'surface_temperature_celcius': 77.0,
#               'time': datetime.datetime(2018, 4, 6, 4, 20, 40)}}
# {'air_temperature_celcius': 19.0,
#  'hotspots': {'confidence': 91.0,
#               'surface_temperature_celcius': 68.0,
#               'time': datetime.datetime(2018, 4, 6, 4, 20, 40)}}
# {'air_temperature_celcius': 19.0,
#  'hotspots': {'confidence': 97.0,
#               'surface_temperature_celcius': 81.0,
#               'time': datetime.datetime(2018, 4, 6, 4, 20, 40)}}
# {'air_temperature_celcius': 19.0,
#  'hotspots': {'confidence': 82.0,
#               'surface_temperature_celcius': 56.0,
#               'time': datetime.datetime(2018, 4, 6, 4, 20, 40)}}
# {'air_temperature_celcius': 19.0,
#  'hotspots': {'confidence': 94.0,
#               'surface_temperature_celcius': 104.0,
#               'time': datetime.datetime(2018, 4, 6, 4, 20, 40)}}
# {'air_temperature_celcius': 19.0,
#  'hotspots': {'confidence': 92.0,
#               'surface_temperature_celcius': 71.0,
#               'time': datetime.datetime(2018, 4, 6, 4, 20, 40)}}
# {'air_temperature_celcius': 19.0,
#  'hotspots': {'confidence': 87.0,
#               'surface_temperature_celcius': 62.0,
#               'time': datetime.datetime(2018, 4, 6, 4, 20, 40)}}
# {'air_temperature_celcius': 19.0,
#  'hotspots': {'confidence': 81.0,
#               'surface_temperature_celcius': 61.0,
#               'time': datetime.datetime(2018, 4, 6, 4, 20, 40)}}
# {'air_temperature_celcius': 19.0,
#  'hotspots': {'confidence': 80.0,
#               'surface_temperature_celcius': 53.0,
#               'time': datetime.datetime(2018, 4, 6, 4, 20, 40)}}
# {'air_temperature_celcius': 19.0,
#  'hotspots': {'confidence': 85.0,
#               'surface_temperature_celcius': 60.0,
#               'time': datetime.datetime(2018, 4, 6, 4, 20, 40)}}
# {'air_temperature_celcius': 19.0,
#  'hotspots': {'confidence': 90.0,
#               'surface_temperature_celcius': 67.0,
#               'time': datetime.datetime(2018, 4, 6, 4, 20, 40)}}
# {'air_temperature_celcius': 19.0,
#  'hotspots': {'confidence': 87.0,
#               'surface_temperature_celcius': 62.0,
#               'time': datetime.datetime(2018, 4, 6, 4, 20, 40)}}
# {'air_temperature_celcius': 19.0,
#  'hotspots': {'confidence': 94.0,
#               'surface_temperature_celcius': 86.0,
#               'time': datetime.datetime(2018, 4, 6, 4, 20, 40)}}
# {'air_temperature_celcius': 19.0,
#  'hotspots': {'confidence': 84.0,
#               'surface_temperature_celcius': 57.0,
#               'time': datetime.datetime(2018, 4, 6, 4, 20, 40)}}
# {'air_temperature_celcius': 19.0,
#  'hotspots': {'confidence': 87.0,
#               'surface_temperature_celcius': 62.0,
#               'time': datetime.datetime(2018, 4, 6, 4, 20, 40)}}
# {'air_temperature_celcius': 19.0,
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 100.0,
#               'time': datetime.datetime(2018, 4, 6, 4, 20, 40)}}
# {'air_temperature_celcius': 19.0,
#  'hotspots': {'confidence': 86.0,
#               'surface_temperature_celcius': 72.0,
#               'time': datetime.datetime(2018, 4, 6, 4, 20, 40)}}
# {'air_temperature_celcius': 19.0,
#  'hotspots': {'confidence': 81.0,
#               'surface_temperature_celcius': 57.0,
#               'time': datetime.datetime(2018, 4, 6, 4, 20, 40)}}
# {'air_temperature_celcius': 19.0,
#  'hotspots': {'confidence': 94.0,
#               'surface_temperature_celcius': 89.0,
#               'time': datetime.datetime(2018, 4, 6, 4, 20, 40)}}
# {'air_temperature_celcius': 21.0,
#  'hotspots': {'confidence': 85.0,
#               'surface_temperature_celcius': 41.0,
#               'time': datetime.datetime(2018, 4, 7, 12, 56, 50)}}
# {'air_temperature_celcius': 21.0,
#  'hotspots': {'confidence': 80.0,
#               'surface_temperature_celcius': 39.0,
#               'time': datetime.datetime(2018, 4, 7, 12, 56, 30)}}
# {'air_temperature_celcius': 21.0,
#  'hotspots': {'confidence': 94.0,
#               'surface_temperature_celcius': 49.0,
# ...
# {'air_temperature_celcius': 13.0,
#  'hotspots': {'confidence': 88.0,
#               'surface_temperature_celcius': 65.0,
#               'time': datetime.datetime(2018, 10, 3, 3, 58, 14)}}
# {'air_temperature_celcius': 13.0,
#  'hotspots': {'confidence': 87.0,
#               'surface_temperature_celcius': 59.0,
#               'time': datetime.datetime(2018, 10, 3, 3, 58, 14)}}
# {'air_temperature_celcius': 19.0,
#  'hotspots': {'confidence': 80.0,
#               'surface_temperature_celcius': 46.0,
#               'time': datetime.datetime(2018, 10, 4, 4, 41, 2)}}
# {'air_temperature_celcius': 19.0,
#  'hotspots': {'confidence': 80.0,
#               'surface_temperature_celcius': 46.0,
#               'time': datetime.datetime(2018, 10, 4, 4, 41)}}
# {'air_temperature_celcius': 19.0,
#  'hotspots': {'confidence': 85.0,
#               'surface_temperature_celcius': 54.0,
#               'time': datetime.datetime(2018, 10, 4, 4, 41)}}
# {'air_temperature_celcius': 19.0,
#  'hotspots': {'confidence': 88.0,
#               'surface_temperature_celcius': 58.0,
#               'time': datetime.datetime(2018, 10, 4, 4, 41)}}
# {'air_temperature_celcius': 17.0,
#  'hotspots': {'confidence': 91.0,
#               'surface_temperature_celcius': 42.0,
#               'time': datetime.datetime(2018, 10, 7, 12, 59, 33)}}
# {'air_temperature_celcius': 13.0,
#  'hotspots': {'confidence': 96.0,
#               'surface_temperature_celcius': 77.0,
#               'time': datetime.datetime(2018, 10, 10, 4, 4, 19)}}
# {'air_temperature_celcius': 13.0,
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 87.0,
#               'time': datetime.datetime(2018, 10, 15, 4, 23, 1)}}
# {'air_temperature_celcius': 13.0,
#  'hotspots': {'confidence': 99.0,
#               'surface_temperature_celcius': 85.0,
#               'time': datetime.datetime(2018, 10, 15, 4, 23, 1)}}
# {'air_temperature_celcius': 22.0,
#  'hotspots': {'confidence': 94.0,
#               'surface_temperature_celcius': 43.0,
#               'time': datetime.datetime(2018, 10, 17, 13, 36, 12)}}
# {'air_temperature_celcius': 22.0,
#  'hotspots': {'confidence': 91.0,
#               'surface_temperature_celcius': 68.0,
#               'time': datetime.datetime(2018, 10, 17, 4, 10, 45)}}
# {'air_temperature_celcius': 22.0,
#  'hotspots': {'confidence': 82.0,
#               'surface_temperature_celcius': 55.0,
#               'time': datetime.datetime(2018, 10, 17, 4, 10, 32)}}
# {'air_temperature_celcius': 26.0,
#  'hotspots': {'confidence': 84.0,
#               'surface_temperature_celcius': 59.0,
#               'time': datetime.datetime(2018, 10, 18, 0, 39, 2)}}
# {'air_temperature_celcius': 26.0,
#  'hotspots': {'confidence': 82.0,
#               'surface_temperature_celcius': 56.0,
#               'time': datetime.datetime(2018, 10, 18, 0, 39, 2)}}
# {'air_temperature_celcius': 13.0,
#  'hotspots': {'confidence': 80.0,
#               'surface_temperature_celcius': 46.0,
#               'time': datetime.datetime(2018, 10, 20, 4, 41, 19)}}
# {'air_temperature_celcius': 13.0,
#  'hotspots': {'confidence': 82.0,
#               'surface_temperature_celcius': 50.0,
#               'time': datetime.datetime(2018, 10, 20, 4, 41, 19)}}
# {'air_temperature_celcius': 12.0,
#  'hotspots': {'confidence': 88.0,
#               'surface_temperature_celcius': 59.0,
#               'time': datetime.datetime(2018, 10, 21, 1, 9, 55)}}
# {'air_temperature_celcius': 12.0,
#  'hotspots': {'confidence': 92.0,
#               'surface_temperature_celcius': 67.0,
#               'time': datetime.datetime(2018, 10, 21, 1, 9, 54)}}
# {'air_temperature_celcius': 13.0,
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 48.0,
#               'time': datetime.datetime(2018, 10, 26, 13, 30, 31)}}
# {'air_temperature_celcius': 13.0,
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 53.0,
#               'time': datetime.datetime(2018, 10, 26, 13, 30, 31)}}
# {'air_temperature_celcius': 22.0,
#  'hotspots': {'confidence': 86.0,
#               'surface_temperature_celcius': 60.0,
#               'time': datetime.datetime(2018, 10, 27, 4, 47, 31)}}
# {'air_temperature_celcius': 15.0,
#  'hotspots': {'confidence': 81.0,
#               'surface_temperature_celcius': 56.0,
#               'time': datetime.datetime(2018, 10, 28, 3, 52, 17)}}
# {'air_temperature_celcius': 13.0,
#  'hotspots': {'confidence': 83.0,
#               'surface_temperature_celcius': 58.0,
#               'time': datetime.datetime(2018, 11, 5, 4, 41, 34)}}
# {'air_temperature_celcius': 13.0,
#  'hotspots': {'confidence': 90.0,
#               'surface_temperature_celcius': 65.0,
#               'time': datetime.datetime(2018, 11, 5, 4, 41, 19)}}
# {'air_temperature_celcius': 13.0,
#  'hotspots': {'confidence': 89.0,
#               'surface_temperature_celcius': 62.0,
#               'time': datetime.datetime(2018, 11, 5, 4, 41, 19)}}
# {'air_temperature_celcius': 14.0,
#  'hotspots': {'confidence': 85.0,
#               'surface_temperature_celcius': 59.0,
#               'time': datetime.datetime(2018, 11, 9, 4, 16, 48)}}
# {'air_temperature_celcius': 14.0,
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 93.0,
#               'time': datetime.datetime(2018, 11, 9, 4, 16, 48)}}
# {'air_temperature_celcius': 14.0,
#  'hotspots': {'confidence': 96.0,
#               'surface_temperature_celcius': 77.0,
#               'time': datetime.datetime(2018, 11, 9, 4, 16, 48)}}
# {'air_temperature_celcius': 14.0,
#  'hotspots': {'confidence': 87.0,
#               'surface_temperature_celcius': 62.0,
#               'time': datetime.datetime(2018, 11, 9, 4, 16, 44)}}
# {'air_temperature_celcius': 14.0,
#  'hotspots': {'confidence': 97.0,
#               'surface_temperature_celcius': 80.0,
#               'time': datetime.datetime(2018, 11, 9, 4, 16, 44)}}
# {'air_temperature_celcius': 18.0,
#  'hotspots': {'confidence': 80.0,
#               'surface_temperature_celcius': 37.0,
#               'time': datetime.datetime(2018, 11, 11, 13, 30, 8)}}
# {'air_temperature_celcius': 18.0,
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 59.0,
#               'time': datetime.datetime(2018, 11, 11, 13, 30, 8)}}
# {'air_temperature_celcius': 18.0,
#  'hotspots': {'confidence': 86.0,
#               'surface_temperature_celcius': 60.0,
#               'time': datetime.datetime(2018, 11, 11, 4, 4, 25)}}
# {'air_temperature_celcius': 18.0,
#  'hotspots': {'confidence': 89.0,
#               'surface_temperature_celcius': 69.0,
#               'time': datetime.datetime(2018, 11, 12, 0, 33, 15)}}
# {'air_temperature_celcius': 24.0,
#  'hotspots': {'confidence': 87.0,
#               'surface_temperature_celcius': 61.0,
#               'time': datetime.datetime(2018, 11, 13, 3, 52, 15)}}
# {'air_temperature_celcius': 24.0,
#  'hotspots': {'confidence': 81.0,
#               'surface_temperature_celcius': 53.0,
#               'time': datetime.datetime(2018, 11, 13, 3, 52, 14)}}
# {'air_temperature_celcius': 28.0,
#  'hotspots': {'confidence': 87.0,
#               'surface_temperature_celcius': 65.0,
#               'time': datetime.datetime(2018, 11, 14, 4, 35, 4)}}
# {'air_temperature_celcius': 24.0,
#  'hotspots': {'confidence': 85.0,
#               'surface_temperature_celcius': 59.0,
#               'time': datetime.datetime(2018, 11, 21, 0, 27, 21)}}
# {'air_temperature_celcius': 23.0,
#  'hotspots': {'confidence': 84.0,
#               'surface_temperature_celcius': 59.0,
#               'time': datetime.datetime(2018, 11, 22, 3, 46)}}
# {'air_temperature_celcius': 23.0,
#  'hotspots': {'confidence': 88.0,
#               'surface_temperature_celcius': 64.0,
#               'time': datetime.datetime(2018, 11, 22, 3, 46)}}
# {'air_temperature_celcius': 24.0,
#  'hotspots': {'confidence': 84.0,
#               'surface_temperature_celcius': 60.0,
#               'time': datetime.datetime(2018, 11, 23, 4, 28, 59)}}
# {'air_temperature_celcius': 24.0,
#  'hotspots': {'confidence': 93.0,
#               'surface_temperature_celcius': 73.0,
#               'time': datetime.datetime(2018, 11, 23, 4, 28, 59)}}
# {'air_temperature_celcius': 28.0,
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 55.0,
#               'time': datetime.datetime(2018, 11, 29, 13, 17, 24)}}
# {'air_temperature_celcius': 28.0,
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 87.0,
#               'time': datetime.datetime(2018, 11, 29, 3, 52, 10)}}
# {'air_temperature_celcius': 28.0,
#  'hotspots': {'confidence': 97.0,
#               'surface_temperature_celcius': 80.0,
#               'time': datetime.datetime(2018, 11, 29, 3, 52, 10)}}
# {'air_temperature_celcius': 28.0,
#  'hotspots': {'confidence': 99.0,
#               'surface_temperature_celcius': 84.0,
#               'time': datetime.datetime(2018, 11, 29, 3, 52, 10)}}
# {'air_temperature_celcius': 26.0,
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 53.0,
#               'time': datetime.datetime(2018, 11, 30, 15, 38, 36)}}
# {'air_temperature_celcius': 26.0,
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 54.0,
#               'time': datetime.datetime(2018, 11, 30, 15, 38, 35)}}
# {'air_temperature_celcius': 26.0,
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 49.0,
#               'time': datetime.datetime(2018, 11, 30, 15, 38, 35)}}
# {'air_temperature_celcius': 26.0,
#  'hotspots': {'confidence': 84.0,
#               'surface_temperature_celcius': 38.0,
#               'time': datetime.datetime(2018, 11, 30, 12, 22, 15)}}
# {'air_temperature_celcius': 26.0,
#  'hotspots': {'confidence': 81.0,
#               'surface_temperature_celcius': 42.0,
#               'time': datetime.datetime(2018, 11, 30, 12, 22, 15)}}
# {'air_temperature_celcius': 26.0,
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 55.0,
#               'time': datetime.datetime(2018, 11, 30, 12, 22, 15)}}
# {'air_temperature_celcius': 26.0,
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 65.0,
#               'time': datetime.datetime(2018, 11, 30, 12, 22, 15)}}
# {'air_temperature_celcius': 26.0,
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 71.0,
#               'time': datetime.datetime(2018, 11, 30, 12, 22, 14)}}
# {'air_temperature_celcius': 26.0,
#  'hotspots': {'confidence': 84.0,
#               'surface_temperature_celcius': 59.0,
#               'time': datetime.datetime(2018, 11, 30, 4, 35)}}
# {'air_temperature_celcius': 26.0,
#  'hotspots': {'confidence': 98.0,
#               'surface_temperature_celcius': 83.0,
#               'time': datetime.datetime(2018, 11, 30, 4, 34, 57)}}
# {'air_temperature_celcius': 26.0,
#  'hotspots': {'confidence': 81.0,
#               'surface_temperature_celcius': 57.0,
#               'time': datetime.datetime(2018, 11, 30, 4, 34, 57)}}
# {'air_temperature_celcius': 26.0,
#  'hotspots': {'confidence': 84.0,
#               'surface_temperature_celcius': 61.0,
#               'time': datetime.datetime(2018, 11, 30, 4, 34, 57)}}
# {'air_temperature_celcius': 26.0,
#  'hotspots': {'confidence': 99.0,
#               'surface_temperature_celcius': 86.0,
#               'time': datetime.datetime(2018, 11, 30, 4, 34, 57)}}
# {'air_temperature_celcius': 26.0,
#  'hotspots': {'confidence': 83.0,
#               'surface_temperature_celcius': 58.0,
#               'time': datetime.datetime(2018, 11, 30, 0, 20, 53)}}
# {'air_temperature_celcius': 26.0,
#  'hotspots': {'confidence': 87.0,
#               'surface_temperature_celcius': 63.0,
#               'time': datetime.datetime(2018, 11, 30, 0, 20, 53)}}
# {'air_temperature_celcius': 26.0,
#  'hotspots': {'confidence': 95.0,
#               'surface_temperature_celcius': 76.0,
#               'time': datetime.datetime(2018, 11, 30, 0, 20, 53)}}
# {'air_temperature_celcius': 26.0,
#  'hotspots': {'confidence': 81.0,
#               'surface_temperature_celcius': 56.0,
#               'time': datetime.datetime(2018, 11, 30, 0, 20, 53)}}
# {'air_temperature_celcius': 26.0,
#  'hotspots': {'confidence': 81.0,
#               'surface_temperature_celcius': 55.0,
#               'time': datetime.datetime(2018, 11, 30, 0, 20, 53)}}
# {'air_temperature_celcius': 15.0,
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 54.0,
#               'time': datetime.datetime(2018, 12, 8, 13, 11, 44)}}
# {'air_temperature_celcius': 15.0,
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 71.0,
#               'time': datetime.datetime(2018, 12, 8, 13, 11, 44)}}
# {'air_temperature_celcius': 15.0,
#  'hotspots': {'confidence': 100.0,
#               'surface_temperature_celcius': 52.0,
#               'time': datetime.datetime(2018, 12, 8, 13, 11, 43)}}
# {'air_temperature_celcius': 17.0,
#  'hotspots': {'confidence': 87.0,
#               'surface_temperature_celcius': 61.0,
#               'time': datetime.datetime(2018, 12, 9, 0, 14, 34)}}
# {'air_temperature_celcius': 17.0,
#  'hotspots': {'confidence': 81.0,
#               'surface_temperature_celcius': 54.0,
#               'time': datetime.datetime(2018, 12, 9, 0, 14, 34)}}
# {'air_temperature_celcius': 17.0,
#  'hotspots': {'confidence': 84.0,
#               'surface_temperature_celcius': 58.0,
#               'time': datetime.datetime(2018, 12, 9, 0, 14, 33)}}
# {'air_temperature_celcius': 17.0,
#  'hotspots': {'confidence': 86.0,
#               'surface_temperature_celcius': 60.0,
#               'time': datetime.datetime(2018, 12, 9, 0, 14, 33)}}
# {'air_temperature_celcius': 28.0,
#  'hotspots': {'confidence': 83.0,
#               'surface_temperature_celcius': 60.0,
#               'time': datetime.datetime(2018, 12, 13, 4, 4, 19)}}
# {'air_temperature_celcius': 17.0,
#  'hotspots': {'confidence': 92.0,
#               'surface_temperature_celcius': 70.0,
#               'time': datetime.datetime(2018, 12, 14, 4, 47, 25)}}
# {'air_temperature_celcius': 18.0,
#  'hotspots': {'confidence': 92.0,
#               'surface_temperature_celcius': 42.0,
#               'time': datetime.datetime(2018, 12, 15, 13, 17, 17)}}
# {'air_temperature_celcius': 18.0,
#  'hotspots': {'confidence': 94.0,
#               'surface_temperature_celcius': 43.0,
#               'time': datetime.datetime(2018, 12, 16, 15, 38, 39)}}
# {'air_temperature_celcius': 18.0,
#  'hotspots': {'confidence': 93.0,
#               'surface_temperature_celcius': 73.0,
#               'time': datetime.datetime(2018, 12, 16, 4, 35, 13)}}
# {'air_temperature_celcius': 18.0,
#  'hotspots': {'confidence': 84.0,
#               'surface_temperature_celcius': 55.0,
#               'time': datetime.datetime(2018, 12, 16, 4, 34, 58)}}
# {'air_temperature_celcius': 18.0,
#  'hotspots': {'confidence': 95.0,
#               'surface_temperature_celcius': 75.0,
#               'time': datetime.datetime(2018, 12, 16, 4, 34, 58)}}
# {'air_temperature_celcius': 18.0,
#  'hotspots': {'confidence': 90.0,
#               'surface_temperature_celcius': 66.0,
#               'time': datetime.datetime(2018, 12, 16, 4, 34, 57)}}
# {'air_temperature_celcius': 18.0,
#  'hotspots': {'confidence': 93.0,
#               'surface_temperature_celcius': 73.0,
#               'time': datetime.datetime(2018, 12, 16, 0, 21, 12)}}
# {'air_temperature_celcius': 18.0,
#  'hotspots': {'confidence': 82.0,
#               'surface_temperature_celcius': 55.0,
#               'time': datetime.datetime(2018, 12, 16, 0, 21, 11)}}
# {'air_temperature_celcius': 18.0,
#  'hotspots': {'confidence': 82.0,
#               'surface_temperature_celcius': 64.0,
#               'time': datetime.datetime(2018, 12, 16, 0, 20, 53)}}
# {'air_temperature_celcius': 17.0,
#  'hotspots': {'confidence': 80.0,
#               'surface_temperature_celcius': 54.0,
#               'time': datetime.datetime(2018, 12, 25, 4, 29, 8)}}
# {'air_temperature_celcius': 28.0,
#  'hotspots': {'confidence': 82.0,
#               'surface_temperature_celcius': 63.0,
#               'time': datetime.datetime(2018, 12, 27, 0, 2, 15)}}
# {'air_temperature_celcius': 28.0,
#  'hotspots': {'confidence': 86.0,
#               'surface_temperature_celcius': 67.0,
#               'time': datetime.datetime(2018, 12, 27, 0, 2, 14)}}

# %% [markdown]
# E. Find the top 10 records with the highest surface temperature.

# %%
result = collection.aggregate([{'$unwind': '$hotspots'}, {
    '$sort': {'hotspots.surface_temperature_celcius': -1}}, {'$limit': 10}])

for each in result:
    pprint(each)
# Out:
# {'_id': ObjectId('60aa3feaf0d4af2cc0bd6ca6'),
#  'air_temperature_celcius': 15.0,
#  'date': datetime.datetime(2018, 4, 18, 0, 0),
#  'ghi': 122.0,
#  'hotspots': {'confidence': 100.0,
#               'latitude': -38.1665,
#               'longitude': 143.062,
#               'surface_temperature_celcius': 124.0,
#               'time': datetime.datetime(2018, 4, 18, 4, 52)},
#  'max_wind_speed': 9.9,
#  'precipitation': '0.00I',
#  'relative_humidity': 56.1,
#  'station': 948701,
#  'windspeed_knots': 5.1}
# {'_id': ObjectId('60aa3feaf0d4af2cc0bd6c98'),
#  'air_temperature_celcius': 16.0,
#  'date': datetime.datetime(2018, 4, 4, 0, 0),
#  'ghi': 140.0,
#  'hotspots': {'confidence': 100.0,
#               'latitude': -36.343,
#               'longitude': 142.1986,
#               'surface_temperature_celcius': 123.0,
#               'time': datetime.datetime(2018, 4, 4, 4, 32, 50)},
#  'max_wind_speed': 12.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 47.5,
#  'station': 948701,
#  'windspeed_knots': 5.4}
# {'_id': ObjectId('60aa3feaf0d4af2cc0bd6cb3'),
#  'air_temperature_celcius': 14.0,
#  'date': datetime.datetime(2018, 5, 1, 0, 0),
#  'ghi': 121.0,
#  'hotspots': {'confidence': 100.0,
#               'latitude': -36.9318,
#               'longitude': 143.0907,
#               'surface_temperature_celcius': 122.0,
#               'time': datetime.datetime(2018, 5, 1, 4, 14, 20)},
#  'max_wind_speed': 20.0,
#  'precipitation': '0.12G',
#  'relative_humidity': 49.2,
#  'station': 948701,
#  'windspeed_knots': 10.5}
# {'_id': ObjectId('60aa3feaf0d4af2cc0bd6c87'),
#  'air_temperature_celcius': 21.0,
#  'date': datetime.datetime(2018, 3, 18, 0, 0),
#  'ghi': 176.0,
#  'hotspots': {'confidence': 100.0,
#               'latitude': -37.017,
#               'longitude': 148.1297,
#               'surface_temperature_celcius': 121.0,
#               'time': datetime.datetime(2018, 3, 18, 3, 50, 50)},
#  'max_wind_speed': 11.1,
#  'precipitation': '0.00I',
#  'relative_humidity': 52.8,
#  'station': 948701,
#  'windspeed_knots': 4.1}
# {'_id': ObjectId('60aa3feaf0d4af2cc0bd6c98'),
#  'air_temperature_celcius': 16.0,
#  'date': datetime.datetime(2018, 4, 4, 0, 0),
#  'ghi': 140.0,
#  'hotspots': {'confidence': 100.0,
#               'latitude': -36.3521,
#               'longitude': 142.2008,
#               'surface_temperature_celcius': 120.0,
#               'time': datetime.datetime(2018, 4, 4, 4, 32, 40)},
#  'max_wind_speed': 12.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 47.5,
#  'station': 948701,
#  'windspeed_knots': 5.4}
# {'_id': ObjectId('60aa3feaf0d4af2cc0bd6ca1'),
#  'air_temperature_celcius': 16.0,
#  'date': datetime.datetime(2018, 4, 13, 0, 0),
#  'ghi': 132.0,
#  'hotspots': {'confidence': 100.0,
#               'latitude': -37.0745,
#               'longitude': 141.0692,
#               'surface_temperature_celcius': 120.0,
#               'time': datetime.datetime(2018, 4, 13, 4, 28, 10)},
#  'max_wind_speed': 9.9,
#  'precipitation': '0.00I',
#  'relative_humidity': 54.9,
#  'station': 948701,
#  'windspeed_knots': 5.9}
# {'_id': ObjectId('60aa3feaf0d4af2cc0bd6cbf'),
#  'air_temperature_celcius': 9.0,
#  'date': datetime.datetime(2018, 5, 13, 0, 0),
#  'ghi': 81.0,
#  'hotspots': {'confidence': 100.0,
#               'latitude': -34.9938,
#               'longitude': 141.876,
#               'surface_temperature_celcius': 120.0,
#               'time': datetime.datetime(2018, 5, 13, 4, 40, 20)},
#  'max_wind_speed': 8.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 44.0,
#  'station': 948701,
#  'windspeed_knots': 2.8}
# {'_id': ObjectId('60aa3feaf0d4af2cc0bd6ca6'),
#  'air_temperature_celcius': 15.0,
#  'date': datetime.datetime(2018, 4, 18, 0, 0),
#  'ghi': 122.0,
#  'hotspots': {'confidence': 100.0,
#               'latitude': -37.8326,
#               'longitude': 143.4999,
#               'surface_temperature_celcius': 120.0,
#               'time': datetime.datetime(2018, 4, 18, 4, 44, 50)},
#  'max_wind_speed': 9.9,
#  'precipitation': '0.00I',
#  'relative_humidity': 56.1,
#  'station': 948701,
#  'windspeed_knots': 5.1}
# {'_id': ObjectId('60aa3feaf0d4af2cc0bd6c98'),
#  'air_temperature_celcius': 16.0,
#  'date': datetime.datetime(2018, 4, 4, 0, 0),
#  'ghi': 140.0,
#  'hotspots': {'confidence': 100.0,
#               'latitude': -36.1057,
#               'longitude': 141.7608,
#               'surface_temperature_celcius': 120.0,
#               'time': datetime.datetime(2018, 4, 4, 4, 40)},
#  'max_wind_speed': 12.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 47.5,
#  'station': 948701,
#  'windspeed_knots': 5.4}
# {'_id': ObjectId('60aa3feaf0d4af2cc0bd6cb6'),
#  'air_temperature_celcius': 10.0,
#  'date': datetime.datetime(2018, 5, 4, 0, 0),
#  'ghi': 91.0,
#  'hotspots': {'confidence': 100.0,
#               'latitude': -36.4057,
#               'longitude': 140.9806,
#               'surface_temperature_celcius': 119.0,
#               'time': datetime.datetime(2018, 5, 4, 4, 44, 50)},
#  'max_wind_speed': 7.0,
#  'precipitation': '0.00I',
#  'relative_humidity': 43.3,
#  'station': 948701,
#  'windspeed_knots': 2.6}

# %% [markdown]
# F. Find the number of fires each day. You are required to only display the total number of fires and the date in the output.

# %%
result = collection.aggregate(
    [{'$project': {'_id': 0, 'date': 1, 'numberOfFires': {'$size': {'$ifNull': ['$hotspots', []]}}}}])

for each in result:
    pprint({
        "date": each['date'].strftime("%d/%m/%Y"),
        "numberOfFires": each['numberOfFires']
    })
# Out:
# {'date': '31/12/2017', 'numberOfFires': 0}
# {'date': '02/01/2018', 'numberOfFires': 0}
# {'date': '03/01/2018', 'numberOfFires': 0}
# {'date': '04/01/2018', 'numberOfFires': 0}
# {'date': '05/01/2018', 'numberOfFires': 0}
# {'date': '06/01/2018', 'numberOfFires': 0}
# {'date': '07/01/2018', 'numberOfFires': 0}
# {'date': '08/01/2018', 'numberOfFires': 0}
# {'date': '09/01/2018', 'numberOfFires': 0}
# {'date': '10/01/2018', 'numberOfFires': 0}
# {'date': '11/01/2018', 'numberOfFires': 0}
# {'date': '12/01/2018', 'numberOfFires': 0}
# {'date': '13/01/2018', 'numberOfFires': 0}
# {'date': '14/01/2018', 'numberOfFires': 0}
# {'date': '15/01/2018', 'numberOfFires': 0}
# {'date': '16/01/2018', 'numberOfFires': 0}
# {'date': '17/01/2018', 'numberOfFires': 0}
# {'date': '18/01/2018', 'numberOfFires': 0}
# {'date': '19/01/2018', 'numberOfFires': 0}
# {'date': '20/01/2018', 'numberOfFires': 0}
# {'date': '21/01/2018', 'numberOfFires': 0}
# {'date': '22/01/2018', 'numberOfFires': 0}
# {'date': '23/01/2018', 'numberOfFires': 0}
# {'date': '24/01/2018', 'numberOfFires': 0}
# {'date': '25/01/2018', 'numberOfFires': 0}
# {'date': '26/01/2018', 'numberOfFires': 0}
# {'date': '27/01/2018', 'numberOfFires': 0}
# {'date': '28/01/2018', 'numberOfFires': 0}
# {'date': '29/01/2018', 'numberOfFires': 0}
# {'date': '30/01/2018', 'numberOfFires': 0}
# {'date': '31/01/2018', 'numberOfFires': 0}
# {'date': '01/02/2018', 'numberOfFires': 0}
# {'date': '02/02/2018', 'numberOfFires': 0}
# {'date': '03/02/2018', 'numberOfFires': 0}
# {'date': '04/02/2018', 'numberOfFires': 0}
# {'date': '05/02/2018', 'numberOfFires': 0}
# {'date': '06/02/2018', 'numberOfFires': 0}
# {'date': '07/02/2018', 'numberOfFires': 0}
# {'date': '08/02/2018', 'numberOfFires': 0}
# {'date': '09/02/2018', 'numberOfFires': 0}
# {'date': '10/02/2018', 'numberOfFires': 0}
# {'date': '11/02/2018', 'numberOfFires': 0}
# {'date': '12/02/2018', 'numberOfFires': 0}
# {'date': '13/02/2018', 'numberOfFires': 0}
# {'date': '14/02/2018', 'numberOfFires': 0}
# {'date': '15/02/2018', 'numberOfFires': 0}
# {'date': '16/02/2018', 'numberOfFires': 0}
# {'date': '17/02/2018', 'numberOfFires': 0}
# {'date': '18/02/2018', 'numberOfFires': 0}
# {'date': '19/02/2018', 'numberOfFires': 0}
# {'date': '20/02/2018', 'numberOfFires': 0}
# {'date': '21/02/2018', 'numberOfFires': 0}
# {'date': '22/02/2018', 'numberOfFires': 0}
# {'date': '23/02/2018', 'numberOfFires': 0}
# {'date': '24/02/2018', 'numberOfFires': 0}
# {'date': '25/02/2018', 'numberOfFires': 0}
# {'date': '26/02/2018', 'numberOfFires': 0}
# {'date': '27/02/2018', 'numberOfFires': 0}
# {'date': '28/02/2018', 'numberOfFires': 0}
# {'date': '01/03/2018', 'numberOfFires': 0}
# {'date': '02/03/2018', 'numberOfFires': 0}
# {'date': '03/03/2018', 'numberOfFires': 0}
# {'date': '04/03/2018', 'numberOfFires': 0}
# {'date': '05/03/2018', 'numberOfFires': 0}
# {'date': '06/03/2018', 'numberOfFires': 2}
# {'date': '07/03/2018', 'numberOfFires': 1}
# {'date': '08/03/2018', 'numberOfFires': 2}
# {'date': '09/03/2018', 'numberOfFires': 3}
# {'date': '10/03/2018', 'numberOfFires': 8}
# {'date': '11/03/2018', 'numberOfFires': 0}
# {'date': '12/03/2018', 'numberOfFires': 5}
# {'date': '13/03/2018', 'numberOfFires': 2}
# {'date': '14/03/2018', 'numberOfFires': 10}
# {'date': '15/03/2018', 'numberOfFires': 7}
# {'date': '16/03/2018', 'numberOfFires': 0}
# {'date': '17/03/2018', 'numberOfFires': 6}
# {'date': '18/03/2018', 'numberOfFires': 3}
# {'date': '19/03/2018', 'numberOfFires': 21}
# {'date': '20/03/2018', 'numberOfFires': 0}
# {'date': '21/03/2018', 'numberOfFires': 0}
# {'date': '22/03/2018', 'numberOfFires': 0}
# {'date': '23/03/2018', 'numberOfFires': 0}
# {'date': '24/03/2018', 'numberOfFires': 2}
# {'date': '25/03/2018', 'numberOfFires': 13}
# {'date': '26/03/2018', 'numberOfFires': 17}
# {'date': '27/03/2018', 'numberOfFires': 0}
# {'date': '28/03/2018', 'numberOfFires': 54}
# {'date': '29/03/2018', 'numberOfFires': 1}
# {'date': '30/03/2018', 'numberOfFires': 0}
# {'date': '31/03/2018', 'numberOfFires': 22}
# {'date': '01/04/2018', 'numberOfFires': 7}
# {'date': '02/04/2018', 'numberOfFires': 5}
# {'date': '03/04/2018', 'numberOfFires': 72}
# {'date': '04/04/2018', 'numberOfFires': 89}
# {'date': '05/04/2018', 'numberOfFires': 49}
# {'date': '06/04/2018', 'numberOfFires': 118}
# {'date': '07/04/2018', 'numberOfFires': 39}
# {'date': '08/04/2018', 'numberOfFires': 20}
# {'date': '09/04/2018', 'numberOfFires': 0}
# {'date': '10/04/2018', 'numberOfFires': 0}
# {'date': '11/04/2018', 'numberOfFires': 24}
# {'date': '12/04/2018', 'numberOfFires': 69}
# {'date': '13/04/2018', 'numberOfFires': 357}
# {'date': '14/04/2018', 'numberOfFires': 18}
# {'date': '15/04/2018', 'numberOfFires': 69}
# {'date': '16/04/2018', 'numberOfFires': 18}
# {'date': '17/04/2018', 'numberOfFires': 38}
# {'date': '18/04/2018', 'numberOfFires': 325}
# {'date': '19/04/2018', 'numberOfFires': 50}
# {'date': '20/04/2018', 'numberOfFires': 31}
# {'date': '21/04/2018', 'numberOfFires': 0}
# {'date': '22/04/2018', 'numberOfFires': 2}
# {'date': '23/04/2018', 'numberOfFires': 19}
# {'date': '24/04/2018', 'numberOfFires': 8}
# {'date': '25/04/2018', 'numberOfFires': 3}
# {'date': '26/04/2018', 'numberOfFires': 1}
# {'date': '27/04/2018', 'numberOfFires': 0}
# {'date': '28/04/2018', 'numberOfFires': 0}
# {'date': '29/04/2018', 'numberOfFires': 3}
# {'date': '30/04/2018', 'numberOfFires': 0}
# {'date': '01/05/2018', 'numberOfFires': 20}
# {'date': '02/05/2018', 'numberOfFires': 10}
# {'date': '03/05/2018', 'numberOfFires': 64}
# {'date': '04/05/2018', 'numberOfFires': 135}
# {'date': '05/05/2018', 'numberOfFires': 31}
# {'date': '06/05/2018', 'numberOfFires': 17}
# {'date': '07/05/2018', 'numberOfFires': 3}
# {'date': '08/05/2018', 'numberOfFires': 24}
# {'date': '09/05/2018', 'numberOfFires': 13}
# {'date': '10/05/2018', 'numberOfFires': 114}
# {'date': '11/05/2018', 'numberOfFires': 19}
# {'date': '12/05/2018', 'numberOfFires': 10}
# {'date': '13/05/2018', 'numberOfFires': 54}
# {'date': '14/05/2018', 'numberOfFires': 1}
# {'date': '15/05/2018', 'numberOfFires': 102}
# {'date': '16/05/2018', 'numberOfFires': 3}
# {'date': '17/05/2018', 'numberOfFires': 1}
# {'date': '18/05/2018', 'numberOfFires': 7}
# {'date': '19/05/2018', 'numberOfFires': 0}
# {'date': '20/05/2018', 'numberOfFires': 0}
# {'date': '21/05/2018', 'numberOfFires': 0}
# {'date': '22/05/2018', 'numberOfFires': 33}
# {'date': '23/05/2018', 'numberOfFires': 5}
# {'date': '24/05/2018', 'numberOfFires': 3}
# {'date': '25/05/2018', 'numberOfFires': 0}
# {'date': '26/05/2018', 'numberOfFires': 4}
# {'date': '27/05/2018', 'numberOfFires': 0}
# {'date': '28/05/2018', 'numberOfFires': 0}
# {'date': '29/05/2018', 'numberOfFires': 0}
# {'date': '30/05/2018', 'numberOfFires': 0}
# {'date': '31/05/2018', 'numberOfFires': 0}
# {'date': '01/06/2018', 'numberOfFires': 2}
# {'date': '02/06/2018', 'numberOfFires': 11}
# {'date': '03/06/2018', 'numberOfFires': 2}
# {'date': '04/06/2018', 'numberOfFires': 9}
# {'date': '05/06/2018', 'numberOfFires': 0}
# {'date': '06/06/2018', 'numberOfFires': 0}
# {'date': '07/06/2018', 'numberOfFires': 14}
# {'date': '08/06/2018', 'numberOfFires': 0}
# {'date': '09/06/2018', 'numberOfFires': 3}
# {'date': '10/06/2018', 'numberOfFires': 0}
# {'date': '11/06/2018', 'numberOfFires': 2}
# {'date': '12/06/2018', 'numberOfFires': 0}
# {'date': '13/06/2018', 'numberOfFires': 1}
# {'date': '14/06/2018', 'numberOfFires': 4}
# {'date': '15/06/2018', 'numberOfFires': 0}
# {'date': '16/06/2018', 'numberOfFires': 2}
# {'date': '17/06/2018', 'numberOfFires': 0}
# {'date': '18/06/2018', 'numberOfFires': 2}
# {'date': '19/06/2018', 'numberOfFires': 0}
# {'date': '20/06/2018', 'numberOfFires': 6}
# {'date': '21/06/2018', 'numberOfFires': 0}
# {'date': '22/06/2018', 'numberOfFires': 1}
# {'date': '23/06/2018', 'numberOfFires': 0}
# {'date': '24/06/2018', 'numberOfFires': 0}
# {'date': '25/06/2018', 'numberOfFires': 0}
# {'date': '26/06/2018', 'numberOfFires': 0}
# {'date': '27/06/2018', 'numberOfFires': 0}
# {'date': '28/06/2018', 'numberOfFires': 0}
# {'date': '29/06/2018', 'numberOfFires': 0}
# {'date': '30/06/2018', 'numberOfFires': 6}
# {'date': '01/07/2018', 'numberOfFires': 4}
# {'date': '02/07/2018', 'numberOfFires': 8}
# {'date': '03/07/2018', 'numberOfFires': 0}
# {'date': '04/07/2018', 'numberOfFires': 1}
# {'date': '05/07/2018', 'numberOfFires': 1}
# {'date': '06/07/2018', 'numberOfFires': 3}
# {'date': '07/07/2018', 'numberOfFires': 0}
# {'date': '08/07/2018', 'numberOfFires': 0}
# {'date': '09/07/2018', 'numberOfFires': 0}
# {'date': '10/07/2018', 'numberOfFires': 0}
# {'date': '11/07/2018', 'numberOfFires': 0}
# {'date': '12/07/2018', 'numberOfFires': 0}
# {'date': '13/07/2018', 'numberOfFires': 0}
# {'date': '14/07/2018', 'numberOfFires': 2}
# {'date': '15/07/2018', 'numberOfFires': 0}
# {'date': '16/07/2018', 'numberOfFires': 0}
# {'date': '17/07/2018', 'numberOfFires': 0}
# {'date': '18/07/2018', 'numberOfFires': 0}
# {'date': '19/07/2018', 'numberOfFires': 0}
# {'date': '20/07/2018', 'numberOfFires': 0}
# {'date': '21/07/2018', 'numberOfFires': 0}
# {'date': '22/07/2018', 'numberOfFires': 0}
# {'date': '23/07/2018', 'numberOfFires': 0}
# {'date': '24/07/2018', 'numberOfFires': 0}
# {'date': '25/07/2018', 'numberOfFires': 0}
# {'date': '26/07/2018', 'numberOfFires': 0}
# {'date': '27/07/2018', 'numberOfFires': 0}
# {'date': '28/07/2018', 'numberOfFires': 0}
# {'date': '29/07/2018', 'numberOfFires': 2}
# {'date': '30/07/2018', 'numberOfFires': 0}
# {'date': '31/07/2018', 'numberOfFires': 2}
# {'date': '01/08/2018', 'numberOfFires': 2}
# {'date': '02/08/2018', 'numberOfFires': 2}
# {'date': '03/08/2018', 'numberOfFires': 0}
# {'date': '04/08/2018', 'numberOfFires': 0}
# {'date': '05/08/2018', 'numberOfFires': 1}
# {'date': '06/08/2018', 'numberOfFires': 0}
# {'date': '07/08/2018', 'numberOfFires': 0}
# {'date': '08/08/2018', 'numberOfFires': 0}
# {'date': '09/08/2018', 'numberOfFires': 0}
# {'date': '10/08/2018', 'numberOfFires': 1}
# {'date': '11/08/2018', 'numberOfFires': 0}
# {'date': '12/08/2018', 'numberOfFires': 0}
# {'date': '13/08/2018', 'numberOfFires': 9}
# {'date': '14/08/2018', 'numberOfFires': 5}
# {'date': '15/08/2018', 'numberOfFires': 0}
# {'date': '16/08/2018', 'numberOfFires': 0}
# {'date': '17/08/2018', 'numberOfFires': 0}
# {'date': '18/08/2018', 'numberOfFires': 0}
# {'date': '19/08/2018', 'numberOfFires': 0}
# {'date': '20/08/2018', 'numberOfFires': 0}
# {'date': '21/08/2018', 'numberOfFires': 0}
# {'date': '22/08/2018', 'numberOfFires': 0}
# {'date': '23/08/2018', 'numberOfFires': 0}
# {'date': '24/08/2018', 'numberOfFires': 0}
# {'date': '25/08/2018', 'numberOfFires': 0}
# {'date': '26/08/2018', 'numberOfFires': 0}
# {'date': '27/08/2018', 'numberOfFires': 0}
# {'date': '28/08/2018', 'numberOfFires': 0}
# {'date': '29/08/2018', 'numberOfFires': 0}
# {'date': '30/08/2018', 'numberOfFires': 0}
# {'date': '31/08/2018', 'numberOfFires': 0}
# {'date': '01/09/2018', 'numberOfFires': 0}
# {'date': '02/09/2018', 'numberOfFires': 0}
# {'date': '03/09/2018', 'numberOfFires': 0}
# {'date': '04/09/2018', 'numberOfFires': 0}
# {'date': '05/09/2018', 'numberOfFires': 0}
# {'date': '06/09/2018', 'numberOfFires': 0}
# {'date': '07/09/2018', 'numberOfFires': 0}
# {'date': '08/09/2018', 'numberOfFires': 0}
# {'date': '09/09/2018', 'numberOfFires': 0}
# {'date': '10/09/2018', 'numberOfFires': 4}
# {'date': '11/09/2018', 'numberOfFires': 0}
# {'date': '12/09/2018', 'numberOfFires': 0}
# {'date': '13/09/2018', 'numberOfFires': 0}
# {'date': '14/09/2018', 'numberOfFires': 0}
# {'date': '15/09/2018', 'numberOfFires': 0}
# {'date': '16/09/2018', 'numberOfFires': 0}
# {'date': '17/09/2018', 'numberOfFires': 0}
# {'date': '18/09/2018', 'numberOfFires': 0}
# {'date': '19/09/2018', 'numberOfFires': 0}
# {'date': '20/09/2018', 'numberOfFires': 5}
# {'date': '21/09/2018', 'numberOfFires': 2}
# {'date': '22/09/2018', 'numberOfFires': 1}
# {'date': '23/09/2018', 'numberOfFires': 23}
# {'date': '24/09/2018', 'numberOfFires': 28}
# {'date': '25/09/2018', 'numberOfFires': 0}
# {'date': '26/09/2018', 'numberOfFires': 1}
# {'date': '27/09/2018', 'numberOfFires': 7}
# {'date': '28/09/2018', 'numberOfFires': 0}
# {'date': '29/09/2018', 'numberOfFires': 2}
# {'date': '30/09/2018', 'numberOfFires': 0}
# {'date': '01/10/2018', 'numberOfFires': 8}
# {'date': '02/10/2018', 'numberOfFires': 7}
# {'date': '03/10/2018', 'numberOfFires': 18}
# {'date': '04/10/2018', 'numberOfFires': 5}
# {'date': '05/10/2018', 'numberOfFires': 0}
# {'date': '06/10/2018', 'numberOfFires': 2}
# {'date': '07/10/2018', 'numberOfFires': 1}
# {'date': '08/10/2018', 'numberOfFires': 1}
# {'date': '09/10/2018', 'numberOfFires': 1}
# {'date': '10/10/2018', 'numberOfFires': 3}
# {'date': '11/10/2018', 'numberOfFires': 0}
# {'date': '12/10/2018', 'numberOfFires': 0}
# {'date': '13/10/2018', 'numberOfFires': 0}
# {'date': '14/10/2018', 'numberOfFires': 0}
# {'date': '15/10/2018', 'numberOfFires': 3}
# {'date': '16/10/2018', 'numberOfFires': 1}
# {'date': '17/10/2018', 'numberOfFires': 5}
# {'date': '18/10/2018', 'numberOfFires': 6}
# {'date': '19/10/2018', 'numberOfFires': 0}
# {'date': '20/10/2018', 'numberOfFires': 3}
# {'date': '21/10/2018', 'numberOfFires': 4}
# {'date': '22/10/2018', 'numberOfFires': 0}
# {'date': '23/10/2018', 'numberOfFires': 1}
# {'date': '24/10/2018', 'numberOfFires': 0}
# {'date': '25/10/2018', 'numberOfFires': 0}
# {'date': '26/10/2018', 'numberOfFires': 5}
# {'date': '27/10/2018', 'numberOfFires': 5}
# {'date': '28/10/2018', 'numberOfFires': 1}
# {'date': '29/10/2018', 'numberOfFires': 0}
# {'date': '30/10/2018', 'numberOfFires': 0}
# {'date': '31/10/2018', 'numberOfFires': 0}
# {'date': '01/11/2018', 'numberOfFires': 0}
# {'date': '02/11/2018', 'numberOfFires': 0}
# {'date': '03/11/2018', 'numberOfFires': 0}
# {'date': '04/11/2018', 'numberOfFires': 0}
# {'date': '05/11/2018', 'numberOfFires': 4}
# {'date': '06/11/2018', 'numberOfFires': 0}
# {'date': '07/11/2018', 'numberOfFires': 0}
# {'date': '08/11/2018', 'numberOfFires': 2}
# {'date': '09/11/2018', 'numberOfFires': 10}
# {'date': '10/11/2018', 'numberOfFires': 0}
# {'date': '11/11/2018', 'numberOfFires': 4}
# {'date': '12/11/2018', 'numberOfFires': 5}
# {'date': '13/11/2018', 'numberOfFires': 5}
# {'date': '14/11/2018', 'numberOfFires': 3}
# {'date': '15/11/2018', 'numberOfFires': 0}
# {'date': '16/11/2018', 'numberOfFires': 0}
# {'date': '17/11/2018', 'numberOfFires': 0}
# {'date': '18/11/2018', 'numberOfFires': 0}
# {'date': '19/11/2018', 'numberOfFires': 0}
# {'date': '20/11/2018', 'numberOfFires': 0}
# {'date': '21/11/2018', 'numberOfFires': 1}
# {'date': '22/11/2018', 'numberOfFires': 2}
# {'date': '23/11/2018', 'numberOfFires': 5}
# {'date': '24/11/2018', 'numberOfFires': 0}
# {'date': '25/11/2018', 'numberOfFires': 0}
# {'date': '26/11/2018', 'numberOfFires': 0}
# {'date': '27/11/2018', 'numberOfFires': 0}
# {'date': '28/11/2018', 'numberOfFires': 1}
# {'date': '29/11/2018', 'numberOfFires': 8}
# {'date': '30/11/2018', 'numberOfFires': 31}
# {'date': '01/12/2018', 'numberOfFires': 0}
# {'date': '02/12/2018', 'numberOfFires': 0}
# {'date': '03/12/2018', 'numberOfFires': 0}
# {'date': '04/12/2018', 'numberOfFires': 0}
# {'date': '05/12/2018', 'numberOfFires': 0}
# {'date': '06/12/2018', 'numberOfFires': 0}
# {'date': '07/12/2018', 'numberOfFires': 0}
# {'date': '08/12/2018', 'numberOfFires': 5}
# {'date': '09/12/2018', 'numberOfFires': 4}
# {'date': '10/12/2018', 'numberOfFires': 2}
# {'date': '11/12/2018', 'numberOfFires': 0}
# {'date': '12/12/2018', 'numberOfFires': 1}
# {'date': '13/12/2018', 'numberOfFires': 1}
# {'date': '14/12/2018', 'numberOfFires': 1}
# {'date': '15/12/2018', 'numberOfFires': 4}
# {'date': '16/12/2018', 'numberOfFires': 15}
# {'date': '17/12/2018', 'numberOfFires': 0}
# {'date': '18/12/2018', 'numberOfFires': 0}
# {'date': '19/12/2018', 'numberOfFires': 0}
# {'date': '20/12/2018', 'numberOfFires': 0}
# {'date': '21/12/2018', 'numberOfFires': 1}
# {'date': '22/12/2018', 'numberOfFires': 0}
# {'date': '23/12/2018', 'numberOfFires': 0}
# {'date': '24/12/2018', 'numberOfFires': 1}
# {'date': '25/12/2018', 'numberOfFires': 1}
# {'date': '26/12/2018', 'numberOfFires': 0}
# {'date': '27/12/2018', 'numberOfFires': 4}
# {'date': '28/12/2018', 'numberOfFires': 0}
# {'date': '29/12/2018', 'numberOfFires': 0}
# {'date': '30/12/2018', 'numberOfFires': 0}
# {'date': '31/12/2018', 'numberOfFires': 0}
# {'date': '01/01/2018', 'numberOfFires': 0}

# %% [markdown]
# G. Find the records of fires where the confidence is below 70.

# %%
result = collection.aggregate(
    [{'$unwind': '$hotspots'}, {'$match': {'hotspots.confidence': {'$lt': 70}}}, {'$project': {'_id': 0, 'hotspots': 1}}])

for each in result:
    pprint(each)
# Out:
# {'hotspots': {'confidence': 68.0,
#               'latitude': -37.7885,
#               'longitude': 141.9352,
#               'surface_temperature_celcius': 55.0,
#               'time': datetime.datetime(2018, 3, 8, 4, 51)}}
# {'hotspots': {'confidence': 54.0,
#               'latitude': -37.7171,
#               'longitude': 147.5866,
#               'surface_temperature_celcius': 44.0,
#               'time': datetime.datetime(2018, 3, 9, 3, 57)}}
# {'hotspots': {'confidence': 55.0,
#               'latitude': -36.2544,
#               'longitude': 148.0353,
#               'surface_temperature_celcius': 42.0,
#               'time': datetime.datetime(2018, 3, 10, 4, 43)}}
# {'hotspots': {'confidence': 54.0,
#               'latitude': -37.2197,
#               'longitude': 147.9621,
#               'surface_temperature_celcius': 43.0,
#               'time': datetime.datetime(2018, 3, 10, 4, 42, 30)}}
# {'hotspots': {'confidence': 56.0,
#               'latitude': -37.0286,
#               'longitude': 148.155,
#               'surface_temperature_celcius': 42.0,
#               'time': datetime.datetime(2018, 3, 13, 23, 58, 50)}}
# {'hotspots': {'confidence': 52.0,
#               'latitude': -37.0316,
#               'longitude': 148.1519,
#               'surface_temperature_celcius': 35.0,
#               'time': datetime.datetime(2018, 3, 13, 12, 57)}}
# {'hotspots': {'confidence': 52.0,
#               'latitude': -37.4075,
#               'longitude': 147.0233,
#               'surface_temperature_celcius': 43.0,
#               'time': datetime.datetime(2018, 3, 15, 0, 42, 50)}}
# {'hotspots': {'confidence': 66.0,
#               'latitude': -37.0228,
#               'longitude': 148.1281,
#               'surface_temperature_celcius': 43.0,
#               'time': datetime.datetime(2018, 3, 15, 0, 42, 50)}}
# {'hotspots': {'confidence': 51.0,
#               'latitude': -37.002,
#               'longitude': 148.2055,
#               'surface_temperature_celcius': 44.0,
#               'time': datetime.datetime(2018, 3, 15, 0, 42, 40)}}
# {'hotspots': {'confidence': 64.0,
#               'latitude': -37.4313,
#               'longitude': 147.0343,
#               'surface_temperature_celcius': 37.0,
#               'time': datetime.datetime(2018, 3, 18, 13, 16, 50)}}
# {'hotspots': {'confidence': 58.0,
#               'latitude': -37.9164,
#               'longitude': 143.4866,
#               'surface_temperature_celcius': 54.0,
#               'time': datetime.datetime(2018, 3, 19, 4, 39, 20)}}
# {'hotspots': {'confidence': 63.0,
#               'latitude': -37.9257,
#               'longitude': 143.4891,
#               'surface_temperature_celcius': 54.0,
#               'time': datetime.datetime(2018, 3, 19, 4, 39, 20)}}
# {'hotspots': {'confidence': 64.0,
#               'latitude': -37.3982,
#               'longitude': 147.0001,
#               'surface_temperature_celcius': 58.0,
#               'time': datetime.datetime(2018, 3, 19, 4, 36)}}
# {'hotspots': {'confidence': 59.0,
#               'latitude': -37.4023,
#               'longitude': 147.0394,
#               'surface_temperature_celcius': 56.0,
#               'time': datetime.datetime(2018, 3, 19, 4, 35)}}
# {'hotspots': {'confidence': 60.0,
#               'latitude': -37.4336,
#               'longitude': 147.0534,
#               'surface_temperature_celcius': 51.0,
#               'time': datetime.datetime(2018, 3, 19, 4, 33, 50)}}
# {'hotspots': {'confidence': 61.0,
#               'latitude': -37.4003,
#               'longitude': 147.0448,
#               'surface_temperature_celcius': 55.0,
#               'time': datetime.datetime(2018, 3, 19, 4, 33, 30)}}
# {'hotspots': {'confidence': 53.0,
#               'latitude': -37.9184,
#               'longitude': 143.4745,
#               'surface_temperature_celcius': 55.0,
#               'time': datetime.datetime(2018, 3, 19, 4, 33, 30)}}
# {'hotspots': {'confidence': 61.0,
#               'latitude': -37.3911,
#               'longitude': 147.037,
#               'surface_temperature_celcius': 50.0,
#               'time': datetime.datetime(2018, 3, 19, 4, 33, 10)}}
# {'hotspots': {'confidence': 66.0,
#               'latitude': -37.9277,
#               'longitude': 143.477,
#               'surface_temperature_celcius': 55.0,
#               'time': datetime.datetime(2018, 3, 19, 4, 32, 50)}}
# {'hotspots': {'confidence': 60.0,
#               'latitude': -37.3942,
#               'longitude': 147.0455,
#               'surface_temperature_celcius': 44.0,
#               'time': datetime.datetime(2018, 3, 19, 0, 12, 50)}}
# {'hotspots': {'confidence': 65.0,
#               'latitude': -37.1603,
#               'longitude': 142.8088,
#               'surface_temperature_celcius': 50.0,
#               'time': datetime.datetime(2018, 3, 24, 4, 58)}}
# {'hotspots': {'confidence': 55.0,
#               'latitude': -37.1684,
#               'longitude': 142.8183,
#               'surface_temperature_celcius': 48.0,
#               'time': datetime.datetime(2018, 3, 24, 4, 56, 10)}}
# {'hotspots': {'confidence': 62.0,
#               'latitude': -37.8992,
#               'longitude': 143.4534,
#               'surface_temperature_celcius': 54.0,
#               'time': datetime.datetime(2018, 3, 25, 4, 3, 10)}}
# {'hotspots': {'confidence': 57.0,
#               'latitude': -37.9022,
#               'longitude': 143.4607,
#               'surface_temperature_celcius': 57.0,
#               'time': datetime.datetime(2018, 3, 25, 3, 56, 40)}}
# {'hotspots': {'confidence': 68.0,
#               'latitude': -38.1131,
#               'longitude': 143.7173,
#               'surface_temperature_celcius': 44.0,
#               'time': datetime.datetime(2018, 3, 26, 4, 41, 10)}}
# {'hotspots': {'confidence': 60.0,
#               'latitude': -37.8469,
#               'longitude': 143.5343,
#               'surface_temperature_celcius': 50.0,
#               'time': datetime.datetime(2018, 3, 26, 4, 39, 10)}}
# {'hotspots': {'confidence': 67.0,
#               'latitude': -37.1956,
#               'longitude': 141.0252,
#               'surface_temperature_celcius': 44.0,
#               'time': datetime.datetime(2018, 3, 26, 4, 39, 10)}}
# {'hotspots': {'confidence': 53.0,
#               'latitude': -37.6195,
#               'longitude': 143.4212,
#               'surface_temperature_celcius': 46.0,
#               'time': datetime.datetime(2018, 3, 28, 4, 29, 30)}}
# {'hotspots': {'confidence': 63.0,
#               'latitude': -37.6376,
#               'longitude': 143.4255,
#               'surface_temperature_celcius': 48.0,
#               'time': datetime.datetime(2018, 3, 28, 4, 26, 50)}}
# {'hotspots': {'confidence': 69.0,
#               'latitude': -36.4422,
#               'longitude': 141.4172,
#               'surface_temperature_celcius': 46.0,
#               'time': datetime.datetime(2018, 3, 28, 4, 26, 50)}}
# {'hotspots': {'confidence': 55.0,
#               'latitude': -34.342,
#               'longitude': 141.6548,
#               'surface_temperature_celcius': 54.0,
#               'time': datetime.datetime(2018, 3, 28, 4, 26, 50)}}
# {'hotspots': {'confidence': 69.0,
#               'latitude': -34.2648,
#               'longitude': 141.6325,
#               'surface_temperature_celcius': 51.0,
#               'time': datetime.datetime(2018, 3, 29, 0, 48, 40)}}
# {'hotspots': {'confidence': 68.0,
#               'latitude': -36.1649,
#               'longitude': 145.9352,
#               'surface_temperature_celcius': 44.0,
#               'time': datetime.datetime(2018, 3, 31, 4, 57, 50)}}
# {'hotspots': {'confidence': 68.0,
#               'latitude': -36.0436,
#               'longitude': 145.7964,
#               'surface_temperature_celcius': 44.0,
#               'time': datetime.datetime(2018, 3, 31, 4, 57, 40)}}
# {'hotspots': {'confidence': 52.0,
#               'latitude': -36.7134,
#               'longitude': 145.2151,
#               'surface_temperature_celcius': 38.0,
#               'time': datetime.datetime(2018, 3, 31, 4, 57, 10)}}
# {'hotspots': {'confidence': 61.0,
#               'latitude': -36.7028,
#               'longitude': 145.2519,
#               'surface_temperature_celcius': 44.0,
#               'time': datetime.datetime(2018, 3, 31, 4, 57, 10)}}
# {'hotspots': {'confidence': 51.0,
#               'latitude': -37.561,
#               'longitude': 143.242,
#               'surface_temperature_celcius': 38.0,
#               'time': datetime.datetime(2018, 3, 31, 4, 57, 10)}}
# {'hotspots': {'confidence': 56.0,
#               'latitude': -37.982,
#               'longitude': 143.6422,
#               'surface_temperature_celcius': 42.0,
#               'time': datetime.datetime(2018, 3, 31, 4, 57, 10)}}
# {'hotspots': {'confidence': 51.0,
#               'latitude': -34.2568,
#               'longitude': 141.64,
#               'surface_temperature_celcius': 42.0,
#               'time': datetime.datetime(2018, 3, 31, 0, 36, 30)}}
# {'hotspots': {'confidence': 58.0,
#               'latitude': -36.2044,
#               'longitude': 145.7706,
#               'surface_temperature_celcius': 51.0,
#               'time': datetime.datetime(2018, 4, 1, 4, 2, 40)}}
# {'hotspots': {'confidence': 57.0,
#               'latitude': -36.5245,
#               'longitude': 143.1556,
#               'surface_temperature_celcius': 43.0,
#               'time': datetime.datetime(2018, 4, 1, 4, 2, 40)}}
# {'hotspots': {'confidence': 50.0,
#               'latitude': -36.1002,
#               'longitude': 147.6494,
#               'surface_temperature_celcius': 39.0,
#               'time': datetime.datetime(2018, 4, 1, 4, 2, 40)}}
# {'hotspots': {'confidence': 60.0,
#               'latitude': -36.3872,
#               'longitude': 145.3858,
#               'surface_temperature_celcius': 40.0,
#               'time': datetime.datetime(2018, 4, 2, 4, 53, 30)}}
# {'hotspots': {'confidence': 63.0,
#               'latitude': -36.494,
#               'longitude': 145.4522,
#               'surface_temperature_celcius': 41.0,
#               'time': datetime.datetime(2018, 4, 2, 4, 45, 10)}}
# {'hotspots': {'confidence': 60.0,
#               'latitude': -37.324,
#               'longitude': 146.1647,
#               'surface_temperature_celcius': 46.0,
#               'time': datetime.datetime(2018, 4, 2, 0, 24, 50)}}
# {'hotspots': {'confidence': 69.0,
#               'latitude': -37.8668,
#               'longitude': 143.0472,
#               'surface_temperature_celcius': 44.0,
#               'time': datetime.datetime(2018, 4, 3, 3, 53, 50)}}
# {'hotspots': {'confidence': 68.0,
#               'latitude': -37.7602,
#               'longitude': 143.382,
#               'surface_temperature_celcius': 44.0,
#               'time': datetime.datetime(2018, 4, 3, 3, 53, 40)}}
# {'hotspots': {'confidence': 66.0,
#               'latitude': -37.7885,
#               'longitude': 142.9509,
#               'surface_temperature_celcius': 43.0,
#               'time': datetime.datetime(2018, 4, 3, 3, 53, 30)}}
# {'hotspots': {'confidence': 66.0,
#               'latitude': -37.8717,
#               'longitude': 143.2566,
#               'surface_temperature_celcius': 43.0,
#               'time': datetime.datetime(2018, 4, 3, 3, 52, 10)}}
# {'hotspots': {'confidence': 67.0,
#               'latitude': -37.8011,
#               'longitude': 144.7343,
#               'surface_temperature_celcius': 44.0,
#               'time': datetime.datetime(2018, 4, 3, 3, 51, 10)}}
# {'hotspots': {'confidence': 67.0,
#               'latitude': -37.0241,
#               'longitude': 141.5163,
#               'surface_temperature_celcius': 43.0,
#               'time': datetime.datetime(2018, 4, 3, 3, 50, 50)}}
# {'hotspots': {'confidence': 66.0,
#               'latitude': -37.2912,
#               'longitude': 143.543,
#               'surface_temperature_celcius': 43.0,
#               'time': datetime.datetime(2018, 4, 3, 3, 50, 50)}}
# {'hotspots': {'confidence': 52.0,
#               'latitude': -37.313,
#               'longitude': 146.1561,
#               'surface_temperature_celcius': 46.0,
#               'time': datetime.datetime(2018, 4, 3, 3, 50, 50)}}
# {'hotspots': {'confidence': 56.0,
#               'latitude': -38.0226,
#               'longitude': 143.6739,
#               'surface_temperature_celcius': 39.0,
#               'time': datetime.datetime(2018, 4, 3, 3, 50, 50)}}
# {'hotspots': {'confidence': 56.0,
#               'latitude': -37.8089,
#               'longitude': 145.9555,
#               'surface_temperature_celcius': 41.0,
#               'time': datetime.datetime(2018, 4, 3, 3, 50, 40)}}
# {'hotspots': {'confidence': 62.0,
#               'latitude': -37.9009,
#               'longitude': 143.6217,
#               'surface_temperature_celcius': 45.0,
#               'time': datetime.datetime(2018, 4, 3, 3, 50, 40)}}
# {'hotspots': {'confidence': 69.0,
#               'latitude': -37.7836,
#               'longitude': 142.9437,
#               'surface_temperature_celcius': 44.0,
#               'time': datetime.datetime(2018, 4, 3, 3, 50, 40)}}
# {'hotspots': {'confidence': 52.0,
#               'latitude': -37.0484,
#               'longitude': 141.6245,
#               'surface_temperature_celcius': 42.0,
#               'time': datetime.datetime(2018, 4, 3, 3, 50, 40)}}
# {'hotspots': {'confidence': 68.0,
#               'latitude': -36.911,
#               'longitude': 142.1445,
#               'surface_temperature_celcius': 47.0,
#               'time': datetime.datetime(2018, 4, 3, 3, 50, 40)}}
# {'hotspots': {'confidence': 67.0,
#               'latitude': -34.2536,
#               'longitude': 141.6199,
#               'surface_temperature_celcius': 46.0,
#               'time': datetime.datetime(2018, 4, 3, 1, 11)}}
# {'hotspots': {'confidence': 57.0,
#               'latitude': -34.2614,
#               'longitude': 141.6412,
#               'surface_temperature_celcius': 43.0,
#               'time': datetime.datetime(2018, 4, 3, 1, 7)}}
# {'hotspots': {'confidence': 63.0,
#               'latitude': -36.0933,
#               'longitude': 141.7154,
#               'surface_temperature_celcius': 35.0,
#               'time': datetime.datetime(2018, 4, 4, 15, 30, 40)}}
# {'hotspots': {'confidence': 64.0,
#               'latitude': -36.6281,
#               'longitude': 142.4349,
#               'surface_temperature_celcius': 68.0,
#               'time': datetime.datetime(2018, 4, 4, 4, 39, 50)}}
# {'hotspots': {'confidence': 61.0,
#               'latitude': -36.937,
#               'longitude': 142.1176,
#               'surface_temperature_celcius': 50.0,
#               'time': datetime.datetime(2018, 4, 4, 4, 39, 40)}}
# {'hotspots': {'confidence': 50.0,
#               'latitude': -36.6951,
#               'longitude': 145.424,
#               'surface_temperature_celcius': 43.0,
#               'time': datetime.datetime(2018, 4, 4, 4, 38, 10)}}
# {'hotspots': {'confidence': 67.0,
#               'latitude': -37.6714,
#               'longitude': 144.2154,
#               'surface_temperature_celcius': 46.0,
#               'time': datetime.datetime(2018, 4, 4, 4, 36, 30)}}
# {'hotspots': {'confidence': 63.0,
#               'latitude': -38.0494,
#               'longitude': 143.9141,
#               'surface_temperature_celcius': 58.0,
#               'time': datetime.datetime(2018, 4, 4, 4, 36, 30)}}
# {'hotspots': {'confidence': 54.0,
#               'latitude': -38.4879,
#               'longitude': 143.9971,
#               'surface_temperature_celcius': 40.0,
#               'time': datetime.datetime(2018, 4, 4, 4, 34, 20)}}
# {'hotspots': {'confidence': 63.0,
#               'latitude': -37.1744,
#               'longitude': 143.9256,
#               'surface_temperature_celcius': 43.0,
#               'time': datetime.datetime(2018, 4, 4, 4, 33, 30)}}
# {'hotspots': {'confidence': 69.0,
#               'latitude': -36.4918,
#               'longitude': 142.2465,
#               'surface_temperature_celcius': 54.0,
#               'time': datetime.datetime(2018, 4, 4, 4, 33, 30)}}
# {'hotspots': {'confidence': 66.0,
#               'latitude': -36.6299,
#               'longitude': 142.4234,
#               'surface_temperature_celcius': 71.0,
#               'time': datetime.datetime(2018, 4, 4, 4, 33, 10)}}
# {'hotspots': {'confidence': 53.0,
#               'latitude': -36.1439,
#               'longitude': 145.832,
#               'surface_temperature_celcius': 50.0,
#               'time': datetime.datetime(2018, 4, 4, 4, 33, 10)}}
# {'hotspots': {'confidence': 54.0,
#               'latitude': -36.7009,
#               'longitude': 141.541,
#               'surface_temperature_celcius': 49.0,
#               'time': datetime.datetime(2018, 4, 4, 4, 32, 50)}}
# {'hotspots': {'confidence': 55.0,
#               'latitude': -36.4611,
#               'longitude': 143.146,
#               'surface_temperature_celcius': 48.0,
#               'time': datetime.datetime(2018, 4, 4, 4, 32, 40)}}
# {'hotspots': {'confidence': 53.0,
#               'latitude': -36.3539,
#               'longitude': 142.1894,
#               'surface_temperature_celcius': 53.0,
#               'time': datetime.datetime(2018, 4, 4, 4, 32, 40)}}
# {'hotspots': {'confidence': 66.0,
#               'latitude': -37.0081,
#               'longitude': 141.7654,
#               'surface_temperature_celcius': 62.0,
#               'time': datetime.datetime(2018, 4, 4, 4, 32, 40)}}
# {'hotspots': {'confidence': 64.0,
#               'latitude': -36.2889,
#               'longitude': 141.7692,
#               'surface_temperature_celcius': 51.0,
#               'time': datetime.datetime(2018, 4, 4, 4, 32, 40)}}
# {'hotspots': {'confidence': 67.0,
#               'latitude': -36.6228,
#               'longitude': 142.428,
#               'surface_temperature_celcius': 43.0,
#               'time': datetime.datetime(2018, 4, 4, 4, 32, 40)}}
# {'hotspots': {'confidence': 60.0,
#               'latitude': -38.1177,
#               'longitude': 143.6409,
#               'surface_temperature_celcius': 40.0,
#               'time': datetime.datetime(2018, 4, 4, 4, 32, 40)}}
# {'hotspots': {'confidence': 61.0,
#               'latitude': -38.3499,
#               'longitude': 147.033,
#               'surface_temperature_celcius': 35.0,
#               'time': datetime.datetime(2018, 4, 5, 13, 10, 10)}}
# {'hotspots': {'confidence': 66.0,
#               'latitude': -37.6435,
#               'longitude': 146.1417,
#               'surface_temperature_celcius': 36.0,
#               'time': datetime.datetime(2018, 4, 5, 13, 2, 40)}}
# {'hotspots': {'confidence': 66.0,
#               'latitude': -37.7522,
#               'longitude': 142.3183,
#               'surface_temperature_celcius': 50.0,
#               'time': datetime.datetime(2018, 4, 5, 5, 15, 40)}}
# {'hotspots': {'confidence': 66.0,
#               'latitude': -36.9396,
#               'longitude': 141.9303,
#               'surface_temperature_celcius': 45.0,
#               'time': datetime.datetime(2018, 4, 5, 5, 15, 30)}}
# {'hotspots': {'confidence': 65.0,
#               'latitude': -37.78,
#               'longitude': 141.8091,
#               'surface_temperature_celcius': 42.0,
#               'time': datetime.datetime(2018, 4, 5, 3, 45, 10)}}
# {'hotspots': {'confidence': 68.0,
#               'latitude': -37.7767,
#               'longitude': 141.8127,
#               'surface_temperature_celcius': 44.0,
#               'time': datetime.datetime(2018, 4, 5, 3, 44, 40)}}
# {'hotspots': {'confidence': 65.0,
#               'latitude': -38.1756,
#               'longitude': 143.9829,
#               'surface_temperature_celcius': 53.0,
#               'time': datetime.datetime(2018, 4, 5, 3, 44, 30)}}
# {'hotspots': {'confidence': 50.0,
#               'latitude': -38.3553,
#               'longitude': 147.0231,
#               'surface_temperature_celcius': 38.0,
#               'time': datetime.datetime(2018, 4, 5, 3, 40, 30)}}
# {'hotspots': {'confidence': 64.0,
#               'latitude': -36.934,
#               'longitude': 142.5759,
#               'surface_temperature_celcius': 47.0,
#               'time': datetime.datetime(2018, 4, 5, 3, 40, 30)}}
# {'hotspots': {'confidence': 59.0,
#               'latitude': -38.0383,
#               'longitude': 144.4307,
#               'surface_temperature_celcius': 40.0,
#               'time': datetime.datetime(2018, 4, 5, 3, 39, 10)}}
# {'hotspots': {'confidence': 69.0,
#               'latitude': -36.9354,
#               'longitude': 142.5807,
#               'surface_temperature_celcius': 45.0,
#               'time': datetime.datetime(2018, 4, 5, 3, 39, 10)}}
# {'hotspots': {'confidence': 68.0,
#               'latitude': -36.9405,
#               'longitude': 142.8627,
#               'surface_temperature_celcius': 44.0,
#               'time': datetime.datetime(2018, 4, 5, 3, 39, 10)}}
# {'hotspots': {'confidence': 69.0,
#               'latitude': -37.6339,
#               'longitude': 143.4108,
#               'surface_temperature_celcius': 46.0,
#               'time': datetime.datetime(2018, 4, 5, 3, 39, 10)}}
# {'hotspots': {'confidence': 66.0,
#               'latitude': -37.7069,
#               'longitude': 142.1573,
#               'surface_temperature_celcius': 53.0,
#               'time': datetime.datetime(2018, 4, 6, 4, 25, 40)}}
# {'hotspots': {'confidence': 50.0,
#               'latitude': -36.0834,
#               'longitude': 146.5364,
#               'surface_temperature_celcius': 53.0,
#               'time': datetime.datetime(2018, 4, 6, 4, 25, 40)}}
# {'hotspots': {'confidence': 62.0,
#               'latitude': -36.3557,
#               'longitude': 141.3268,
#               'surface_temperature_celcius': 52.0,
#               'time': datetime.datetime(2018, 4, 6, 4, 23, 50)}}
# {'hotspots': {'confidence': 62.0,
#               'latitude': -37.6104,
#               'longitude': 147.8367,
#               'surface_temperature_celcius': 42.0,
#               'time': datetime.datetime(2018, 4, 6, 4, 23, 50)}}
# {'hotspots': {'confidence': 64.0,
#               'latitude': -37.9229,
#               'longitude': 143.647,
#               'surface_temperature_celcius': 63.0,
#               'time': datetime.datetime(2018, 4, 6, 4, 23, 50)}}
# {'hotspots': {'confidence': 62.0,
#               'latitude': -37.5052,
#               'longitude': 142.8636,
#               'surface_temperature_celcius': 54.0,
#               'time': datetime.datetime(2018, 4, 6, 4, 23, 50)}}
# {'hotspots': {'confidence': 51.0,
#               'latitude': -37.8177,
#               'longitude': 142.9168,
#               'surface_temperature_celcius': 50.0,
#               'time': datetime.datetime(2018, 4, 6, 4, 22, 20)}}
# {'hotspots': {'confidence': 65.0,
#               'latitude': -37.5842,
#               'longitude': 148.5717,
#               'surface_temperature_celcius': 49.0,
#               'time': datetime.datetime(2018, 4, 6, 4, 21, 20)}}
# {'hotspots': {'confidence': 64.0,
#               'latitude': -38.0089,
#               'longitude': 143.8976,
#               'surface_temperature_celcius': 45.0,
#               'time': datetime.datetime(2018, 4, 6, 4, 21)}}
# {'hotspots': {'confidence': 58.0,
#               'latitude': -37.3072,
#               'longitude': 147.5003,
#               'surface_temperature_celcius': 46.0,
#               'time': datetime.datetime(2018, 4, 6, 4, 21)}}
# {'hotspots': {'confidence': 50.0,
#               'latitude': -37.3556,
#               'longitude': 146.1085,
#               'surface_temperature_celcius': 47.0,
#               'time': datetime.datetime(2018, 4, 6, 4, 20, 50)}}
# {'hotspots': {'confidence': 59.0,
#               'latitude': -37.6806,
#               'longitude': 143.2676,
#               'surface_temperature_celcius': 51.0,
#               'time': datetime.datetime(2018, 4, 6, 4, 20, 40)}}
# {'hotspots': {'confidence': 58.0,
#               'latitude': -37.7212,
#               'longitude': 145.9754,
#               'surface_temperature_celcius': 52.0,
#               'time': datetime.datetime(2018, 4, 6, 4, 20, 40)}}
# {'hotspots': {'confidence': 59.0,
#               'latitude': -38.3343,
#               'longitude': 143.8644,
#               'surface_temperature_celcius': 43.0,
#               'time': datetime.datetime(2018, 4, 6, 4, 20, 40)}}
# {'hotspots': {'confidence': 64.0,
#               'latitude': -35.723,
#               'longitude': 142.063,
#               'surface_temperature_celcius': 54.0,
#               'time': datetime.datetime(2018, 4, 6, 4, 20, 40)}}
# {'hotspots': {'confidence': 50.0,
#               'latitude': -35.1383,
#               'longitude': 141.8172,
#               'surface_temperature_celcius': 53.0,
#               'time': datetime.datetime(2018, 4, 6, 4, 20, 40)}}
# {'hotspots': {'confidence': 52.0,
#               'latitude': -36.4133,
#               'longitude': 141.0286,
#               'surface_temperature_celcius': 47.0,
#               'time': datetime.datetime(2018, 4, 6, 4, 20, 40)}}
# {'hotspots': {'confidence': 66.0,
#               'latitude': -36.6492,
#               'longitude': 142.3976,
#               'surface_temperature_celcius': 60.0,
#               'time': datetime.datetime(2018, 4, 6, 4, 20, 40)}}
# {'hotspots': {'confidence': 69.0,
#               'latitude': -36.0765,
#               'longitude': 146.4896,
#               'surface_temperature_celcius': 46.0,
#               'time': datetime.datetime(2018, 4, 6, 4, 20, 40)}}
# {'hotspots': {'confidence': 57.0,
#               'latitude': -36.0799,
#               'longitude': 146.529,
#               'surface_temperature_celcius': 44.0,
#               'time': datetime.datetime(2018, 4, 6, 4, 20, 40)}}
# {'hotspots': {'confidence': 60.0,
#               'latitude': -36.8632,
#               'longitude': 142.5802,
#               'surface_temperature_celcius': 60.0,
#               'time': datetime.datetime(2018, 4, 6, 4, 20, 40)}}
# {'hotspots': {'confidence': 59.0,
#               'latitude': -37.1929,
#               'longitude': 143.8132,
#               'surface_temperature_celcius': 45.0,
#               'time': datetime.datetime(2018, 4, 6, 4, 20, 40)}}
# {'hotspots': {'confidence': 68.0,
#               'latitude': -37.1992,
#               'longitude': 146.2301,
#               'surface_temperature_celcius': 60.0,
#               'time': datetime.datetime(2018, 4, 6, 4, 20, 40)}}
# {'hotspots': {'confidence': 63.0,
#               'latitude': -37.5914,
#               'longitude': 148.5807,
#               'surface_temperature_celcius': 61.0,
#               'time': datetime.datetime(2018, 4, 6, 4, 20, 40)}}
# {'hotspots': {'confidence': 64.0,
#               'latitude': -37.7496,
#               'longitude': 148.3898,
#               'surface_temperature_celcius': 46.0,
#               'time': datetime.datetime(2018, 4, 6, 4, 20, 40)}}
# {'hotspots': {'confidence': 67.0,
#               'latitude': -35.4625,
#               'longitude': 143.1486,
#               'surface_temperature_celcius': 44.0,
#               'time': datetime.datetime(2018, 4, 6, 0, 3, 50)}}
# {'hotspots': {'confidence': 52.0,
#               'latitude': -38.0942,
#               'longitude': 146.9603,
#               'surface_temperature_celcius': 39.0,
#               'time': datetime.datetime(2018, 4, 6, 0, 1, 40)}}
# {'hotspots': {'confidence': 61.0,
#               'latitude': -35.6961,
#               'longitude': 143.1935,
#               'surface_temperature_celcius': 35.0,
#               'time': datetime.datetime(2018, 4, 7, 12, 53, 40)}}
# {'hotspots': {'confidence': 65.0,
#               'latitude': -37.3314,
#               'longitude': 149.1283,
#               'surface_temperature_celcius': 35.0,
#               'time': datetime.datetime(2018, 4, 7, 12, 52, 10)}}
# {'hotspots': {'confidence': 51.0,
#               'latitude': -37.3359,
#               'longitude': 149.3816,
#               'surface_temperature_celcius': 48.0,
#               'time': datetime.datetime(2018, 4, 7, 12, 51, 20)}}
# {'hotspots': {'confidence': 66.0,
#               'latitude': -37.3526,
#               'longitude': 149.3972,
#               'surface_temperature_celcius': 43.0,
#               'time': datetime.datetime(2018, 4, 7, 12, 51)}}
# {'hotspots': {'confidence': 68.0,
#               'latitude': -37.3344,
#               'longitude': 149.3933,
#               'surface_temperature_celcius': 47.0,
#               'time': datetime.datetime(2018, 4, 7, 12, 50, 40)}}
# {'hotspots': {'confidence': 61.0,
#               'latitude': -37.3511,
#               'longitude': 149.4088,
#               'surface_temperature_celcius': 46.0,
#               'time': datetime.datetime(2018, 4, 7, 12, 50, 40)}}
# {'hotspots': {'confidence': 66.0,
#               'latitude': -36.7508,
#               'longitude': 147.1254,
#               'surface_temperature_celcius': 39.0,
#               'time': datetime.datetime(2018, 4, 7, 12, 50, 40)}}
# {'hotspots': {'confidence': 63.0,
#               'latitude': -36.1031,
#               'longitude': 143.0782,
#               'surface_temperature_celcius': 45.0,
#               'time': datetime.datetime(2018, 4, 7, 5, 3, 10)}}
# {'hotspots': {'confidence': 66.0,
#               'latitude': -36.1025,
#               'longitude': 143.0825,
#               'surface_temperature_celcius': 43.0,
#               'time': datetime.datetime(2018, 4, 7, 5, 3, 10)}}
# {'hotspots': {'confidence': 67.0,
#               'latitude': -36.7314,
#               'longitude': 141.8698,
#               'surface_temperature_celcius': 44.0,
#               'time': datetime.datetime(2018, 4, 7, 5, 3, 10)}}
# {'hotspots': {'confidence': 64.0,
#               'latitude': -37.7931,
#               'longitude': 148.385,
#               'surface_temperature_celcius': 58.0,
#               'time': datetime.datetime(2018, 4, 7, 3, 31, 40)}}
# {'hotspots': {'confidence': 60.0,
#               'latitude': -37.7974,
#               'longitude': 148.5498,
#               'surface_temperature_celcius': 53.0,
#               'time': datetime.datetime(2018, 4, 7, 3, 27, 50)}}
# {'hotspots': {'confidence': 67.0,
#               'latitude': -37.34,
#               'longitude': 149.3668,
#               'surface_temperature_celcius': 74.0,
#               'time': datetime.datetime(2018, 4, 8, 4, 15, 20)}}
# {'hotspots': {'confidence': 62.0,
#               'latitude': -37.8567,
#               'longitude': 147.1576,
#               'surface_temperature_celcius': 48.0,
#               'time': datetime.datetime(2018, 4, 8, 4, 14, 40)}}
# {'hotspots': {'confidence': 56.0,
#               'latitude': -37.4368,
#               'longitude': 149.1191,
#               'surface_temperature_celcius': 52.0,
#               'time': datetime.datetime(2018, 4, 8, 4, 12, 20)}}
# {'hotspots': {'confidence': 58.0,
#               'latitude': -37.9408,
#               'longitude': 146.0611,
#               'surface_temperature_celcius': 47.0,
#               'time': datetime.datetime(2018, 4, 8, 4, 11, 40)}}
# {'hotspots': {'confidence': 59.0,
#               'latitude': -37.6994,
#               'longitude': 146.2162,
#               'surface_temperature_celcius': 40.0,
#               'time': datetime.datetime(2018, 4, 8, 4, 9, 20)}}
# {'hotspots': {'confidence': 63.0,
#               'latitude': -36.7199,
#               'longitude': 142.5844,
#               'surface_temperature_celcius': 56.0,
#               'time': datetime.datetime(2018, 4, 8, 4, 8, 50)}}
# {'hotspots': {'confidence': 66.0,
#               'latitude': -37.3493,
#               'longitude': 149.3691,
#               'surface_temperature_celcius': 80.0,
#               'time': datetime.datetime(2018, 4, 8, 4, 8, 40)}}
# {'hotspots': {'confidence': 61.0,
#               'latitude': -37.6447,
#               'longitude': 148.6039,
#               'surface_temperature_celcius': 50.0,
#               'time': datetime.datetime(2018, 4, 8, 4, 8, 40)}}
# {'hotspots': {'confidence': 67.0,
#               'latitude': -36.2282,
#               'longitude': 145.9074,
#               'surface_temperature_celcius': 43.0,
#               'time': datetime.datetime(2018, 4, 11, 4, 50, 20)}}
# {'hotspots': {'confidence': 53.0,
#               'latitude': -36.3499,
#               'longitude': 146.1402,
#               'surface_temperature_celcius': 41.0,
#               'time': datetime.datetime(2018, 4, 11, 4, 42, 10)}}
# {'hotspots': {'confidence': 56.0,
#               'latitude': -36.4439,
#               'longitude': 145.8846,
#               'surface_temperature_celcius': 39.0,
#               'time': datetime.datetime(2018, 4, 11, 4, 40, 30)}}
# {'hotspots': {'confidence': 57.0,
#               'latitude': -36.0818,
#               'longitude': 146.5461,
#               'surface_temperature_celcius': 44.0,
#               'time': datetime.datetime(2018, 4, 11, 4, 39, 40)}}
# {'hotspots': {'confidence': 50.0,
#               'latitude': -36.343,
#               'longitude': 143.3479,
#               'surface_temperature_celcius': 40.0,
#               'time': datetime.datetime(2018, 4, 11, 4, 38, 50)}}
# {'hotspots': {'confidence': 67.0,
#               'latitude': -36.1751,
#               'longitude': 142.7831,
#               'surface_temperature_celcius': 43.0,
#               'time': datetime.datetime(2018, 4, 11, 4, 38, 50)}}
# {'hotspots': {'confidence': 55.0,
#               'latitude': -36.4606,
#               'longitude': 141.0562,
#               'surface_temperature_celcius': 39.0,
#               'time': datetime.datetime(2018, 4, 11, 4, 38, 50)}}
# {'hotspots': {'confidence': 66.0,
#               'latitude': -36.0156,
#               'longitude': 143.2188,
#               'surface_temperature_celcius': 43.0,
#               'time': datetime.datetime(2018, 4, 11, 4, 38, 50)}}
# {'hotspots': {'confidence': 62.0,
#               'latitude': -36.1398,
#               'longitude': 141.7793,
#               'surface_temperature_celcius': 47.0,
#               'time': datetime.datetime(2018, 4, 11, 4, 38, 50)}}
# {'hotspots': {'confidence': 68.0,
#               'latitude': -35.2068,
#               'longitude': 143.2912,
#               'surface_temperature_celcius': 44.0,
#               'time': datetime.datetime(2018, 4, 11, 4, 38, 50)}}
# {'hotspots': {'confidence': 63.0,
#               'latitude': -36.3579,
#               'longitude': 146.1268,
#               'surface_temperature_celcius': 42.0,
#               'time': datetime.datetime(2018, 4, 11, 4, 38, 50)}}
# {'hotspots': {'confidence': 60.0,
#               'latitude': -36.0787,
#               'longitude': 146.5728,
#               'surface_temperature_celcius': 40.0,
#               'time': datetime.datetime(2018, 4, 11, 4, 38, 50)}}
# {'hotspots': {'confidence': 62.0,
#               'latitude': -37.9796,
#               'longitude': 146.8024,
#               'surface_temperature_celcius': 41.0,
#               'time': datetime.datetime(2018, 4, 11, 0, 20, 30)}}
# {'hotspots': {'confidence': 67.0,
#               'latitude': -35.4309,
#               'longitude': 142.3626,
#               'surface_temperature_celcius': 36.0,
#               'time': datetime.datetime(2018, 4, 12, 13, 13, 10)}}
# {'hotspots': {'confidence': 57.0,
#               'latitude': -35.4407,
#               'longitude': 142.3644,
#               'surface_temperature_celcius': 35.0,
#               'time': datetime.datetime(2018, 4, 12, 13, 9, 20)}}
# {'hotspots': {'confidence': 67.0,
#               'latitude': -37.4755,
#               'longitude': 142.6339,
#               'surface_temperature_celcius': 43.0,
#               'time': datetime.datetime(2018, 4, 12, 5, 28)}}
# {'hotspots': {'confidence': 54.0,
#               'latitude': -36.7453,
#               'longitude': 141.4578,
#               'surface_temperature_celcius': 39.0,
#               'time': datetime.datetime(2018, 4, 12, 5, 26, 50)}}
# {'hotspots': {'confidence': 50.0,
#               'latitude': -36.7038,
#               'longitude': 141.0498,
#               'surface_temperature_celcius': 39.0,
#               'time': datetime.datetime(2018, 4, 12, 5, 25)}}
# {'hotspots': {'confidence': 60.0,
#               'latitude': -37.7578,
#               'longitude': 142.227,
#               'surface_temperature_celcius': 40.0,
#               'time': datetime.datetime(2018, 4, 12, 5, 21, 50)}}
# {'hotspots': {'confidence': 67.0,
#               'latitude': -36.8083,
#               'longitude': 142.0219,
#               'surface_temperature_celcius': 44.0,
#               'time': datetime.datetime(2018, 4, 12, 5, 21, 40)}}
# {'hotspots': {'confidence': 61.0,
#               'latitude': -36.714,
#               'longitude': 141.1485,
#               'surface_temperature_celcius': 41.0,
#               'time': datetime.datetime(2018, 4, 12, 5, 21, 40)}}
# {'hotspots': {'confidence': 68.0,
#               'latitude': -36.6385,
#               'longitude': 142.5297,
#               'surface_temperature_celcius': 44.0,
#               'time': datetime.datetime(2018, 4, 12, 3, 51)}}
# {'hotspots': {'confidence': 59.0,
#               'latitude': -36.9179,
#               'longitude': 141.3095,
#               'surface_temperature_celcius': 40.0,
#               'time': datetime.datetime(2018, 4, 12, 3, 50, 10)}}
# {'hotspots': {'confidence': 65.0,
#               'latitude': -37.3654,
#               'longitude': 143.8156,
#               'surface_temperature_celcius': 42.0,
#               'time': datetime.datetime(2018, 4, 12, 3, 46, 50)}}
# {'hotspots': {'confidence': 69.0,
#               'latitude': -36.6188,
#               'longitude': 144.0402,
#               'surface_temperature_celcius': 44.0,
#               'time': datetime.datetime(2018, 4, 12, 3, 46, 20)}}
# {'hotspots': {'confidence': 69.0,
#               'latitude': -37.4047,
#               'longitude': 143.6615,
#               'surface_temperature_celcius': 45.0,
#               'time': datetime.datetime(2018, 4, 12, 3, 46)}}
# {'hotspots': {'confidence': 65.0,
#               'latitude': -36.2367,
#               'longitude': 141.3998,
#               'surface_temperature_celcius': 42.0,
#               'time': datetime.datetime(2018, 4, 12, 3, 46)}}
# {'hotspots': {'confidence': 62.0,
#               'latitude': -36.5234,
#               'longitude': 144.6939,
#               'surface_temperature_celcius': 41.0,
#               'time': datetime.datetime(2018, 4, 12, 3, 45, 10)}}
# {'hotspots': {'confidence': 60.0,
#               'latitude': -36.6803,
#               'longitude': 141.0957,
#               'surface_temperature_celcius': 44.0,
#               'time': datetime.datetime(2018, 4, 12, 3, 45)}}
# {'hotspots': {'confidence': 65.0,
#               'latitude': -36.7866,
#               'longitude': 142.1989,
#               'surface_temperature_celcius': 42.0,
#               'time': datetime.datetime(2018, 4, 12, 3, 44, 50)}}
# {'hotspots': {'confidence': 65.0,
#               'latitude': -36.6292,
#               'longitude': 143.8862,
#               'surface_temperature_celcius': 43.0,
#               'time': datetime.datetime(2018, 4, 12, 3, 44, 40)}}
# {'hotspots': {'confidence': 68.0,
#               'latitude': -35.7937,
#               'longitude': 143.195,
#               'surface_temperature_celcius': 44.0,
#               'time': datetime.datetime(2018, 4, 12, 3, 44, 40)}}
# {'hotspots': {'confidence': 57.0,
#               'latitude': -36.9142,
#               'longitude': 141.3013,
#               'surface_temperature_celcius': 40.0,
#               'time': datetime.datetime(2018, 4, 12, 3, 44, 40)}}
# {'hotspots': {'confidence': 68.0,
#               'latitude': -36.6306,
#               'longitude': 143.8908,
#               'surface_temperature_celcius': 44.0,
#               'time': datetime.datetime(2018, 4, 12, 3, 44, 40)}}
# {'hotspots': {'confidence': 59.0,
#               'latitude': -37.3586,
#               'longitude': 142.9087,
#               'surface_temperature_celcius': 40.0,
#               'time': datetime.datetime(2018, 4, 12, 3, 44, 40)}}
# {'hotspots': {'confidence': 60.0,
#               'latitude': -36.9524,
#               'longitude': 143.7501,
#               'surface_temperature_celcius': 40.0,
#               'time': datetime.datetime(2018, 4, 12, 3, 44, 40)}}
# {'hotspots': {'confidence': 50.0,
#               'latitude': -37.0643,
#               'longitude': 141.8567,
#               'surface_temperature_celcius': 40.0,
#               'time': datetime.datetime(2018, 4, 12, 3, 44, 40)}}
# {'hotspots': {'confidence': 64.0,
#               'latitude': -36.2403,
#               'longitude': 141.4047,
#               'surface_temperature_celcius': 42.0,
#               'time': datetime.datetime(2018, 4, 12, 3, 44, 40)}}
# {'hotspots': {'confidence': 56.0,
#               'latitude': -36.6776,
#               'longitude': 141.0877,
#               'surface_temperature_celcius': 44.0,
#               'time': datetime.datetime(2018, 4, 12, 3, 44, 40)}}
# {'hotspots': {'confidence': 64.0,
#               'latitude': -37.7929,
#               'longitude': 143.1197,
#               'surface_temperature_celcius': 42.0,
#               'time': datetime.datetime(2018, 4, 12, 3, 44, 40)}}
# {'hotspots': {'confidence': 64.0,
#               'latitude': -37.7972,
#               'longitude': 143.1153,
#               'surface_temperature_celcius': 42.0,
#               'time': datetime.datetime(2018, 4, 12, 3, 44, 40)}}
# {'hotspots': {'confidence': 59.0,
#               'latitude': -37.3656,
#               'longitude': 143.8206,
#               'surface_temperature_celcius': 40.0,
#               'time': datetime.datetime(2018, 4, 12, 3, 44, 40)}}
# {'hotspots': {'confidence': 68.0,
#               'latitude': -37.8865,
#               'longitude': 143.3048,
#               'surface_temperature_celcius': 44.0,
#               'time': datetime.datetime(2018, 4, 13, 4, 36, 30)}}
# {'hotspots': {'confidence': 62.0,
#               'latitude': -37.5687,
#               'longitude': 143.2121,
#               'surface_temperature_celcius': 41.0,
#               'time': datetime.datetime(2018, 4, 13, 4, 36, 20)}}
# {'hotspots': {'confidence': 68.0,
#               'latitude': -37.7359,
#               'longitude': 143.0108,
#               'surface_temperature_celcius': 44.0,
#               'time': datetime.datetime(2018, 4, 13, 4, 34, 50)}}
# {'hotspots': {'confidence': 69.0,
#               'latitude': -37.1009,
#               'longitude': 141.9666,
#               'surface_temperature_celcius': 45.0,
#               'time': datetime.datetime(2018, 4, 13, 4, 33, 50)}}
# {'hotspots': {'confidence': 69.0,
#               'latitude': -36.9211,
#               'longitude': 143.6017,
#               'surface_temperature_celcius': 44.0,
#               'time': datetime.datetime(2018, 4, 13, 4, 33, 50)}}
# {'hotspots': {'confidence': 64.0,
#               'latitude': -38.211,
#               'longitude': 143.9122,
#               'surface_temperature_celcius': 42.0,
#               'time': datetime.datetime(2018, 4, 13, 4, 33, 30)}}
# {'hotspots': {'confidence': 59.0,
#               'latitude': -37.7576,
#               'longitude': 142.465,
#               'surface_temperature_celcius': 40.0,
#               'time': datetime.datetime(2018, 4, 13, 4, 33, 30)}}
# {'hotspots': {'confidence': 57.0,
#               'latitude': -38.0505,
#               'longitude': 142.4791,
#               'surface_temperature_celcius': 40.0,
#               'time': datetime.datetime(2018, 4, 13, 4, 33, 20)}}
# {'hotspots': {'confidence': 52.0,
#               'latitude': -37.7851,
#               'longitude': 141.4593,
#               'surface_temperature_celcius': 38.0,
#               'time': datetime.datetime(2018, 4, 13, 4, 33, 10)}}
# {'hotspots': {'confidence': 62.0,
#               'latitude': -37.9075,
#               'longitude': 142.6403,
#               'surface_temperature_celcius': 41.0,
#               'time': datetime.datetime(2018, 4, 13, 4, 33, 10)}}
# {'hotspots': {'confidence': 50.0,
#               'latitude': -37.8345,
#               'longitude': 142.447,
#               'surface_temperature_celcius': 38.0,
#               'time': datetime.datetime(2018, 4, 13, 4, 33, 10)}}
# {'hotspots': {'confidence': 69.0,
#               'latitude': -36.8573,
#               'longitude': 143.5278,
#               'surface_temperature_celcius': 45.0,
#               'time': datetime.datetime(2018, 4, 13, 4, 31, 30)}}
# {'hotspots': {'confidence': 63.0,
#               'latitude': -37.0207,
#               'longitude': 141.4778,
#               'surface_temperature_celcius': 41.0,
#               'time': datetime.datetime(2018, 4, 13, 4, 29, 50)}}
# {'hotspots': {'confidence': 59.0,
#               'latitude': -37.6857,
#               'longitude': 142.8532,
#               'surface_temperature_celcius': 40.0,
#               'time': datetime.datetime(2018, 4, 13, 4, 29, 40)}}
# {'hotspots': {'confidence': 69.0,
#               'latitude': -37.2709,
#               'longitude': 143.9659,
#               'surface_temperature_celcius': 45.0,
#               'time': datetime.datetime(2018, 4, 13, 4, 29, 40)}}
# {'hotspots': {'confidence': 69.0,
#               'latitude': -37.5632,
#               'longitude': 142.2864,
#               'surface_temperature_celcius': 45.0,
#               'time': datetime.datetime(2018, 4, 13, 4, 29, 40)}}
# {'hotspots': {'confidence': 65.0,
#               'latitude': -36.3305,
#               'longitude': 146.049,
#               'surface_temperature_celcius': 46.0,
#               'time': datetime.datetime(2018, 4, 13, 4, 29, 30)}}
# {'hotspots': {'confidence': 68.0,
#               'latitude': -38.0132,
#               'longitude': 143.2528,
#               'surface_temperature_celcius': 44.0,
#               'time': datetime.datetime(2018, 4, 13, 4, 29, 20)}}
# {'hotspots': {'confidence': 57.0,
#               'latitude': -38.0643,
#               'longitude': 143.6616,
#               'surface_temperature_celcius': 43.0,
#               'time': datetime.datetime(2018, 4, 13, 4, 28, 30)}}
# {'hotspots': {'confidence': 67.0,
#               'latitude': -37.9898,
#               'longitude': 143.8507,
#               'surface_temperature_celcius': 43.0,
#               'time': datetime.datetime(2018, 4, 13, 4, 28, 30)}}
# {'hotspots': {'confidence': 69.0,
#               'latitude': -37.0667,
#               'longitude': 143.0582,
#               'surface_temperature_celcius': 44.0,
#               'time': datetime.datetime(2018, 4, 13, 4, 28, 10)}}
# {'hotspots': {'confidence': 60.0,
#               'latitude': -37.7836,
#               'longitude': 141.4711,
#               'surface_temperature_celcius': 40.0,
#               'time': datetime.datetime(2018, 4, 13, 4, 27, 40)}}
# {'hotspots': {'confidence': 69.0,
#               'latitude': -36.778,
#               'longitude': 145.1635,
#               'surface_temperature_celcius': 45.0,
#               'time': datetime.datetime(2018, 4, 13, 4, 27, 30)}}
# {'hotspots': {'confidence': 69.0,
#               'latitude': -37.6008,
#               'longitude': 143.0558,
#               'surface_temperature_celcius': 44.0,
#               'time': datetime.datetime(2018, 4, 13, 4, 27, 20)}}
# {'hotspots': {'confidence': 63.0,
#               'latitude': -37.2757,
#               'longitude': 143.8126,
#               'surface_temperature_celcius': 42.0,
#               'time': datetime.datetime(2018, 4, 13, 4, 26, 50)}}
# {'hotspots': {'confidence': 58.0,
#               'latitude': -38.26,
#               'longitude': 143.9602,
#               'surface_temperature_celcius': 40.0,
#               'time': datetime.datetime(2018, 4, 13, 4, 26, 40)}}
# {'hotspots': {'confidence': 68.0,
#               'latitude': -37.9916,
#               'longitude': 143.8392,
#               'surface_temperature_celcius': 44.0,
#               'time': datetime.datetime(2018, 4, 13, 4, 26, 40)}}
# {'hotspots': {'confidence': 61.0,
#               'latitude': -37.7635,
#               'longitude': 142.8181,
#               'surface_temperature_celcius': 41.0,
#               'time': datetime.datetime(2018, 4, 13, 4, 26, 40)}}
# {'hotspots': {'confidence': 53.0,
#               'latitude': -37.7982,
#               'longitude': 142.2386,
#               'surface_temperature_celcius': 41.0,
#               'time': datetime.datetime(2018, 4, 13, 4, 26, 40)}}
# {'hotspots': {'confidence': 66.0,
#               'latitude': -37.4391,
#               'longitude': 143.0293,
#               'surface_temperature_celcius': 43.0,
#               'time': datetime.datetime(2018, 4, 13, 4, 26, 40)}}
# {'hotspots': {'confidence': 62.0,
#               'latitude': -37.6161,
#               'longitude': 141.2781,
#               'surface_temperature_celcius': 45.0,
#               'time': datetime.datetime(2018, 4, 13, 4, 26, 40)}}
# {'hotspots': {'confidence': 62.0,
#               'latitude': -36.6777,
#               'longitude': 141.37,
#               'surface_temperature_celcius': 49.0,
#               'time': datetime.datetime(2018, 4, 13, 4, 26, 30)}}
# {'hotspots': {'confidence': 61.0,
#               'latitude': -36.6701,
#               'longitude': 141.3566,
#               'surface_temperature_celcius': 50.0,
#               'time': datetime.datetime(2018, 4, 13, 4, 26, 30)}}
# {'hotspots': {'confidence': 67.0,
#               'latitude': -36.4373,
#               'longitude': 143.6328,
#               'surface_temperature_celcius': 43.0,
#               'time': datetime.datetime(2018, 4, 13, 4, 26, 30)}}
# {'hotspots': {'confidence': 69.0,
# ...
#               'latitude': -37.554,
#               'longitude': 148.073,
#               'surface_temperature_celcius': 37.0,
#               'time': datetime.datetime(2018, 9, 23, 3, 21, 19)}}
# {'hotspots': {'confidence': 59.0,
#               'latitude': -37.375,
#               'longitude': 148.063,
#               'surface_temperature_celcius': 35.0,
#               'time': datetime.datetime(2018, 9, 24, 13, 30, 9)}}
# {'hotspots': {'confidence': 58.0,
#               'latitude': -37.397,
#               'longitude': 148.121,
#               'surface_temperature_celcius': 58.0,
#               'time': datetime.datetime(2018, 9, 24, 4, 4, 19)}}
# {'hotspots': {'confidence': 68.0,
#               'latitude': -37.452,
#               'longitude': 148.115,
#               'surface_temperature_celcius': 77.0,
#               'time': datetime.datetime(2018, 9, 24, 4, 4, 18)}}
# {'hotspots': {'confidence': 68.0,
#               'latitude': -37.465,
#               'longitude': 148.153,
#               'surface_temperature_celcius': 63.0,
#               'time': datetime.datetime(2018, 9, 24, 4, 4, 18)}}
# {'hotspots': {'confidence': 64.0,
#               'latitude': -37.45,
#               'longitude': 148.126,
#               'surface_temperature_celcius': 69.0,
#               'time': datetime.datetime(2018, 9, 24, 4, 4, 18)}}
# {'hotspots': {'confidence': 61.0,
#               'latitude': -37.562,
#               'longitude': 148.05,
#               'surface_temperature_celcius': 72.0,
#               'time': datetime.datetime(2018, 9, 24, 4, 4, 17)}}
# {'hotspots': {'confidence': 56.0,
#               'latitude': -38.495,
#               'longitude': 146.944,
#               'surface_temperature_celcius': 53.0,
#               'time': datetime.datetime(2018, 9, 24, 4, 4, 4)}}
# {'hotspots': {'confidence': 64.0,
#               'latitude': -37.087,
#               'longitude': 145.37,
#               'surface_temperature_celcius': 33.0,
#               'time': datetime.datetime(2018, 9, 26, 3, 52, 14)}}
# {'hotspots': {'confidence': 65.0,
#               'latitude': -36.398,
#               'longitude': 145.286,
#               'surface_temperature_celcius': 39.0,
#               'time': datetime.datetime(2018, 9, 27, 4, 35, 18)}}
# {'hotspots': {'confidence': 62.0,
#               'latitude': -37.463,
#               'longitude': 148.109,
#               'surface_temperature_celcius': 34.0,
#               'time': datetime.datetime(2018, 10, 1, 15, 13, 56)}}
# {'hotspots': {'confidence': 64.0,
#               'latitude': -37.46,
#               'longitude': 148.113,
#               'surface_temperature_celcius': 52.0,
#               'time': datetime.datetime(2018, 10, 1, 4, 10, 28)}}
# {'hotspots': {'confidence': 50.0,
#               'latitude': -37.466,
#               'longitude': 148.1,
#               'surface_temperature_celcius': 29.0,
#               'time': datetime.datetime(2018, 10, 2, 23, 44, 31)}}
# {'hotspots': {'confidence': 59.0,
#               'latitude': -37.475,
#               'longitude': 148.134,
#               'surface_temperature_celcius': 40.0,
#               'time': datetime.datetime(2018, 10, 2, 4, 53, 10)}}
# {'hotspots': {'confidence': 68.0,
#               'latitude': -37.456,
#               'longitude': 148.11,
#               'surface_temperature_celcius': 40.0,
#               'time': datetime.datetime(2018, 10, 2, 0, 39, 34)}}
# {'hotspots': {'confidence': 69.0,
#               'latitude': -37.461,
#               'longitude': 148.109,
#               'surface_temperature_celcius': 33.0,
#               'time': datetime.datetime(2018, 10, 3, 15, 1, 44)}}
# {'hotspots': {'confidence': 68.0,
#               'latitude': -37.236,
#               'longitude': 141.176,
#               'surface_temperature_celcius': 37.0,
#               'time': datetime.datetime(2018, 10, 3, 3, 58, 28)}}
# {'hotspots': {'confidence': 59.0,
#               'latitude': -37.227,
#               'longitude': 141.151,
#               'surface_temperature_celcius': 35.0,
#               'time': datetime.datetime(2018, 10, 3, 3, 58, 28)}}
# {'hotspots': {'confidence': 54.0,
#               'latitude': -37.227,
#               'longitude': 141.146,
#               'surface_temperature_celcius': 31.0,
#               'time': datetime.datetime(2018, 10, 3, 1, 22, 44)}}
# {'hotspots': {'confidence': 50.0,
#               'latitude': -36.418,
#               'longitude': 141.596,
#               'surface_temperature_celcius': 41.0,
#               'time': datetime.datetime(2018, 10, 4, 4, 41, 36)}}
# {'hotspots': {'confidence': 62.0,
#               'latitude': -37.288,
#               'longitude': 144.39,
#               'surface_temperature_celcius': 36.0,
#               'time': datetime.datetime(2018, 10, 16, 23, 56, 43)}}
# {'hotspots': {'confidence': 58.0,
#               'latitude': -37.587,
#               'longitude': 142.479,
#               'surface_temperature_celcius': 41.0,
#               'time': datetime.datetime(2018, 10, 17, 4, 10, 38)}}
# {'hotspots': {'confidence': 65.0,
#               'latitude': -37.296,
#               'longitude': 144.386,
#               'surface_temperature_celcius': 54.0,
#               'time': datetime.datetime(2018, 10, 20, 0, 27, 12)}}
# {'hotspots': {'confidence': 65.0,
#               'latitude': -36.1,
#               'longitude': 143.772,
#               'surface_temperature_celcius': 35.0,
#               'time': datetime.datetime(2018, 10, 21, 1, 9, 54)}}
# {'hotspots': {'confidence': 67.0,
#               'latitude': -36.156,
#               'longitude': 143.568,
#               'surface_temperature_celcius': 42.0,
#               'time': datetime.datetime(2018, 10, 26, 4, 4, 53)}}
# {'hotspots': {'confidence': 69.0,
#               'latitude': -36.152,
#               'longitude': 143.578,
#               'surface_temperature_celcius': 44.0,
#               'time': datetime.datetime(2018, 10, 26, 4, 4, 53)}}
# {'hotspots': {'confidence': 62.0,
#               'latitude': -36.748,
#               'longitude': 144.168,
#               'surface_temperature_celcius': 44.0,
#               'time': datetime.datetime(2018, 10, 27, 4, 47, 31)}}
# {'hotspots': {'confidence': 60.0,
#               'latitude': -36.538,
#               'longitude': 141.129,
#               'surface_temperature_celcius': 43.0,
#               'time': datetime.datetime(2018, 11, 8, 5, 12, 8)}}
# {'hotspots': {'confidence': 68.0,
#               'latitude': -36.759,
#               'longitude': 145.179,
#               'surface_temperature_celcius': 52.0,
#               'time': datetime.datetime(2018, 11, 9, 4, 16, 56)}}
# {'hotspots': {'confidence': 62.0,
#               'latitude': -36.758,
#               'longitude': 145.19,
#               'surface_temperature_celcius': 51.0,
#               'time': datetime.datetime(2018, 11, 9, 4, 16, 56)}}
# {'hotspots': {'confidence': 63.0,
#               'latitude': -37.719,
#               'longitude': 142.154,
#               'surface_temperature_celcius': 41.0,
#               'time': datetime.datetime(2018, 11, 9, 4, 16, 46)}}
# {'hotspots': {'confidence': 51.0,
#               'latitude': -36.943,
#               'longitude': 143.286,
#               'surface_temperature_celcius': 29.0,
#               'time': datetime.datetime(2018, 11, 11, 15, 8)}}
# {'hotspots': {'confidence': 63.0,
#               'latitude': -36.942,
#               'longitude': 143.282,
#               'surface_temperature_celcius': 53.0,
#               'time': datetime.datetime(2018, 11, 12, 4, 47, 32)}}
# {'hotspots': {'confidence': 58.0,
#               'latitude': -37.864,
#               'longitude': 144.174,
#               'surface_temperature_celcius': 41.0,
#               'time': datetime.datetime(2018, 11, 12, 4, 47, 16)}}
# {'hotspots': {'confidence': 56.0,
#               'latitude': -38.912,
#               'longitude': 146.272,
#               'surface_temperature_celcius': 48.0,
#               'time': datetime.datetime(2018, 11, 12, 4, 46, 53)}}
# {'hotspots': {'confidence': 67.0,
#               'latitude': -36.942,
#               'longitude': 143.292,
#               'surface_temperature_celcius': 54.0,
#               'time': datetime.datetime(2018, 11, 12, 0, 33, 15)}}
# {'hotspots': {'confidence': 64.0,
#               'latitude': -37.954,
#               'longitude': 143.918,
#               'surface_temperature_celcius': 42.0,
#               'time': datetime.datetime(2018, 11, 13, 3, 52, 8)}}
# {'hotspots': {'confidence': 51.0,
#               'latitude': -38.167,
#               'longitude': 143.841,
#               'surface_temperature_celcius': 38.0,
#               'time': datetime.datetime(2018, 11, 13, 1, 16, 38)}}
# {'hotspots': {'confidence': 62.0,
#               'latitude': -38.16,
#               'longitude': 143.803,
#               'surface_temperature_celcius': 41.0,
#               'time': datetime.datetime(2018, 11, 13, 1, 16, 37)}}
# {'hotspots': {'confidence': 64.0,
#               'latitude': -38.527,
#               'longitude': 143.493,
#               'surface_temperature_celcius': 45.0,
#               'time': datetime.datetime(2018, 11, 14, 0, 21, 26)}}
# {'hotspots': {'confidence': 64.0,
#               'latitude': -37.332,
#               'longitude': 143.375,
#               'surface_temperature_celcius': 46.0,
#               'time': datetime.datetime(2018, 11, 14, 0, 21, 7)}}
# {'hotspots': {'confidence': 68.0,
#               'latitude': -38.141,
#               'longitude': 143.183,
#               'surface_temperature_celcius': 46.0,
#               'time': datetime.datetime(2018, 11, 23, 0, 15, 12)}}
# {'hotspots': {'confidence': 63.0,
#               'latitude': -36.952,
#               'longitude': 144.972,
#               'surface_temperature_celcius': 60.0,
#               'time': datetime.datetime(2018, 11, 23, 0, 14, 47)}}
# {'hotspots': {'confidence': 50.0,
#               'latitude': -37.749,
#               'longitude': 148.297,
#               'surface_temperature_celcius': 42.0,
#               'time': datetime.datetime(2018, 11, 28, 0, 33, 14)}}
# {'hotspots': {'confidence': 53.0,
#               'latitude': -37.611,
#               'longitude': 149.277,
#               'surface_temperature_celcius': 38.0,
#               'time': datetime.datetime(2018, 11, 29, 13, 17, 24)}}
# {'hotspots': {'confidence': 68.0,
#               'latitude': -37.605,
#               'longitude': 149.308,
#               'surface_temperature_celcius': 43.0,
#               'time': datetime.datetime(2018, 11, 29, 13, 17, 24)}}
# {'hotspots': {'confidence': 52.0,
#               'latitude': -34.282,
#               'longitude': 142.121,
#               'surface_temperature_celcius': 54.0,
#               'time': datetime.datetime(2018, 11, 29, 3, 53, 16)}}
# {'hotspots': {'confidence': 64.0,
#               'latitude': -37.605,
#               'longitude': 149.326,
#               'surface_temperature_celcius': 44.0,
#               'time': datetime.datetime(2018, 11, 29, 3, 52, 10)}}
# {'hotspots': {'confidence': 52.0,
#               'latitude': -37.635,
#               'longitude': 149.303,
#               'surface_temperature_celcius': 47.0,
#               'time': datetime.datetime(2018, 11, 30, 23, 25, 57)}}
# {'hotspots': {'confidence': 51.0,
#               'latitude': -37.59,
#               'longitude': 149.31,
#               'surface_temperature_celcius': 42.0,
#               'time': datetime.datetime(2018, 11, 30, 15, 38, 36)}}
# {'hotspots': {'confidence': 64.0,
#               'latitude': -37.633,
#               'longitude': 149.264,
#               'surface_temperature_celcius': 42.0,
#               'time': datetime.datetime(2018, 11, 30, 15, 38, 36)}}
# {'hotspots': {'confidence': 69.0,
#               'latitude': -37.58,
#               'longitude': 149.331,
#               'surface_temperature_celcius': 35.0,
#               'time': datetime.datetime(2018, 11, 30, 15, 38, 35)}}
# {'hotspots': {'confidence': 61.0,
#               'latitude': -37.38,
#               'longitude': 149.334,
#               'surface_temperature_celcius': 31.0,
#               'time': datetime.datetime(2018, 11, 30, 15, 38, 32)}}
# {'hotspots': {'confidence': 62.0,
#               'latitude': -37.602,
#               'longitude': 149.295,
#               'surface_temperature_celcius': 33.0,
#               'time': datetime.datetime(2018, 11, 30, 12, 22, 15)}}
# {'hotspots': {'confidence': 64.0,
#               'latitude': -37.598,
#               'longitude': 149.29,
#               'surface_temperature_celcius': 32.0,
#               'time': datetime.datetime(2018, 11, 30, 12, 22, 15)}}
# {'hotspots': {'confidence': 69.0,
#               'latitude': -37.61,
#               'longitude': 149.279,
#               'surface_temperature_celcius': 48.0,
#               'time': datetime.datetime(2018, 11, 30, 4, 34, 57)}}
# {'hotspots': {'confidence': 60.0,
#               'latitude': -37.637,
#               'longitude': 146.288,
#               'surface_temperature_celcius': 42.0,
#               'time': datetime.datetime(2018, 11, 30, 0, 21)}}
# {'hotspots': {'confidence': 69.0,
#               'latitude': -37.6,
#               'longitude': 149.297,
#               'surface_temperature_celcius': 50.0,
#               'time': datetime.datetime(2018, 11, 30, 0, 20, 53)}}
# {'hotspots': {'confidence': 64.0,
#               'latitude': -37.382,
#               'longitude': 149.341,
#               'surface_temperature_celcius': 41.0,
#               'time': datetime.datetime(2018, 11, 30, 0, 20, 49)}}
# {'hotspots': {'confidence': 56.0,
#               'latitude': -36.291,
#               'longitude': 146.159,
#               'surface_temperature_celcius': 40.0,
#               'time': datetime.datetime(2018, 12, 8, 13, 11, 43)}}
# {'hotspots': {'confidence': 50.0,
#               'latitude': -37.987,
#               'longitude': 144.005,
#               'surface_temperature_celcius': 38.0,
#               'time': datetime.datetime(2018, 12, 10, 0, 57, 59)}}
# {'hotspots': {'confidence': 67.0,
#               'latitude': -34.289,
#               'longitude': 141.712,
#               'surface_temperature_celcius': 54.0,
#               'time': datetime.datetime(2018, 12, 10, 0, 56, 57)}}
# {'hotspots': {'confidence': 53.0,
#               'latitude': -37.903,
#               'longitude': 145.25,
#               'surface_temperature_celcius': 44.0,
#               'time': datetime.datetime(2018, 12, 12, 0, 45, 38)}}
# {'hotspots': {'confidence': 51.0,
#               'latitude': -37.623,
#               'longitude': 149.323,
#               'surface_temperature_celcius': 38.0,
#               'time': datetime.datetime(2018, 12, 15, 13, 17, 17)}}
# {'hotspots': {'confidence': 65.0,
#               'latitude': -38.038,
#               'longitude': 142.986,
#               'surface_temperature_celcius': 40.0,
#               'time': datetime.datetime(2018, 12, 15, 1, 16, 23)}}
# {'hotspots': {'confidence': 69.0,
#               'latitude': -37.624,
#               'longitude': 149.332,
#               'surface_temperature_celcius': 33.0,
#               'time': datetime.datetime(2018, 12, 16, 15, 38, 39)}}
# {'hotspots': {'confidence': 62.0,
#               'latitude': -37.82,
#               'longitude': 142.323,
#               'surface_temperature_celcius': 54.0,
#               'time': datetime.datetime(2018, 12, 16, 4, 35, 15)}}
# {'hotspots': {'confidence': 59.0,
#               'latitude': -37.644,
#               'longitude': 149.346,
#               'surface_temperature_celcius': 55.0,
#               'time': datetime.datetime(2018, 12, 16, 4, 34, 57)}}
# {'hotspots': {'confidence': 60.0,
#               'latitude': -38.046,
#               'longitude': 144.201,
#               'surface_temperature_celcius': 48.0,
#               'time': datetime.datetime(2018, 12, 16, 0, 21, 11)}}
# {'hotspots': {'confidence': 53.0,
#               'latitude': -37.63,
#               'longitude': 149.335,
#               'surface_temperature_celcius': 57.0,
#               'time': datetime.datetime(2018, 12, 16, 0, 20, 53)}}
# {'hotspots': {'confidence': 65.0,
#               'latitude': -35.646,
#               'longitude': 142.282,
#               'surface_temperature_celcius': 32.0,
#               'time': datetime.datetime(2018, 12, 24, 13, 12, 1)}}
# {'hotspots': {'confidence': 67.0,
#               'latitude': -35.554,
#               'longitude': 143.307,
#               'surface_temperature_celcius': 53.0,
#               'time': datetime.datetime(2018, 12, 27, 0, 2, 15)}}

# %% [markdown]
# H. Find the average surface temperature for each day. You are required to only display average surface temperature and the date in the output.

# %%
result = collection.aggregate([{'$unwind': '$hotspots'}, {'$group': {
    '_id': '$date', 'avgTemp': {'$avg': '$hotspots.surface_temperature_celcius'}}}])

for each in result:
    pprint({
        'date': each['_id'].strftime("%d/%m/%Y"),
        'avgTemp': each['avgTemp']
    })
# Out:
# {'avgTemp': 49.0, 'date': '14/05/2018'}
# {'avgTemp': 51.2, 'date': '23/05/2018'}
# {'avgTemp': 69.375, 'date': '10/03/2018'}
# {'avgTemp': 50.6, 'date': '08/12/2018'}
# {'avgTemp': 56.291666666666664, 'date': '08/05/2018'}
# {'avgTemp': 56.5, 'date': '10/09/2018'}
# {'avgTemp': 46.0, 'date': '22/06/2018'}
# {'avgTemp': 38.5, 'date': '13/03/2018'}
# {'avgTemp': 60.925925925925924, 'date': '28/03/2018'}
# {'avgTemp': 47.0, 'date': '31/07/2018'}
# {'avgTemp': 47.0, 'date': '13/11/2018'}
# {'avgTemp': 62.57303370786517, 'date': '04/04/2018'}
# {'avgTemp': 52.0, 'date': '14/11/2018'}
# {'avgTemp': 61.94444444444444, 'date': '14/04/2018'}
# {'avgTemp': 45.0, 'date': '22/09/2018'}
# {'avgTemp': 44.333333333333336, 'date': '30/06/2018'}
# {'avgTemp': 52.69565217391305, 'date': '12/04/2018'}
# {'avgTemp': 53.89473684210526, 'date': '23/04/2018'}
# {'avgTemp': 53.333333333333336, 'date': '10/10/2018'}
# {'avgTemp': 50.4, 'date': '27/10/2018'}
# {'avgTemp': 58.5, 'date': '05/11/2018'}
# {'avgTemp': 56.80740740740741, 'date': '04/05/2018'}
# {'avgTemp': 52.22222222222222, 'date': '04/06/2018'}
# {'avgTemp': 48.72222222222222, 'date': '16/04/2018'}
# {'avgTemp': 52.41935483870968, 'date': '30/11/2018'}
# {'avgTemp': 59.5, 'date': '17/03/2018'}
# {'avgTemp': 51.5, 'date': '08/03/2018'}
# {'avgTemp': 50.69230769230769, 'date': '07/04/2018'}
# {'avgTemp': 57.8, 'date': '16/12/2018'}
# {'avgTemp': 40.333333333333336, 'date': '24/05/2018'}
# {'avgTemp': 58.44444444444444, 'date': '03/04/2018'}
# {'avgTemp': 49.0, 'date': '24/03/2018'}
# {'avgTemp': 46.25, 'date': '11/11/2018'}
# {'avgTemp': 53.36615384615384, 'date': '18/04/2018'}
# {'avgTemp': 68.4, 'date': '01/05/2018'}
# {'avgTemp': 53.25, 'date': '14/06/2018'}
# {'avgTemp': 61.71186440677966, 'date': '06/04/2018'}
# {'avgTemp': 63.5, 'date': '02/08/2018'}
# {'avgTemp': 42.0, 'date': '28/11/2018'}
# {'avgTemp': 49.0, 'date': '13/08/2018'}
# {'avgTemp': 48.25, 'date': '01/10/2018'}
# {'avgTemp': 52.0, 'date': '17/05/2018'}
# {'avgTemp': 60.5, 'date': '06/03/2018'}
# {'avgTemp': 59.375, 'date': '24/04/2018'}
# {'avgTemp': 53.0, 'date': '12/11/2018'}
# {'avgTemp': 46.666666666666664, 'date': '09/03/2018'}
# {'avgTemp': 46.0, 'date': '10/12/2018'}
# {'avgTemp': 32.0, 'date': '24/12/2018'}
# {'avgTemp': 65.57142857142857, 'date': '19/03/2018'}
# {'avgTemp': 49.0, 'date': '09/06/2018'}
# {'avgTemp': 49.714285714285715, 'date': '27/09/2018'}
# {'avgTemp': 51.0, 'date': '29/03/2018'}
# {'avgTemp': 48.72727272727273, 'date': '31/03/2018'}
# {'avgTemp': 40.5, 'date': '21/09/2018'}
# {'avgTemp': 56.796875, 'date': '03/05/2018'}
# {'avgTemp': 50.0, 'date': '20/10/2018'}
# {'avgTemp': 30.5, 'date': '01/07/2018'}
# {'avgTemp': 63.0, 'date': '29/04/2018'}
# {'avgTemp': 51.70967741935484, 'date': '05/05/2018'}
# {'avgTemp': 41.0, 'date': '13/06/2018'}
# {'avgTemp': 39.0, 'date': '15/12/2018'}
# {'avgTemp': 41.5, 'date': '11/06/2018'}
# {'avgTemp': 44.0, 'date': '09/10/2018'}
# {'avgTemp': 42.0, 'date': '18/06/2018'}
# {'avgTemp': 56.88235294117647, 'date': '26/03/2018'}
# {'avgTemp': 39.666666666666664, 'date': '16/05/2018'}
# {'avgTemp': 33.0, 'date': '26/09/2018'}
# {'avgTemp': 51.5, 'date': '12/05/2018'}
# {'avgTemp': 61.5, 'date': '22/11/2018'}
# {'avgTemp': 54.0, 'date': '25/12/2018'}
# {'avgTemp': 46.291666666666664, 'date': '11/04/2018'}
# {'avgTemp': 51.857142857142854, 'date': '07/06/2018'}
# {'avgTemp': 45.5, 'date': '08/11/2018'}
# {'avgTemp': 56.0, 'date': '06/07/2018'}
# {'avgTemp': 53.142857142857146, 'date': '05/04/2018'}
# {'avgTemp': 55.6, 'date': '02/05/2018'}
# {'avgTemp': 53.950980392156865, 'date': '15/05/2018'}
# {'avgTemp': 58.611111111111114, 'date': '13/05/2018'}
# {'avgTemp': 71.16666666666667, 'date': '20/06/2018'}
# {'avgTemp': 44.0, 'date': '12/12/2018'}
# {'avgTemp': 50.921052631578945, 'date': '17/04/2018'}
# {'avgTemp': 40.0, 'date': '04/07/2018'}
# {'avgTemp': 44.6, 'date': '26/10/2018'}
# {'avgTemp': 60.0, 'date': '13/12/2018'}
# {'avgTemp': 41.0, 'date': '08/10/2018'}
# {'avgTemp': 41.5, 'date': '14/07/2018'}
# {'avgTemp': 38.0, 'date': '23/10/2018'}
# {'avgTemp': 58.25, 'date': '09/12/2018'}
# {'avgTemp': 42.46153846153846, 'date': '09/05/2018'}
# {'avgTemp': 40.0, 'date': '05/08/2018'}
# {'avgTemp': 59.0, 'date': '21/11/2018'}
# {'avgTemp': 66.0, 'date': '25/03/2018'}
# {'avgTemp': 53.57142857142857, 'date': '24/09/2018'}
# {'avgTemp': 57.529411764705884, 'date': '06/05/2018'}
# {'avgTemp': 47.72727272727273, 'date': '02/06/2018'}
# {'avgTemp': 45.0, 'date': '05/07/2018'}
# {'avgTemp': 60.625, 'date': '29/11/2018'}
# {'avgTemp': 46.0, 'date': '21/12/2018'}
# {'avgTemp': 49.5, 'date': '26/05/2018'}
# {'avgTemp': 56.58064516129032, 'date': '20/04/2018'}
# {'avgTemp': 70.0, 'date': '14/12/2018'}
# {'avgTemp': 79.33333333333333, 'date': '18/03/2018'}
# {'avgTemp': 34.0, 'date': '26/04/2018'}
# {'avgTemp': 54.5, 'date': '22/04/2018'}
# {'avgTemp': 47.0, 'date': '03/06/2018'}
# {'avgTemp': 48.666666666666664, 'date': '25/04/2018'}
# {'avgTemp': 42.0, 'date': '07/10/2018'}
# {'avgTemp': 56.0, 'date': '28/10/2018'}
# {'avgTemp': 58.8, 'date': '23/11/2018'}
# {'avgTemp': 40.8, 'date': '14/08/2018'}
# {'avgTemp': 54.0, 'date': '01/06/2018'}
# {'avgTemp': 58.57983193277311, 'date': '13/04/2018'}
# {'avgTemp': 54.16, 'date': '19/04/2018'}
# {'avgTemp': 52.73913043478261, 'date': '23/09/2018'}
# {'avgTemp': 60.75, 'date': '08/04/2018'}
# {'avgTemp': 63.6, 'date': '20/09/2018'}
# {'avgTemp': 58.0, 'date': '01/08/2018'}
# {'avgTemp': 59.57971014492754, 'date': '15/04/2018'}
# {'avgTemp': 44.142857142857146, 'date': '18/05/2018'}
# {'avgTemp': 52.86842105263158, 'date': '10/05/2018'}
# {'avgTemp': 88.2, 'date': '12/03/2018'}
# {'avgTemp': 46.0, 'date': '15/03/2018'}
# {'avgTemp': 59.36842105263158, 'date': '11/05/2018'}
# {'avgTemp': 62.75, 'date': '27/12/2018'}
# {'avgTemp': 48.0, 'date': '29/07/2018'}
# {'avgTemp': 43.5, 'date': '02/07/2018'}
# {'avgTemp': 42.5, 'date': '16/06/2018'}
# {'avgTemp': 72.66666666666667, 'date': '15/10/2018'}
# {'avgTemp': 44.0, 'date': '06/10/2018'}
# {'avgTemp': 43.0, 'date': '29/09/2018'}
# {'avgTemp': 45.2, 'date': '02/04/2018'}
# {'avgTemp': 63.0, 'date': '10/08/2018'}
# {'avgTemp': 64.0, 'date': '07/03/2018'}
# {'avgTemp': 50.0, 'date': '03/10/2018'}
# {'avgTemp': 36.0, 'date': '16/10/2018'}
# {'avgTemp': 61.3, 'date': '09/11/2018'}
# {'avgTemp': 50.333333333333336, 'date': '07/05/2018'}
# {'avgTemp': 43.57142857142857, 'date': '02/10/2018'}
# {'avgTemp': 49.0, 'date': '04/10/2018'}
# {'avgTemp': 52.166666666666664, 'date': '18/10/2018'}
# {'avgTemp': 51.6, 'date': '17/10/2018'}
# {'avgTemp': 46.714285714285715, 'date': '01/04/2018'}
# {'avgTemp': 65.6, 'date': '14/03/2018'}
# {'avgTemp': 51.25, 'date': '21/10/2018'}
# {'avgTemp': 54.484848484848484, 'date': '22/05/2018'}

# %% [markdown]
# i. Find the top 10 records with the lowest GHI.

# %%
result = collection.aggregate([{'$sort': {'ghi': 1}}, {'$limit': 10}])

for each in result:
    pprint(each)
# Out:
# {'_id': ObjectId('60aa4d77f1c7e6844f090c92'),
#  'air_temperature_celcius': 5.0,
#  'date': datetime.datetime(2018, 8, 2, 0, 0),
#  'ghi': 47.0,
#  'hotspots': [{'confidence': 94.0,
#                'latitude': -37.4796,
#                'longitude': 141.9403,
#                'surface_temperature_celcius': 87.0,
#                'time': datetime.datetime(2018, 8, 2, 3, 45, 40)},
#               {'confidence': 54.0,
#                'latitude': -37.491,
#                'longitude': 141.936,
#                'surface_temperature_celcius': 40.0,
#                'time': datetime.datetime(2018, 8, 2, 3, 45)}],
#  'max_wind_speed': 5.1,
#  'precipitation': 0.0,
#  'precipitation_type': 'I',
#  'relative_humidity': 38.6,
#  'station': 948701,
#  'windspeed_knots': 1.8}
# {'_id': ObjectId('60aa4d77f1c7e6844f090c71'),
#  'air_temperature_celcius': 5.0,
#  'date': datetime.datetime(2018, 6, 30, 0, 0),
#  'ghi': 48.0,
#  'hotspots': [{'confidence': 78.0,
#                'latitude': -36.834,
#                'longitude': 142.524,
#                'surface_temperature_celcius': 44.0,
#                'time': datetime.datetime(2018, 6, 30, 4, 41, 25)},
#               {'confidence': 78.0,
#                'latitude': -36.834,
#                'longitude': 142.524,
#                'surface_temperature_celcius': 44.0,
#                'time': datetime.datetime(2018, 6, 30, 4, 41, 25)},
#               {'confidence': 81.0,
#                'latitude': -37.858,
#                'longitude': 143.428,
#                'surface_temperature_celcius': 48.0,
#                'time': datetime.datetime(2018, 6, 30, 0, 27, 19)},
#               {'confidence': 75.0,
#                'latitude': -37.856,
#                'longitude': 143.416,
#                'surface_temperature_celcius': 41.0,
#                'time': datetime.datetime(2018, 6, 30, 0, 27, 19)},
#               {'confidence': 75.0,
#                'latitude': -37.856,
#                'longitude': 143.416,
#                'surface_temperature_celcius': 41.0,
#                'time': datetime.datetime(2018, 6, 30, 0, 27, 19)},
#               {'confidence': 81.0,
#                'latitude': -37.858,
#                'longitude': 143.428,
#                'surface_temperature_celcius': 48.0,
#                'time': datetime.datetime(2018, 6, 30, 0, 27, 19)}],
#  'max_wind_speed': 11.1,
#  'precipitation': 0.0,
#  'precipitation_type': 'A',
#  'relative_humidity': 34.9,
#  'station': 948701,
#  'windspeed_knots': 4.3}
# {'_id': ObjectId('60aa4d77f1c7e6844f090c72'),
#  'air_temperature_celcius': 5.0,
#  'date': datetime.datetime(2018, 7, 1, 0, 0),
#  'ghi': 49.0,
#  'hotspots': [{'confidence': 53.0,
#                'latitude': -37.062,
#                'longitude': 141.373,
#                'surface_temperature_celcius': 29.0,
#                'time': datetime.datetime(2018, 7, 1, 13, 11, 41)},
#               {'confidence': 53.0,
#                'latitude': -37.062,
#                'longitude': 141.373,
#                'surface_temperature_celcius': 29.0,
#                'time': datetime.datetime(2018, 7, 1, 13, 11, 41)},
#               {'confidence': 61.0,
#                'latitude': -36.779,
#                'longitude': 146.108,
#                'surface_temperature_celcius': 32.0,
#                'time': datetime.datetime(2018, 7, 1, 3, 46, 8)},
#               {'confidence': 61.0,
#                'latitude': -36.779,
#                'longitude': 146.108,
#                'surface_temperature_celcius': 32.0,
#                'time': datetime.datetime(2018, 7, 1, 3, 46, 8)}],
#  'max_wind_speed': 14.0,
#  'precipitation': 0.0,
#  'precipitation_type': 'I',
#  'relative_humidity': 33.1,
#  'station': 948701,
#  'windspeed_knots': 5.8}
# {'_id': ObjectId('60aa4d77f1c7e6844f090c7c'),
#  'air_temperature_celcius': 6.0,
#  'date': datetime.datetime(2018, 7, 11, 0, 0),
#  'ghi': 56.0,
#  'max_wind_speed': 5.1,
#  'precipitation': 0.01,
#  'precipitation_type': 'G',
#  'relative_humidity': 39.0,
#  'station': 948701,
#  'windspeed_knots': 1.8}
# {'_id': ObjectId('60aa4d77f1c7e6844f090c80'),
#  'air_temperature_celcius': 6.0,
#  'date': datetime.datetime(2018, 7, 15, 0, 0),
#  'ghi': 57.0,
#  'max_wind_speed': 9.9,
#  'precipitation': 0.0,
#  'precipitation_type': 'I',
#  'relative_humidity': 37.1,
#  'station': 948701,
#  'windspeed_knots': 5.8}
# {'_id': ObjectId('60aa4d77f1c7e6844f090c73'),
#  'air_temperature_celcius': 6.0,
#  'date': datetime.datetime(2018, 7, 2, 0, 0),
#  'ghi': 60.0,
#  'hotspots': [{'confidence': 84.0,
#                'latitude': -36.397,
#                'longitude': 142.254,
#                'surface_temperature_celcius': 52.0,
#                'time': datetime.datetime(2018, 7, 2, 4, 29, 18)},
#               {'confidence': 84.0,
#                'latitude': -36.397,
#                'longitude': 142.254,
#                'surface_temperature_celcius': 52.0,
#                'time': datetime.datetime(2018, 7, 2, 4, 29, 18)},
#               {'confidence': 69.0,
#                'latitude': -37.067,
#                'longitude': 141.379,
#                'surface_temperature_celcius': 36.0,
#                'time': datetime.datetime(2018, 7, 2, 4, 29, 10)},
#               {'confidence': 69.0,
#                'latitude': -37.067,
#                'longitude': 141.379,
#                'surface_temperature_celcius': 36.0,
#                'time': datetime.datetime(2018, 7, 2, 4, 29, 10)},
#               {'confidence': 88.0,
#                'latitude': -37.333,
#                'longitude': 143.534,
#                'surface_temperature_celcius': 58.0,
#                'time': datetime.datetime(2018, 7, 2, 4, 29)},
#               {'confidence': 88.0,
#                'latitude': -37.333,
#                'longitude': 143.534,
#                'surface_temperature_celcius': 58.0,
#                'time': datetime.datetime(2018, 7, 2, 4, 29)},
#               {'confidence': 50.0,
#                'latitude': -37.886,
#                'longitude': 147.207,
#                'surface_temperature_celcius': 28.0,
#                'time': datetime.datetime(2018, 7, 2, 4, 28, 42)},
#               {'confidence': 50.0,
#                'latitude': -37.886,
#                'longitude': 147.207,
#                'surface_temperature_celcius': 28.0,
#                'time': datetime.datetime(2018, 7, 2, 4, 28, 42)}],
#  'max_wind_speed': 11.1,
#  'precipitation': 0.0,
#  'precipitation_type': 'I',
#  'relative_humidity': 30.8,
#  'station': 948701,
#  'windspeed_knots': 5.7}
# {'_id': ObjectId('60aa4d77f1c7e6844f090c91'),
#  'air_temperature_celcius': 7.0,
#  'date': datetime.datetime(2018, 8, 1, 0, 0),
#  'ghi': 65.0,
#  'hotspots': [{'confidence': 89.0,
#                'latitude': -38.3998,
#                'longitude': 147.064,
#                'surface_temperature_celcius': 65.0,
#                'time': datetime.datetime(2018, 8, 1, 0, 20, 30)},
#               {'confidence': 78.0,
#                'latitude': -38.3982,
#                'longitude': 147.0509,
#                'surface_temperature_celcius': 51.0,
#                'time': datetime.datetime(2018, 8, 1, 0, 19, 30)}],
#  'max_wind_speed': 7.0,
#  'precipitation': 0.0,
#  'precipitation_type': 'I',
#  'relative_humidity': 40.7,
#  'station': 948701,
#  'windspeed_knots': 3.7}
# {'_id': ObjectId('60aa4d77f1c7e6844f090c85'),
#  'air_temperature_celcius': 7.0,
#  'date': datetime.datetime(2018, 7, 20, 0, 0),
#  'ghi': 65.0,
#  'max_wind_speed': 15.0,
#  'precipitation': 0.12,
#  'precipitation_type': 'G',
#  'relative_humidity': 40.5,
#  'station': 948701,
#  'windspeed_knots': 8.1}
# {'_id': ObjectId('60aa4d77f1c7e6844f090c90'),
#  'air_temperature_celcius': 7.0,
#  'date': datetime.datetime(2018, 7, 31, 0, 0),
#  'ghi': 65.0,
#  'hotspots': [{'confidence': 100.0,
#                'latitude': -37.8641,
#                'longitude': 143.4276,
#                'surface_temperature_celcius': 51.0,
#                'time': datetime.datetime(2018, 7, 31, 13, 21)},
#               {'confidence': 92.0,
#                'latitude': -37.8658,
#                'longitude': 143.4162,
#                'surface_temperature_celcius': 43.0,
#                'time': datetime.datetime(2018, 7, 31, 13, 21)}],
#  'max_wind_speed': 8.0,
#  'precipitation': 0.0,
#  'precipitation_type': 'I',
#  'relative_humidity': 40.5,
#  'station': 948701,
#  'windspeed_knots': 3.1}
# {'_id': ObjectId('60aa4d77f1c7e6844f090ca3'),
#  'air_temperature_celcius': 7.0,
#  'date': datetime.datetime(2018, 8, 19, 0, 0),
#  'ghi': 66.0,
#  'max_wind_speed': 9.9,
#  'precipitation': 0.04,
#  'precipitation_type': 'G',
#  'relative_humidity': 37.9,
#  'station': 948702,
#  'windspeed_knots': 5.7}

# %% [markdown]
# j. Find the records with a 24-hour precipiation record between 0.20 and 0.35.

# %%
result = collection.aggregate(
    [{'$match': {'precipitation_type': 'G', 'precipitation': {'$gte': 0.20, '$lte': 0.35}}}])

for each in result:
    pprint(each)
# Out:
# {'_id': ObjectId('60aa4e725841cf5659939f10'),
#  'air_temperature_celcius': 19.0,
#  'date': datetime.datetime(2018, 1, 13, 0, 0),
#  'ghi': 157.0,
#  'max_wind_speed': 18.1,
#  'precipitation': 0.31,
#  'precipitation_type': 'G',
#  'relative_humidity': 54.1,
#  'station': 948700,
#  'windspeed_knots': 11.2}
# {'_id': ObjectId('60aa4e725841cf5659939f5b'),
#  'air_temperature_celcius': 17.0,
#  'date': datetime.datetime(2018, 3, 29, 0, 0),
#  'ghi': 146.0,
#  'hotspots': [{'confidence': 69.0,
#                'latitude': -34.2648,
#                'longitude': 141.6325,
#                'surface_temperature_celcius': 51.0,
#                'time': datetime.datetime(2018, 3, 29, 0, 48, 40)}],
#  'max_wind_speed': 21.0,
#  'precipitation': 0.24,
#  'precipitation_type': 'G',
#  'relative_humidity': 49.9,
#  'station': 948701,
#  'windspeed_knots': 12.2}
# {'_id': ObjectId('60aa4e725841cf5659939f71'),
#  'air_temperature_celcius': 20.0,
#  'date': datetime.datetime(2018, 4, 20, 0, 0),
#  'ghi': 166.0,
#  'hotspots': [{'confidence': 84.0,
#                'latitude': -36.8871,
#                'longitude': 145.1536,
#                'surface_temperature_celcius': 58.0,
#                'time': datetime.datetime(2018, 4, 20, 4, 44, 20)},
#               {'confidence': 59.0,
#                'latitude': -38.4685,
#                'longitude': 146.673,
#                'surface_temperature_celcius': 40.0,
#                'time': datetime.datetime(2018, 4, 20, 4, 36)},
#               {'confidence': 60.0,
#                'latitude': -36.8922,
#                'longitude': 145.1252,
#                'surface_temperature_celcius': 40.0,
#                'time': datetime.datetime(2018, 4, 20, 4, 34, 10)},
#               {'confidence': 93.0,
#                'latitude': -37.769,
#                'longitude': 147.94,
#                'surface_temperature_celcius': 72.0,
#                'time': datetime.datetime(2018, 4, 20, 4, 34, 10)},
#               {'confidence': 77.0,
#                'latitude': -36.0799,
#                'longitude': 146.0784,
#                'surface_temperature_celcius': 50.0,
#                'time': datetime.datetime(2018, 4, 20, 4, 33, 40)},
#               {'confidence': 88.0,
#                'latitude': -36.0829,
#                'longitude': 146.0621,
#                'surface_temperature_celcius': 63.0,
#                'time': datetime.datetime(2018, 4, 20, 4, 33, 20)},
#               {'confidence': 90.0,
#                'latitude': -36.1303,
#                'longitude': 146.3606,
#                'surface_temperature_celcius': 67.0,
#                'time': datetime.datetime(2018, 4, 20, 4, 32, 50)},
#               {'confidence': 67.0,
#                'latitude': -37.7615,
#                'longitude': 147.9169,
#                'surface_temperature_celcius': 45.0,
#                'time': datetime.datetime(2018, 4, 20, 4, 32, 50)},
#               {'confidence': 63.0,
#                'latitude': -36.8079,
#                'longitude': 145.1409,
#                'surface_temperature_celcius': 42.0,
#                'time': datetime.datetime(2018, 4, 20, 4, 32, 30)},
#               {'confidence': 85.0,
#                'latitude': -37.7783,
#                'longitude': 147.9284,
#                'surface_temperature_celcius': 60.0,
#                'time': datetime.datetime(2018, 4, 20, 4, 32, 30)},
#               {'confidence': 79.0,
#                'latitude': -36.8846,
#                'longitude': 145.1679,
#                'surface_temperature_celcius': 52.0,
#                'time': datetime.datetime(2018, 4, 20, 4, 32, 30)},
#               {'confidence': 80.0,
#                'latitude': -37.2341,
#                'longitude': 149.1736,
#                'surface_temperature_celcius': 53.0,
#                'time': datetime.datetime(2018, 4, 20, 4, 32, 30)},
#               {'confidence': 63.0,
#                'latitude': -36.9189,
#                'longitude': 147.5603,
#                'surface_temperature_celcius': 52.0,
#                'time': datetime.datetime(2018, 4, 20, 4, 32, 30)},
#               {'confidence': 98.0,
#                'latitude': -36.1345,
#                'longitude': 146.351,
#                'surface_temperature_celcius': 84.0,
#                'time': datetime.datetime(2018, 4, 20, 4, 32, 30)},
#               {'confidence': 87.0,
#                'latitude': -36.9246,
#                'longitude': 147.5559,
#                'surface_temperature_celcius': 62.0,
#                'time': datetime.datetime(2018, 4, 20, 4, 32, 30)},
#               {'confidence': 64.0,
#                'latitude': -36.085,
#                'longitude': 145.9096,
#                'surface_temperature_celcius': 42.0,
#                'time': datetime.datetime(2018, 4, 20, 0, 19)},
#               {'confidence': 88.0,
#                'latitude': -38.1301,
#                'longitude': 143.9398,
#                'surface_temperature_celcius': 63.0,
#                'time': datetime.datetime(2018, 4, 20, 0, 18, 40)},
#               {'confidence': 69.0,
#                'latitude': -37.7087,
#                'longitude': 145.5499,
#                'surface_temperature_celcius': 45.0,
#                'time': datetime.datetime(2018, 4, 20, 0, 18, 20)},
#               {'confidence': 100.0,
#                'latitude': -36.5865,
#                'longitude': 145.2081,
#                'surface_temperature_celcius': 111.0,
#                'time': datetime.datetime(2018, 4, 20, 0, 18, 20)},
#               {'confidence': 73.0,
#                'latitude': -36.8702,
#                'longitude': 144.0381,
#                'surface_temperature_celcius': 47.0,
#                'time': datetime.datetime(2018, 4, 20, 0, 17, 10)},
#               {'confidence': 99.0,
#                'latitude': -36.1586,
#                'longitude': 145.6666,
#                'surface_temperature_celcius': 85.0,
#                'time': datetime.datetime(2018, 4, 20, 0, 17, 10)},
#               {'confidence': 74.0,
#                'latitude': -37.8672,
#                'longitude': 143.8194,
#                'surface_temperature_celcius': 48.0,
#                'time': datetime.datetime(2018, 4, 20, 0, 16, 50)},
#               {'confidence': 78.0,
#                'latitude': -36.5956,
#                'longitude': 145.206,
#                'surface_temperature_celcius': 51.0,
#                'time': datetime.datetime(2018, 4, 20, 0, 15, 30)},
#               {'confidence': 77.0,
#                'latitude': -37.2197,
#                'longitude': 148.8134,
#                'surface_temperature_celcius': 50.0,
#                'time': datetime.datetime(2018, 4, 20, 0, 14, 20)},
#               {'confidence': 96.0,
#                'latitude': -36.5847,
#                'longitude': 145.1968,
#                'surface_temperature_celcius': 78.0,
#                'time': datetime.datetime(2018, 4, 20, 0, 14, 10)},
#               {'confidence': 89.0,
#                'latitude': -37.6997,
#                'longitude': 145.5519,
#                'surface_temperature_celcius': 64.0,
#                'time': datetime.datetime(2018, 4, 20, 0, 13, 40)},
#               {'confidence': 61.0,
#                'latitude': -37.932,
#                'longitude': 146.1845,
#                'surface_temperature_celcius': 50.0,
#                'time': datetime.datetime(2018, 4, 20, 0, 13, 30)},
#               {'confidence': 76.0,
#                'latitude': -36.6407,
#                'longitude': 144.2957,
#                'surface_temperature_celcius': 50.0,
#                'time': datetime.datetime(2018, 4, 20, 0, 13, 10)},
#               {'confidence': 63.0,
#                'latitude': -36.1569,
#                'longitude': 145.6554,
#                'surface_temperature_celcius': 41.0,
#                'time': datetime.datetime(2018, 4, 20, 0, 13)},
#               {'confidence': 54.0,
#                'latitude': -36.6363,
#                'longitude': 144.3033,
#                'surface_temperature_celcius': 40.0,
#                'time': datetime.datetime(2018, 4, 20, 0, 13)},
#               {'confidence': 76.0,
#                'latitude': -37.2212,
#                'longitude': 148.8262,
#                'surface_temperature_celcius': 49.0,
#                'time': datetime.datetime(2018, 4, 20, 0, 12, 50)}],
#  'max_wind_speed': 15.9,
#  'precipitation': 0.31,
#  'precipitation_type': 'G',
#  'relative_humidity': 53.5,
#  'station': 948701,
#  'windspeed_knots': 7.2}
# {'_id': ObjectId('60aa4e725841cf5659939f77'),
#  'air_temperature_celcius': 11.0,
#  'date': datetime.datetime(2018, 4, 26, 0, 0),
#  'ghi': 102.0,
#  'hotspots': [{'confidence': 56.0,
#                'latitude': -36.5511,
#                'longitude': 146.7819,
#                'surface_temperature_celcius': 34.0,
#                'time': datetime.datetime(2018, 4, 26, 13, 26, 10)}],
#  'max_wind_speed': 20.0,
#  'precipitation': 0.24,
#  'precipitation_type': 'G',
#  'relative_humidity': 40.8,
#  'station': 948701,
#  'windspeed_knots': 12.2}
# {'_id': ObjectId('60aa4e725841cf5659939f96'),
#  'air_temperature_celcius': 14.0,
#  'date': datetime.datetime(2018, 5, 27, 0, 0),
#  'ghi': 122.0,
#  'max_wind_speed': 19.0,
#  'precipitation': 0.35,
#  'precipitation_type': 'G',
#  'relative_humidity': 48.1,
#  'station': 948701,
#  'windspeed_knots': 13.7}
# {'_id': ObjectId('60aa4e725841cf5659939f99'),
#  'air_temperature_celcius': 8.0,
#  'date': datetime.datetime(2018, 5, 30, 0, 0),
#  'ghi': 73.0,
#  'max_wind_speed': 15.9,
#  'precipitation': 0.24,
#  'precipitation_type': 'G',
#  'relative_humidity': 41.6,
#  'station': 948701,
#  'windspeed_knots': 8.3}
# {'_id': ObjectId('60aa4e725841cf5659939fbb'),
#  'air_temperature_celcius': 11.0,
#  'date': datetime.datetime(2018, 7, 3, 0, 0),
#  'ghi': 98.0,
#  'max_wind_speed': 18.1,
#  'precipitation': 0.2,
#  'precipitation_type': 'G',
#  'relative_humidity': 45.1,
#  'station': 948701,
#  'windspeed_knots': 11.5}
# {'_id': ObjectId('60aa4e725841cf5659939fd3'),
#  'air_temperature_celcius': 11.0,
#  'date': datetime.datetime(2018, 7, 27, 0, 0),
#  'ghi': 99.0,
#  'max_wind_speed': 21.0,
#  'precipitation': 0.24,
#  'precipitation_type': 'G',
#  'relative_humidity': 43.5,
#  'station': 948701,
#  'windspeed_knots': 13.1}
# {'_id': ObjectId('60aa4e725841cf5659939fdd'),
#  'air_temperature_celcius': 9.0,
#  'date': datetime.datetime(2018, 8, 6, 0, 0),
#  'ghi': 83.0,
#  'max_wind_speed': 19.0,
#  'precipitation': 0.24,
#  'precipitation_type': 'G',
#  'relative_humidity': 41.1,
#  'station': 948702,
#  'windspeed_knots': 12.7}
# {'_id': ObjectId('60aa4e725841cf5659939ff1'),
#  'air_temperature_celcius': 11.0,
#  'date': datetime.datetime(2018, 8, 26, 0, 0),
#  'ghi': 102.0,
#  'max_wind_speed': 19.0,
#  'precipitation': 0.28,
#  'precipitation_type': 'G',
#  'relative_humidity': 39.7,
#  'station': 948702,
#  'windspeed_knots': 11.8}
# {'_id': ObjectId('60aa4e725841cf5659939ffb'),
#  'air_temperature_celcius': 8.0,
#  'date': datetime.datetime(2018, 9, 5, 0, 0),
#  'ghi': 75.0,
#  'max_wind_speed': 18.1,
#  'precipitation': 0.31,
#  'precipitation_type': 'G',
#  'relative_humidity': 38.6,
#  'station': 948702,
#  'windspeed_knots': 12.8}
# {'_id': ObjectId('60aa4e725841cf5659939ffd'),
#  'air_temperature_celcius': 10.0,
#  'date': datetime.datetime(2018, 9, 7, 0, 0),
#  'ghi': 90.0,
#  'max_wind_speed': 14.0,
#  'precipitation': 0.2,
#  'precipitation_type': 'G',
#  'relative_humidity': 43.6,
#  'station': 948702,
#  'windspeed_knots': 9.7}
# {'_id': ObjectId('60aa4e725841cf565993a005'),
#  'air_temperature_celcius': 11.0,
#  'date': datetime.datetime(2018, 9, 15, 0, 0),
#  'ghi': 97.0,
#  'max_wind_speed': 15.0,
#  'precipitation': 0.28,
#  'precipitation_type': 'G',
#  'relative_humidity': 46.2,
#  'station': 948702,
#  'windspeed_knots': 10.5}
# {'_id': ObjectId('60aa4e725841cf565993a019'),
#  'air_temperature_celcius': 12.0,
#  'date': datetime.datetime(2018, 10, 5, 0, 0),
#  'ghi': 105.0,
#  'max_wind_speed': 18.1,
#  'precipitation': 0.2,
#  'precipitation_type': 'G',
#  'relative_humidity': 47.5,
#  'station': 948702,
#  'windspeed_knots': 15.0}
# {'_id': ObjectId('60aa4e725841cf565993a031'),
#  'air_temperature_celcius': 17.0,
#  'date': datetime.datetime(2018, 10, 29, 0, 0),
#  'ghi': 152.0,
#  'max_wind_speed': 27.0,
#  'precipitation': 0.24,
#  'precipitation_type': 'G',
#  'relative_humidity': 44.9,
#  'station': 948702,
#  'windspeed_knots': 16.1}
# {'_id': ObjectId('60aa4e725841cf565993a032'),
#  'air_temperature_celcius': 11.0,
#  'date': datetime.datetime(2018, 10, 30, 0, 0),
#  'ghi': 100.0,
#  'max_wind_speed': 14.0,
#  'precipitation': 0.2,
#  'precipitation_type': 'G',
#  'relative_humidity': 43.2,
#  'station': 948702,
#  'windspeed_knots': 8.1}
# {'_id': ObjectId('60aa4e725841cf565993a043'),
#  'air_temperature_celcius': 18.0,
#  'date': datetime.datetime(2018, 11, 16, 0, 0),
#  'ghi': 140.0,
#  'max_wind_speed': 11.1,
#  'precipitation': 0.28,
#  'precipitation_type': 'G',
#  'relative_humidity': 61.5,
#  'station': 948702,
#  'windspeed_knots': 5.5}
# {'_id': ObjectId('60aa4e725841cf565993a044'),
#  'air_temperature_celcius': 19.0,
#  'date': datetime.datetime(2018, 11, 17, 0, 0),
#  'ghi': 151.0,
#  'max_wind_speed': 12.0,
#  'precipitation': 0.28,
#  'precipitation_type': 'G',
#  'relative_humidity': 58.7,
#  'station': 948702,
#  'windspeed_knots': 5.5}
# {'_id': ObjectId('60aa4e725841cf565993a051'),
#  'air_temperature_celcius': 26.0,
#  'date': datetime.datetime(2018, 11, 30, 0, 0),
#  'ghi': 202.0,
#  'hotspots': [{'confidence': 52.0,
#                'latitude': -37.635,
#                'longitude': 149.303,
#                'surface_temperature_celcius': 47.0,
#                'time': datetime.datetime(2018, 11, 30, 23, 25, 57)},
#               {'confidence': 100.0,
#                'latitude': -37.591,
#                'longitude': 149.33,
#                'surface_temperature_celcius': 53.0,
#                'time': datetime.datetime(2018, 11, 30, 15, 38, 36)},
#               {'confidence': 51.0,
#                'latitude': -37.59,
#                'longitude': 149.31,
#                'surface_temperature_celcius': 42.0,
#                'time': datetime.datetime(2018, 11, 30, 15, 38, 36)},
#               {'confidence': 64.0,
#                'latitude': -37.633,
#                'longitude': 149.264,
#                'surface_temperature_celcius': 42.0,
#                'time': datetime.datetime(2018, 11, 30, 15, 38, 36)},
#               {'confidence': 100.0,
#                'latitude': -37.585,
#                'longitude': 149.336,
#                'surface_temperature_celcius': 54.0,
#                'time': datetime.datetime(2018, 11, 30, 15, 38, 35)},
#               {'confidence': 69.0,
#                'latitude': -37.58,
#                'longitude': 149.331,
#                'surface_temperature_celcius': 35.0,
#                'time': datetime.datetime(2018, 11, 30, 15, 38, 35)},
#               {'confidence': 100.0,
#                'latitude': -37.583,
#                'longitude': 149.316,
#                'surface_temperature_celcius': 49.0,
#                'time': datetime.datetime(2018, 11, 30, 15, 38, 35)},
#               {'confidence': 61.0,
#                'latitude': -37.38,
#                'longitude': 149.334,
#                'surface_temperature_celcius': 31.0,
#                'time': datetime.datetime(2018, 11, 30, 15, 38, 32)},
#               {'confidence': 62.0,
#                'latitude': -37.602,
#                'longitude': 149.295,
#                'surface_temperature_celcius': 33.0,
#                'time': datetime.datetime(2018, 11, 30, 12, 22, 15)},
#               {'confidence': 64.0,
#                'latitude': -37.598,
#                'longitude': 149.29,
#                'surface_temperature_celcius': 32.0,
#                'time': datetime.datetime(2018, 11, 30, 12, 22, 15)},
#               {'confidence': 84.0,
#                'latitude': -37.596,
#                'longitude': 149.319,
#                'surface_temperature_celcius': 38.0,
#                'time': datetime.datetime(2018, 11, 30, 12, 22, 15)},
#               {'confidence': 81.0,
#                'latitude': -37.63,
#                'longitude': 149.232,
#                'surface_temperature_celcius': 42.0,
#                'time': datetime.datetime(2018, 11, 30, 12, 22, 15)},
#               {'confidence': 100.0,
#                'latitude': -37.644,
#                'longitude': 149.233,
#                'surface_temperature_celcius': 55.0,
#                'time': datetime.datetime(2018, 11, 30, 12, 22, 15)},
#               {'confidence': 100.0,
#                'latitude': -37.642,
#                'longitude': 149.263,
#                'surface_temperature_celcius': 65.0,
#                'time': datetime.datetime(2018, 11, 30, 12, 22, 15)},
#               {'confidence': 100.0,
#                'latitude': -37.634,
#                'longitude': 149.237,
#                'surface_temperature_celcius': 71.0,
#                'time': datetime.datetime(2018, 11, 30, 12, 22, 14)},
#               {'confidence': 84.0,
#                'latitude': -37.384,
#                'longitude': 149.336,
#                'surface_temperature_celcius': 59.0,
#                'time': datetime.datetime(2018, 11, 30, 4, 35)},
#               {'confidence': 73.0,
#                'latitude': -37.389,
#                'longitude': 149.311,
#                'surface_temperature_celcius': 50.0,
#                'time': datetime.datetime(2018, 11, 30, 4, 35)},
#               {'confidence': 98.0,
#                'latitude': -37.605,
#                'longitude': 149.302,
#                'surface_temperature_celcius': 83.0,
#                'time': datetime.datetime(2018, 11, 30, 4, 34, 57)},
#               {'confidence': 81.0,
#                'latitude': -37.627,
#                'longitude': 149.261,
#                'surface_temperature_celcius': 57.0,
#                'time': datetime.datetime(2018, 11, 30, 4, 34, 57)},
#               {'confidence': 84.0,
#                'latitude': -37.623,
#                'longitude': 149.284,
#                'surface_temperature_celcius': 61.0,
#                'time': datetime.datetime(2018, 11, 30, 4, 34, 57)},
#               {'confidence': 99.0,
#                'latitude': -37.6,
#                'longitude': 149.325,
#                'surface_temperature_celcius': 86.0,
#                'time': datetime.datetime(2018, 11, 30, 4, 34, 57)},
#               {'confidence': 69.0,
#                'latitude': -37.61,
#                'longitude': 149.279,
#                'surface_temperature_celcius': 48.0,
#                'time': datetime.datetime(2018, 11, 30, 4, 34, 57)},
#               {'confidence': 60.0,
#                'latitude': -37.637,
#                'longitude': 146.288,
#                'surface_temperature_celcius': 42.0,
#                'time': datetime.datetime(2018, 11, 30, 0, 21)},
#               {'confidence': 83.0,
#                'latitude': -37.608,
#                'longitude': 149.282,
#                'surface_temperature_celcius': 58.0,
#                'time': datetime.datetime(2018, 11, 30, 0, 20, 53)},
#               {'confidence': 87.0,
#                'latitude': -37.62,
#                'longitude': 149.294,
#                'surface_temperature_celcius': 63.0,
#                'time': datetime.datetime(2018, 11, 30, 0, 20, 53)},
#               {'confidence': 95.0,
#                'latitude': -37.618,
#                'longitude': 149.281,
#                'surface_temperature_celcius': 76.0,
#                'time': datetime.datetime(2018, 11, 30, 0, 20, 53)},
#               {'confidence': 81.0,
#                'latitude': -37.61,
#                'longitude': 149.296,
#                'surface_temperature_celcius': 56.0,
#                'time': datetime.datetime(2018, 11, 30, 0, 20, 53)},
#               {'confidence': 73.0,
#                'latitude': -37.603,
#                'longitude': 149.324,
#                'surface_temperature_celcius': 51.0,
#                'time': datetime.datetime(2018, 11, 30, 0, 20, 53)},
#               {'confidence': 81.0,
#                'latitude': -37.602,
#                'longitude': 149.311,
#                'surface_temperature_celcius': 55.0,
#                'time': datetime.datetime(2018, 11, 30, 0, 20, 53)},
#               {'confidence': 69.0,
#                'latitude': -37.6,
#                'longitude': 149.297,
#                'surface_temperature_celcius': 50.0,
#                'time': datetime.datetime(2018, 11, 30, 0, 20, 53)},
#               {'confidence': 64.0,
#                'latitude': -37.382,
#                'longitude': 149.341,
#                'surface_temperature_celcius': 41.0,
#                'time': datetime.datetime(2018, 11, 30, 0, 20, 49)}],
#  'max_wind_speed': 15.0,
#  'precipitation': 0.2,
#  'precipitation_type': 'G',
#  'relative_humidity': 61.0,
#  'station': 948702,
#  'windspeed_knots': 9.3}
