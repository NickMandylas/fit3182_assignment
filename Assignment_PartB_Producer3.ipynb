# %% [markdown]
# ## FIT3182 - Assignment 2
# ---
# ### Part B - Producer 3
#
# **Information:**
# - Filename: Assignment_PartB_Producer3.ipynb
# - Student Name: Nicholas Mandylas
# - Student Number: 27840328
# - Student Email: nman48@student.monash.edu

# %%
from time import sleep
from json import dumps
from kafka import KafkaProducer
import random
import datetime as dt
import pandas


def readCSV():
    climate_streaming_data = pandas.read_csv('hotspot_TERRA_streaming.csv')
    streaming_data = []
    for _, row in climate_streaming_data.iterrows(): # Iterate through each row in the CSV
        data_point = {} # Create dictionary for individual row & format data appropriately.
        data_point['latitude'] = float(row['latitude'])
        data_point['longitude'] = float(row['longitude'])
        data_point['confidence'] = float(row['confidence'])
        data_point['surface_temperature_celcius'] = float(
            row['surface_temperature_celcius'])

        streaming_data.append(data_point)

    return streaming_data


def publish_message(producer_instance, topic_name, data):
    try:
        producer_instance.send(topic_name, value=data)
        producer_instance.flush()
        print('Message published successfully. Data: ' + str(data))
    except Exception as ex:
        print('Exception in publishing message.')
        print(str(ex))


def connect_kafka_producer():
    _producer = None
    try:
        _producer = KafkaProducer( # Added serializer on the producer, which will automatically serialize to JSON string format.
            bootstrap_servers=['localhost:9092'], value_serializer=lambda x: dumps(x).encode('ascii'), api_version=(0, 10))
    except Exception as ex:
        print('Exception while connecting Kafka.')
        print(str(ex))
    finally:
        return _producer


if __name__ == '__main__':

    data = readCSV()
    topic = 'Hotspot_TERRA'
    producer = connect_kafka_producer()
    created_date = dt.datetime(2019, 1, 1)

    count = 0

    while True:
        count += 4

        random_number = random.randrange(0, len(data))
        selected_data = data[random_number]

        if count > 16: # As data stream is expected to be sent every 2 seconds (10 seconds total for a single day), iterate up to 6, counting by 4.
            created_date += dt.timedelta(days=1) # Set to next day & reset time back to 0 hours, 0 minutes & 0 seconds.
            created_date.replace(hour=0, minute=0, second=0)
            count = 0

        # Every two seconds, I select a random hour (in the space of 4 hours), random minutes & seconds, to make a more simulated flow of data.
        # As the count increases (as it does 4), the next two seconds, will be a random time, keeping the output in sequential & random order.
        created_time = created_date + dt.timedelta(
            hours=(random.randrange(count - 4, count)),
            minutes=(random.randrange(0, 60)),
            seconds=(random.randrange(0, 60)))
        selected_data['created_time'] = created_time.isoformat()
        # print(selected_data['created_time'].strftime("%m/%d/%Y, %H:%M:%S"))
        selected_data['producer_id'] = 'producer_hotspot_terra'

        publish_message(producer, topic, selected_data)

        sleep(2)
# Out:
# Message published successfully. Data: {'latitude': -36.494, 'longitude': 145.4522, 'confidence': 63.0, 'surface_temperature_celcius': 41.0, 'created_time': '2019-01-01T03:11:51', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. Data: {'latitude': -37.166, 'longitude': 148.9436, 'confidence': 75.0, 'surface_temperature_celcius': 49.0, 'created_time': '2019-01-01T06:33:04', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. Data: {'latitude': -34.8404, 'longitude': 143.1806, 'confidence': 78.0, 'surface_temperature_celcius': 55.0, 'created_time': '2019-01-01T11:06:09', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. Data: {'latitude': -38.294, 'longitude': 143.7227, 'confidence': 60.0, 'surface_temperature_celcius': 41.0, 'created_time': '2019-01-01T14:21:12', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. Data: {'latitude': -36.5871, 'longitude': 144.961, 'confidence': 86.0, 'surface_temperature_celcius': 60.0, 'created_time': '2019-01-01T23:34:44', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. Data: {'latitude': -37.7269, 'longitude': 143.0087, 'confidence': 100.0, 'surface_temperature_celcius': 114.0, 'created_time': '2019-01-02T01:19:11', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. Data: {'latitude': -37.4437, 'longitude': 143.4924, 'confidence': 72.0, 'surface_temperature_celcius': 46.0, 'created_time': '2019-01-02T07:06:46', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. Data: {'latitude': -36.5956, 'longitude': 144.7405, 'confidence': 74.0, 'surface_temperature_celcius': 48.0, 'created_time': '2019-01-02T09:23:40', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. Data: {'latitude': -37.8635, 'longitude': 143.1986, 'confidence': 57.0, 'surface_temperature_celcius': 39.0, 'created_time': '2019-01-02T15:00:04', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. Data: {'latitude': -36.3278, 'longitude': 141.082, 'confidence': 54.0, 'surface_temperature_celcius': 39.0, 'created_time': '2019-01-02T21:10:22', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. Data: {'latitude': -37.8774, 'longitude': 145.8213, 'confidence': 95.0, 'surface_temperature_celcius': 77.0, 'created_time': '2019-01-03T03:19:48', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. Data: {'latitude': -37.5914, 'longitude': 148.5807, 'confidence': 63.0, 'surface_temperature_celcius': 61.0, 'created_time': '2019-01-03T05:49:51', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. Data: {'latitude': -37.6593, 'longitude': 143.3445, 'confidence': 78.0, 'surface_temperature_celcius': 52.0, 'created_time': '2019-01-03T10:41:03', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. Data: {'latitude': -36.1104, 'longitude': 145.9829, 'confidence': 90.0, 'surface_temperature_celcius': 76.0, 'created_time': '2019-01-03T14:37:40', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. Data: {'latitude': -36.0834, 'longitude': 146.5364, 'confidence': 50.0, 'surface_temperature_celcius': 53.0, 'created_time': '2019-01-03T22:53:26', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. Data: {'latitude': -37.2609, 'longitude': 141.7999, 'confidence': 89.0, 'surface_temperature_celcius': 66.0, 'created_time': '2019-01-04T03:36:06', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. Data: {'latitude': -36.5107, 'longitude': 144.4722, 'confidence': 84.0, 'surface_temperature_celcius': 58.0, 'created_time': '2019-01-04T07:27:59', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. Data: {'latitude': -36.3753, 'longitude': 146.6914, 'confidence': 57.0, 'surface_temperature_celcius': 40.0, 'created_time': '2019-01-04T10:47:23', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. Data: {'latitude': -37.062, 'longitude': 141.373, 'confidence': 53.0, 'surface_temperature_celcius': 29.0, 'created_time': '2019-01-04T14:36:23', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. Data: {'latitude': -36.8147, 'longitude': 142.8375, 'confidence': 74.0, 'surface_temperature_celcius': 48.0, 'created_time': '2019-01-04T22:00:03', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. Data: {'latitude': -36.4125, 'longitude': 143.1189, 'confidence': 100.0, 'surface_temperature_celcius': 92.0, 'created_time': '2019-01-05T00:34:16', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. Data: {'latitude': -36.4437, 'longitude': 141.5916, 'confidence': 58.0, 'surface_temperature_celcius': 45.0, 'created_time': '2019-01-05T04:02:39', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. Data: {'latitude': -38.2661, 'longitude': 143.9672, 'confidence': 83.0, 'surface_temperature_celcius': 56.0, 'created_time': '2019-01-05T09:29:28', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. Data: {'latitude': -37.6514, 'longitude': 142.9253, 'confidence': 75.0, 'surface_temperature_celcius': 48.0, 'created_time': '2019-01-05T12:15:09', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. Data: {'latitude': -37.0135, 'longitude': 143.5822, 'confidence': 69.0, 'surface_temperature_celcius': 44.0, 'created_time': '2019-01-05T23:02:22', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. Data: {'latitude': -36.5828, 'longitude': 144.5775, 'confidence': 92.0, 'surface_temperature_celcius': 70.0, 'created_time': '2019-01-06T02:56:05', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. Data: {'latitude': -37.9075, 'longitude': 142.6403, 'confidence': 62.0, 'surface_temperature_celcius': 41.0, 'created_time': '2019-01-06T05:25:07', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. Data: {'latitude': -36.4925, 'longitude': 142.2657, 'confidence': 74.0, 'surface_temperature_celcius': 48.0, 'created_time': '2019-01-06T11:49:18', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. Data: {'latitude': -37.8817, 'longitude': 143.7119, 'confidence': 88.0, 'surface_temperature_celcius': 63.0, 'created_time': '2019-01-06T13:12:44', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. Data: {'latitude': -36.2692, 'longitude': 141.0705, 'confidence': 58.0, 'surface_temperature_celcius': 40.0, 'created_time': '2019-01-06T22:51:53', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. Data: {'latitude': -36.4464, 'longitude': 141.0436, 'confidence': 86.0, 'surface_temperature_celcius': 61.0, 'created_time': '2019-01-07T02:43:34', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. Data: {'latitude': -36.6507, 'longitude': 142.4998, 'confidence': 86.0, 'surface_temperature_celcius': 61.0, 'created_time': '2019-01-07T05:15:41', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. Data: {'latitude': -36.085, 'longitude': 145.9096, 'confidence': 64.0, 'surface_temperature_celcius': 42.0, 'created_time': '2019-01-07T10:06:47', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. Data: {'latitude': -36.1532, 'longitude': 143.5527, 'confidence': 100.0, 'surface_temperature_celcius': 90.0, 'created_time': '2019-01-07T12:39:04', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. Data: {'latitude': -37.5728, 'longitude': 142.6348, 'confidence': 100.0, 'surface_temperature_celcius': 98.0, 'created_time': '2019-01-07T22:23:17', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. Data: {'latitude': -37.9378, 'longitude': 144.3115, 'confidence': 87.0, 'surface_temperature_celcius': 62.0, 'created_time': '2019-01-08T02:21:25', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. Data: {'latitude': -36.0994, 'longitude': 143.4156, 'confidence': 82.0, 'surface_temperature_celcius': 62.0, 'created_time': '2019-01-08T04:14:11', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. Data: {'latitude': -37.9452, 'longitude': 143.5834, 'confidence': 97.0, 'surface_temperature_celcius': 80.0, 'created_time': '2019-01-08T09:48:09', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. Data: {'latitude': -37.6518, 'longitude': 142.9159, 'confidence': 83.0, 'surface_temperature_celcius': 57.0, 'created_time': '2019-01-08T12:42:46', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. Data: {'latitude': -37.7322, 'longitude': 145.9657, 'confidence': 73.0, 'surface_temperature_celcius': 50.0, 'created_time': '2019-01-08T22:05:27', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. Data: {'latitude': -36.827, 'longitude': 142.5446, 'confidence': 75.0, 'surface_temperature_celcius': 49.0, 'created_time': '2019-01-09T00:48:23', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. Data: {'latitude': -36.9454, 'longitude': 143.0869, 'confidence': 73.0, 'surface_temperature_celcius': 47.0, 'created_time': '2019-01-09T07:42:56', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. Data: {'latitude': -36.6228, 'longitude': 142.428, 'confidence': 67.0, 'surface_temperature_celcius': 43.0, 'created_time': '2019-01-09T08:19:57', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. Data: {'latitude': -36.1078, 'longitude': 141.7798, 'confidence': 77.0, 'surface_temperature_celcius': 50.0, 'created_time': '2019-01-09T15:44:05', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. Data: {'latitude': -36.309, 'longitude': 141.4964, 'confidence': 75.0, 'surface_temperature_celcius': 48.0, 'created_time': '2019-01-09T20:06:45', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. Data: {'latitude': -36.439, 'longitude': 143.6214, 'confidence': 76.0, 'surface_temperature_celcius': 50.0, 'created_time': '2019-01-10T01:47:44', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. Data: {'latitude': -36.7001, 'longitude': 141.7567, 'confidence': 55.0, 'surface_temperature_celcius': 39.0, 'created_time': '2019-01-10T05:34:10', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. Data: {'latitude': -38.1403, 'longitude': 144.2187, 'confidence': 84.0, 'surface_temperature_celcius': 58.0, 'created_time': '2019-01-10T08:28:47', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. Data: {'latitude': -37.9255, 'longitude': 143.1236, 'confidence': 68.0, 'surface_temperature_celcius': 44.0, 'created_time': '2019-01-10T12:23:15', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. Data: {'latitude': -35.2312, 'longitude': 141.0149, 'confidence': 71.0, 'surface_temperature_celcius': 45.0, 'created_time': '2019-01-10T21:07:22', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. Data: {'latitude': -36.3362, 'longitude': 141.4973, 'confidence': 78.0, 'surface_temperature_celcius': 52.0, 'created_time': '2019-01-11T01:47:45', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. Data: {'latitude': -36.3739, 'longitude': 141.108, 'confidence': 78.0, 'surface_temperature_celcius': 51.0, 'created_time': '2019-01-11T06:34:56', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. Data: {'latitude': -36.6859, 'longitude': 146.8907, 'confidence': 59.0, 'surface_temperature_celcius': 40.0, 'created_time': '2019-01-11T08:59:25', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. Data: {'latitude': -37.9112, 'longitude': 143.6025, 'confidence': 85.0, 'surface_temperature_celcius': 61.0, 'created_time': '2019-01-11T15:13:40', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. Data: {'latitude': -36.3489, 'longitude': 145.3342, 'confidence': 52.0, 'surface_temperature_celcius': 38.0, 'created_time': '2019-01-11T22:12:17', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. Data: {'latitude': -37.5135, 'longitude': 142.7238, 'confidence': 93.0, 'surface_temperature_celcius': 72.0, 'created_time': '2019-01-12T01:12:50', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. Data: {'latitude': -36.6407, 'longitude': 142.4914, 'confidence': 87.0, 'surface_temperature_celcius': 63.0, 'created_time': '2019-01-12T07:26:41', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. Data: {'latitude': -38.0494, 'longitude': 143.9141, 'confidence': 63.0, 'surface_temperature_celcius': 58.0, 'created_time': '2019-01-12T09:32:39', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. Data: {'latitude': -37.1749, 'longitude': 143.9573, 'confidence': 69.0, 'surface_temperature_celcius': 44.0, 'created_time': '2019-01-12T13:02:03', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. Data: {'latitude': -36.7564, 'longitude': 142.343, 'confidence': 56.0, 'surface_temperature_celcius': 41.0, 'created_time': '2019-01-12T22:32:56', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. Data: {'latitude': -37.073, 'longitude': 141.0811, 'confidence': 87.0, 'surface_temperature_celcius': 61.0, 'created_time': '2019-01-13T01:53:10', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. Data: {'latitude': -36.0318, 'longitude': 145.7492, 'confidence': 73.0, 'surface_temperature_celcius': 47.0, 'created_time': '2019-01-13T07:23:07', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. Data: {'latitude': -36.5541, 'longitude': 144.1321, 'confidence': 91.0, 'surface_temperature_celcius': 69.0, 'created_time': '2019-01-13T11:07:57', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. Data: {'latitude': -36.1021, 'longitude': 146.6853, 'confidence': 52.0, 'surface_temperature_celcius': 42.0, 'created_time': '2019-01-13T13:34:51', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. Data: {'latitude': -37.3301, 'longitude': 143.5514, 'confidence': 86.0, 'surface_temperature_celcius': 61.0, 'created_time': '2019-01-13T20:04:41', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. Data: {'latitude': -37.2197, 'longitude': 148.8134, 'confidence': 77.0, 'surface_temperature_celcius': 50.0, 'created_time': '2019-01-14T02:47:20', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. Data: {'latitude': -36.1598, 'longitude': 141.8841, 'confidence': 88.0, 'surface_temperature_celcius': 64.0, 'created_time': '2019-01-14T07:32:47', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. Data: {'latitude': -36.2549, 'longitude': 141.9908, 'confidence': 69.0, 'surface_temperature_celcius': 44.0, 'created_time': '2019-01-14T08:19:52', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. Data: {'latitude': -36.738, 'longitude': 142.1177, 'confidence': 95.0, 'surface_temperature_celcius': 77.0, 'created_time': '2019-01-14T13:12:04', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. Data: {'latitude': -35.8857, 'longitude': 142.1212, 'confidence': 74.0, 'surface_temperature_celcius': 48.0, 'created_time': '2019-01-14T23:24:25', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. Data: {'latitude': -37.627, 'longitude': 149.33, 'confidence': 92.0, 'surface_temperature_celcius': 42.0, 'created_time': '2019-01-15T02:15:11', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. Data: {'latitude': -36.1702, 'longitude': 142.0586, 'confidence': 86.0, 'surface_temperature_celcius': 60.0, 'created_time': '2019-01-15T07:07:13', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. Data: {'latitude': -36.6669, 'longitude': 142.8645, 'confidence': 100.0, 'surface_temperature_celcius': 110.0, 'created_time': '2019-01-15T09:24:21', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. Data: {'latitude': -35.9508, 'longitude': 142.1753, 'confidence': 81.0, 'surface_temperature_celcius': 54.0, 'created_time': '2019-01-15T15:27:42', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. Data: {'latitude': -37.5025, 'longitude': 142.9011, 'confidence': 73.0, 'surface_temperature_celcius': 47.0, 'created_time': '2019-01-15T23:51:59', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. Data: {'latitude': -37.6387, 'longitude': 142.9032, 'confidence': 87.0, 'surface_temperature_celcius': 88.0, 'created_time': '2019-01-16T02:39:20', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. Data: {'latitude': -36.669, 'longitude': 144.6148, 'confidence': 88.0, 'surface_temperature_celcius': 63.0, 'created_time': '2019-01-16T07:49:11', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. Data: {'latitude': -36.834, 'longitude': 142.524, 'confidence': 78.0, 'surface_temperature_celcius': 44.0, 'created_time': '2019-01-16T11:50:46', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. Data: {'latitude': -37.569, 'longitude': 148.024, 'confidence': 87.0, 'surface_temperature_celcius': 60.0, 'created_time': '2019-01-16T14:25:47', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. Data: {'latitude': -37.63, 'longitude': 149.335, 'confidence': 53.0, 'surface_temperature_celcius': 57.0, 'created_time': '2019-01-16T20:57:22', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. Data: {'latitude': -36.5125, 'longitude': 144.4496, 'confidence': 87.0, 'surface_temperature_celcius': 62.0, 'created_time': '2019-01-17T01:20:34', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. Data: {'latitude': -36.9246, 'longitude': 147.5559, 'confidence': 87.0, 'surface_temperature_celcius': 62.0, 'created_time': '2019-01-17T06:35:48', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. Data: {'latitude': -36.494, 'longitude': 145.4522, 'confidence': 63.0, 'surface_temperature_celcius': 41.0, 'created_time': '2019-01-17T11:05:16', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. Data: {'latitude': -38.0401, 'longitude': 143.9388, 'confidence': 87.0, 'surface_temperature_celcius': 61.0, 'created_time': '2019-01-17T15:09:04', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. Data: {'latitude': -37.671, 'longitude': 144.6536, 'confidence': 84.0, 'surface_temperature_celcius': 58.0, 'created_time': '2019-01-17T22:02:16', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. Data: {'latitude': -37.363, 'longitude': 148.06, 'confidence': 100.0, 'surface_temperature_celcius': 48.0, 'created_time': '2019-01-18T02:47:18', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. Data: {'latitude': -36.6188, 'longitude': 144.0402, 'confidence': 69.0, 'surface_temperature_celcius': 44.0, 'created_time': '2019-01-18T05:56:53', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. Data: {'latitude': -35.2464, 'longitude': 141.1143, 'confidence': 98.0, 'surface_temperature_celcius': 45.0, 'created_time': '2019-01-18T11:12:58', 'producer_id': 'producer_hotspot_terra'}
# Message published successfully. Data: {'latitude': -37.6008, 'longitude': 143.0558, 'confidence': 69.0, 'surface_temperature_celcius': 44.0, 'created_time': '2019-01-18T13:44:19', 'producer_id': 'producer_hotspot_terra'}
