# %% [markdown]
# ## FIT3182 - Assignment 2
# ---
# ### Part B - Producer 2
#
# **Information:**
# - Filename: Assignment_PartB_Producer2.ipynb
# - Student Name: Nicholas Mandylas
# - Student Number: 27840328
# - Student Email: nman48@student.monash.edu

# %%
from time import sleep
from json import dumps
from kafka import KafkaProducer
import random
import datetime as dt
import pandas

# Reading data from CSV
def readCSV():
    climate_streaming_data = pandas.read_csv('hotspot_AQUA_streaming.csv')
    streaming_data = []
    for _, row in climate_streaming_data.iterrows(): # Iterate through each row in the CSV
        data_point = {} # Create dictionary for individual row & format data appropriately.
        data_point['latitude'] = float(row['latitude'])
        data_point['longitude'] = float(row['longitude'])
        data_point['confidence'] = float(row['confidence'])
        data_point['surface_temperature_celcius'] = float(
            row['surface_temperature_celcius'])

        streaming_data.append(data_point)

    return streaming_data


def publish_message(producer_instance, topic_name, data):
    try:
        producer_instance.send(topic_name, value=data)
        producer_instance.flush()
        print('Message published successfully. Data: ' + str(data))
    except Exception as ex:
        print('Exception in publishing message.')
        print(str(ex))


def connect_kafka_producer():
    _producer = None
    try:
        _producer = KafkaProducer( # Added serializer on the producer, which will automatically serialize to JSON string format.
            bootstrap_servers=['localhost:9092'], value_serializer=lambda x: dumps(x).encode('ascii'), api_version=(0, 10))
    except Exception as ex:
        print('Exception while connecting Kafka.')
        print(str(ex))
    finally:
        return _producer


if __name__ == '__main__':

    data = readCSV() # Read all data from CSV at one time.
    topic = 'Hotspot_AQUA'
    producer = connect_kafka_producer()
    created_date = dt.datetime(2019, 1, 1) # Initial date

    count = 0

    while True:
        count += 4

        random_number = random.randrange(0, len(data)) # Pick random aqua data point.
        selected_data = data[random_number]

        if count > 16: # As data stream is expected to be sent every 2 seconds (10 seconds total for a single day), iterate up to 6, counting by 4.
            created_date += dt.timedelta(days=1) # Set to next day & reset time back to 0 hours, 0 minutes & 0 seconds.
            created_date.replace(hour=0, minute=0, second=0)
            count = 0

        # Every two seconds, I select a random hour (in the space of 4 hours), random minutes & seconds, to make a more simulated flow of data.
        # As the count increases (as it does 4), the next two seconds, will be a random time, keeping the output in sequential & random order.
        created_time = created_date + dt.timedelta(
            hours=(random.randrange(count - 4, count)),
            minutes=(random.randrange(0, 60)),
            seconds=(random.randrange(0, 60)))
        selected_data['created_time'] = created_time.isoformat()
        # print(selected_data['created_time'].strftime("%m/%d/%Y, %H:%M:%S"))
        selected_data['producer_id'] = 'producer_hotspot_aqua'

        publish_message(producer, topic, selected_data)

        sleep(2)
# Out:
# Message published successfully. Data: {'latitude': -36.5039, 'longitude': 142.8384, 'confidence': 74.0, 'surface_temperature_celcius': 48.0, 'created_time': '2019-01-01T03:26:15', 'producer_id': 'producer_hotspot_aqua'}
# Message published successfully. Data: {'latitude': -37.7105, 'longitude': 148.6047, 'confidence': 77.0, 'surface_temperature_celcius': 56.0, 'created_time': '2019-01-01T06:01:54', 'producer_id': 'producer_hotspot_aqua'}
# Message published successfully. Data: {'latitude': -37.976, 'longitude': 145.649, 'confidence': 88.0, 'surface_temperature_celcius': 64.0, 'created_time': '2019-01-01T11:15:59', 'producer_id': 'producer_hotspot_aqua'}
# Message published successfully. Data: {'latitude': -36.599, 'longitude': 144.6498, 'confidence': 76.0, 'surface_temperature_celcius': 49.0, 'created_time': '2019-01-01T12:27:54', 'producer_id': 'producer_hotspot_aqua'}
# Message published successfully. Data: {'latitude': -36.6672, 'longitude': 143.8631, 'confidence': 79.0, 'surface_temperature_celcius': 52.0, 'created_time': '2019-01-01T23:43:01', 'producer_id': 'producer_hotspot_aqua'}
# Message published successfully. Data: {'latitude': -37.7177, 'longitude': 143.2919, 'confidence': 61.0, 'surface_temperature_celcius': 41.0, 'created_time': '2019-01-02T02:47:22', 'producer_id': 'producer_hotspot_aqua'}
# Message published successfully. Data: {'latitude': -37.8064, 'longitude': 146.0189, 'confidence': 96.0, 'surface_temperature_celcius': 45.0, 'created_time': '2019-01-02T07:48:47', 'producer_id': 'producer_hotspot_aqua'}
# Message published successfully. Data: {'latitude': -36.7134, 'longitude': 145.2151, 'confidence': 52.0, 'surface_temperature_celcius': 38.0, 'created_time': '2019-01-02T11:37:08', 'producer_id': 'producer_hotspot_aqua'}
# Message published successfully. Data: {'latitude': -36.1401, 'longitude': 146.0217, 'confidence': 68.0, 'surface_temperature_celcius': 44.0, 'created_time': '2019-01-02T14:45:57', 'producer_id': 'producer_hotspot_aqua'}
# Message published successfully. Data: {'latitude': -38.0631, 'longitude': 143.6433, 'confidence': 68.0, 'surface_temperature_celcius': 46.0, 'created_time': '2019-01-02T20:15:56', 'producer_id': 'producer_hotspot_aqua'}
# Message published successfully. Data: {'latitude': -37.719, 'longitude': 142.154, 'confidence': 63.0, 'surface_temperature_celcius': 41.0, 'created_time': '2019-01-03T01:36:14', 'producer_id': 'producer_hotspot_aqua'}
# Message published successfully. Data: {'latitude': -37.0221, 'longitude': 141.5517, 'confidence': 76.0, 'surface_temperature_celcius': 50.0, 'created_time': '2019-01-03T04:54:13', 'producer_id': 'producer_hotspot_aqua'}
# Message published successfully. Data: {'latitude': -37.769, 'longitude': 147.94, 'confidence': 93.0, 'surface_temperature_celcius': 72.0, 'created_time': '2019-01-03T09:28:15', 'producer_id': 'producer_hotspot_aqua'}
# Message published successfully. Data: {'latitude': -37.903, 'longitude': 141.0975, 'confidence': 84.0, 'surface_temperature_celcius': 59.0, 'created_time': '2019-01-03T12:24:52', 'producer_id': 'producer_hotspot_aqua'}
# Message published successfully. Data: {'latitude': -35.961, 'longitude': 141.089, 'confidence': 83.0, 'surface_temperature_celcius': 56.0, 'created_time': '2019-01-03T20:17:40', 'producer_id': 'producer_hotspot_aqua'}
# Message published successfully. Data: {'latitude': -37.4439, 'longitude': 142.9811, 'confidence': 71.0, 'surface_temperature_celcius': 46.0, 'created_time': '2019-01-04T03:38:29', 'producer_id': 'producer_hotspot_aqua'}
# Message published successfully. Data: {'latitude': -36.3799, 'longitude': 143.7149, 'confidence': 100.0, 'surface_temperature_celcius': 89.0, 'created_time': '2019-01-04T07:59:35', 'producer_id': 'producer_hotspot_aqua'}
# Message published successfully. Data: {'latitude': -37.8088, 'longitude': 142.2291, 'confidence': 80.0, 'surface_temperature_celcius': 54.0, 'created_time': '2019-01-04T09:27:26', 'producer_id': 'producer_hotspot_aqua'}
# Message published successfully. Data: {'latitude': -36.6914, 'longitude': 140.9792, 'confidence': 81.0, 'surface_temperature_celcius': 55.0, 'created_time': '2019-01-04T12:15:07', 'producer_id': 'producer_hotspot_aqua'}
# Message published successfully. Data: {'latitude': -38.0326, 'longitude': 141.5413, 'confidence': 83.0, 'surface_temperature_celcius': 56.0, 'created_time': '2019-01-04T23:05:47', 'producer_id': 'producer_hotspot_aqua'}
# Message published successfully. Data: {'latitude': -36.2282, 'longitude': 145.9074, 'confidence': 67.0, 'surface_temperature_celcius': 43.0, 'created_time': '2019-01-05T03:10:12', 'producer_id': 'producer_hotspot_aqua'}
# Message published successfully. Data: {'latitude': -37.7851, 'longitude': 143.3753, 'confidence': 83.0, 'surface_temperature_celcius': 64.0, 'created_time': '2019-01-05T07:50:38', 'producer_id': 'producer_hotspot_aqua'}
# Message published successfully. Data: {'latitude': -36.2476, 'longitude': 147.5281, 'confidence': 55.0, 'surface_temperature_celcius': 39.0, 'created_time': '2019-01-05T09:04:35', 'producer_id': 'producer_hotspot_aqua'}
# Message published successfully. Data: {'latitude': -37.4754, 'longitude': 148.161, 'confidence': 67.0, 'surface_temperature_celcius': 43.0, 'created_time': '2019-01-05T14:52:27', 'producer_id': 'producer_hotspot_aqua'}
# Message published successfully. Data: {'latitude': -37.3723, 'longitude': 143.8406, 'confidence': 52.0, 'surface_temperature_celcius': 42.0, 'created_time': '2019-01-05T20:53:12', 'producer_id': 'producer_hotspot_aqua'}
# Message published successfully. Data: {'latitude': -36.6803, 'longitude': 141.0957, 'confidence': 60.0, 'surface_temperature_celcius': 44.0, 'created_time': '2019-01-06T00:23:07', 'producer_id': 'producer_hotspot_aqua'}
# Message published successfully. Data: {'latitude': -36.9446, 'longitude': 142.8698, 'confidence': 75.0, 'surface_temperature_celcius': 48.0, 'created_time': '2019-01-06T05:54:44', 'producer_id': 'producer_hotspot_aqua'}
# Message published successfully. Data: {'latitude': -36.9986, 'longitude': 143.8953, 'confidence': 68.0, 'surface_temperature_celcius': 44.0, 'created_time': '2019-01-06T09:58:06', 'producer_id': 'producer_hotspot_aqua'}
# Message published successfully. Data: {'latitude': -36.6529, 'longitude': 143.9035, 'confidence': 100.0, 'surface_temperature_celcius': 112.0, 'created_time': '2019-01-06T13:58:17', 'producer_id': 'producer_hotspot_aqua'}
# Message published successfully. Data: {'latitude': -37.7935, 'longitude': 143.1606, 'confidence': 96.0, 'surface_temperature_celcius': 78.0, 'created_time': '2019-01-06T23:06:16', 'producer_id': 'producer_hotspot_aqua'}
# Message published successfully. Data: {'latitude': -36.3493, 'longitude': 141.5238, 'confidence': 70.0, 'surface_temperature_celcius': 45.0, 'created_time': '2019-01-07T00:33:37', 'producer_id': 'producer_hotspot_aqua'}
# Message published successfully. Data: {'latitude': -37.7129, 'longitude': 143.0307, 'confidence': 57.0, 'surface_temperature_celcius': 39.0, 'created_time': '2019-01-07T06:57:27', 'producer_id': 'producer_hotspot_aqua'}
# Message published successfully. Data: {'latitude': -37.4471, 'longitude': 147.6331, 'confidence': 89.0, 'surface_temperature_celcius': 65.0, 'created_time': '2019-01-07T11:12:10', 'producer_id': 'producer_hotspot_aqua'}
# Message published successfully. Data: {'latitude': -34.3539, 'longitude': 141.5547, 'confidence': 93.0, 'surface_temperature_celcius': 72.0, 'created_time': '2019-01-07T15:04:46', 'producer_id': 'producer_hotspot_aqua'}
# Message published successfully. Data: {'latitude': -35.0706, 'longitude': 141.4435, 'confidence': 95.0, 'surface_temperature_celcius': 75.0, 'created_time': '2019-01-07T22:48:02', 'producer_id': 'producer_hotspot_aqua'}
# Message published successfully. Data: {'latitude': -37.3735, 'longitude': 145.886, 'confidence': 87.0, 'surface_temperature_celcius': 96.0, 'created_time': '2019-01-08T03:32:37', 'producer_id': 'producer_hotspot_aqua'}
# Message published successfully. Data: {'latitude': -36.834, 'longitude': 141.9115, 'confidence': 71.0, 'surface_temperature_celcius': 46.0, 'created_time': '2019-01-08T06:53:07', 'producer_id': 'producer_hotspot_aqua'}
# Message published successfully. Data: {'latitude': -37.8672, 'longitude': 143.8194, 'confidence': 74.0, 'surface_temperature_celcius': 48.0, 'created_time': '2019-01-08T11:06:38', 'producer_id': 'producer_hotspot_aqua'}
# Message published successfully. Data: {'latitude': -36.0106, 'longitude': 144.9927, 'confidence': 73.0, 'surface_temperature_celcius': 47.0, 'created_time': '2019-01-08T15:50:21', 'producer_id': 'producer_hotspot_aqua'}
# Message published successfully. Data: {'latitude': -35.8055, 'longitude': 142.7428, 'confidence': 73.0, 'surface_temperature_celcius': 47.0, 'created_time': '2019-01-08T21:06:52', 'producer_id': 'producer_hotspot_aqua'}
# Message published successfully. Data: {'latitude': -36.9171, 'longitude': 143.4749, 'confidence': 62.0, 'surface_temperature_celcius': 41.0, 'created_time': '2019-01-09T01:46:15', 'producer_id': 'producer_hotspot_aqua'}
# Message published successfully. Data: {'latitude': -36.8416, 'longitude': 143.4597, 'confidence': 79.0, 'surface_temperature_celcius': 52.0, 'created_time': '2019-01-09T07:43:46', 'producer_id': 'producer_hotspot_aqua'}
# Message published successfully. Data: {'latitude': -37.886, 'longitude': 147.207, 'confidence': 50.0, 'surface_temperature_celcius': 28.0, 'created_time': '2019-01-09T08:00:50', 'producer_id': 'producer_hotspot_aqua'}
# Message published successfully. Data: {'latitude': -38.116, 'longitude': 143.818, 'confidence': 76.0, 'surface_temperature_celcius': 43.0, 'created_time': '2019-01-09T12:05:04', 'producer_id': 'producer_hotspot_aqua'}
# Message published successfully. Data: {'latitude': -38.0881, 'longitude': 143.9391, 'confidence': 99.0, 'surface_temperature_celcius': 84.0, 'created_time': '2019-01-09T20:54:44', 'producer_id': 'producer_hotspot_aqua'}
# Message published successfully. Data: {'latitude': -36.2205, 'longitude': 141.7933, 'confidence': 81.0, 'surface_temperature_celcius': 54.0, 'created_time': '2019-01-10T01:50:43', 'producer_id': 'producer_hotspot_aqua'}
# Message published successfully. Data: {'latitude': -36.4179, 'longitude': 144.2924, 'confidence': 94.0, 'surface_temperature_celcius': 75.0, 'created_time': '2019-01-10T07:40:56', 'producer_id': 'producer_hotspot_aqua'}
# Message published successfully. Data: {'latitude': -35.4625, 'longitude': 143.1486, 'confidence': 67.0, 'surface_temperature_celcius': 44.0, 'created_time': '2019-01-10T11:35:05', 'producer_id': 'producer_hotspot_aqua'}
# Message published successfully. Data: {'latitude': -36.0375, 'longitude': 143.8172, 'confidence': 87.0, 'surface_temperature_celcius': 63.0, 'created_time': '2019-01-10T12:07:25', 'producer_id': 'producer_hotspot_aqua'}
# Message published successfully. Data: {'latitude': -37.7506, 'longitude': 142.7265, 'confidence': 63.0, 'surface_temperature_celcius': 41.0, 'created_time': '2019-01-10T20:15:48', 'producer_id': 'producer_hotspot_aqua'}
# Message published successfully. Data: {'latitude': -37.3949, 'longitude': 147.0175, 'confidence': 100.0, 'surface_temperature_celcius': 91.0, 'created_time': '2019-01-11T03:04:33', 'producer_id': 'producer_hotspot_aqua'}
# Message published successfully. Data: {'latitude': -37.3656, 'longitude': 143.8206, 'confidence': 59.0, 'surface_temperature_celcius': 40.0, 'created_time': '2019-01-11T04:35:45', 'producer_id': 'producer_hotspot_aqua'}
# Message published successfully. Data: {'latitude': -36.2784, 'longitude': 143.2794, 'confidence': 74.0, 'surface_temperature_celcius': 48.0, 'created_time': '2019-01-11T08:08:01', 'producer_id': 'producer_hotspot_aqua'}
# Message published successfully. Data: {'latitude': -38.1868, 'longitude': 143.0938, 'confidence': 70.0, 'surface_temperature_celcius': 45.0, 'created_time': '2019-01-11T14:12:56', 'producer_id': 'producer_hotspot_aqua'}
# Message published successfully. Data: {'latitude': -36.6867, 'longitude': 141.137, 'confidence': 84.0, 'surface_temperature_celcius': 59.0, 'created_time': '2019-01-11T22:48:02', 'producer_id': 'producer_hotspot_aqua'}
# Message published successfully. Data: {'latitude': -36.6026, 'longitude': 144.48, 'confidence': 64.0, 'surface_temperature_celcius': 42.0, 'created_time': '2019-01-12T03:24:48', 'producer_id': 'producer_hotspot_aqua'}
# Message published successfully. Data: {'latitude': -36.4631, 'longitude': 144.7654, 'confidence': 86.0, 'surface_temperature_celcius': 61.0, 'created_time': '2019-01-12T04:30:44', 'producer_id': 'producer_hotspot_aqua'}
# Message published successfully. Data: {'latitude': -36.701, 'longitude': 141.6351, 'confidence': 80.0, 'surface_temperature_celcius': 53.0, 'created_time': '2019-01-12T10:24:59', 'producer_id': 'producer_hotspot_aqua'}
# Message published successfully. Data: {'latitude': -36.438, 'longitude': 145.5865, 'confidence': 81.0, 'surface_temperature_celcius': 54.0, 'created_time': '2019-01-12T15:46:04', 'producer_id': 'producer_hotspot_aqua'}
# Message published successfully. Data: {'latitude': -36.7606, 'longitude': 147.1326, 'confidence': 75.0, 'surface_temperature_celcius': 41.0, 'created_time': '2019-01-12T21:13:25', 'producer_id': 'producer_hotspot_aqua'}
# Message published successfully. Data: {'latitude': -36.4417, 'longitude': 145.5688, 'confidence': 77.0, 'surface_temperature_celcius': 51.0, 'created_time': '2019-01-13T00:48:34', 'producer_id': 'producer_hotspot_aqua'}
# Message published successfully. Data: {'latitude': -35.7786, 'longitude': 143.469, 'confidence': 84.0, 'surface_temperature_celcius': 58.0, 'created_time': '2019-01-13T04:03:39', 'producer_id': 'producer_hotspot_aqua'}
# Message published successfully. Data: {'latitude': -37.6592, 'longitude': 142.058, 'confidence': 81.0, 'surface_temperature_celcius': 55.0, 'created_time': '2019-01-13T08:06:57', 'producer_id': 'producer_hotspot_aqua'}
# Message published successfully. Data: {'latitude': -37.5576, 'longitude': 143.5687, 'confidence': 82.0, 'surface_temperature_celcius': 56.0, 'created_time': '2019-01-13T12:46:33', 'producer_id': 'producer_hotspot_aqua'}
# Message published successfully. Data: {'latitude': -36.0829, 'longitude': 146.0621, 'confidence': 88.0, 'surface_temperature_celcius': 63.0, 'created_time': '2019-01-13T23:34:05', 'producer_id': 'producer_hotspot_aqua'}
# Message published successfully. Data: {'latitude': -35.9423, 'longitude': 145.0943, 'confidence': 79.0, 'surface_temperature_celcius': 52.0, 'created_time': '2019-01-14T02:31:11', 'producer_id': 'producer_hotspot_aqua'}
# Message published successfully. Data: {'latitude': -37.4381, 'longitude': 143.1201, 'confidence': 78.0, 'surface_temperature_celcius': 51.0, 'created_time': '2019-01-14T05:01:13', 'producer_id': 'producer_hotspot_aqua'}
# Message published successfully. Data: {'latitude': -36.2523, 'longitude': 143.6509, 'confidence': 74.0, 'surface_temperature_celcius': 48.0, 'created_time': '2019-01-14T08:20:49', 'producer_id': 'producer_hotspot_aqua'}
# Message published successfully. Data: {'latitude': -36.3488, 'longitude': 141.148, 'confidence': 81.0, 'surface_temperature_celcius': 54.0, 'created_time': '2019-01-14T12:25:42', 'producer_id': 'producer_hotspot_aqua'}
# Message published successfully. Data: {'latitude': -37.1248, 'longitude': 141.8795, 'confidence': 71.0, 'surface_temperature_celcius': 52.0, 'created_time': '2019-01-14T22:14:16', 'producer_id': 'producer_hotspot_aqua'}
# Message published successfully. Data: {'latitude': -36.3728, 'longitude': 141.3641, 'confidence': 71.0, 'surface_temperature_celcius': 46.0, 'created_time': '2019-01-15T00:54:10', 'producer_id': 'producer_hotspot_aqua'}
# Message published successfully. Data: {'latitude': -36.2648, 'longitude': 141.1012, 'confidence': 100.0, 'surface_temperature_celcius': 111.0, 'created_time': '2019-01-15T06:36:25', 'producer_id': 'producer_hotspot_aqua'}
# Message published successfully. Data: {'latitude': -38.0089, 'longitude': 143.8976, 'confidence': 64.0, 'surface_temperature_celcius': 45.0, 'created_time': '2019-01-15T10:54:59', 'producer_id': 'producer_hotspot_aqua'}
# Message published successfully. Data: {'latitude': -36.1031, 'longitude': 143.0782, 'confidence': 63.0, 'surface_temperature_celcius': 45.0, 'created_time': '2019-01-15T12:18:33', 'producer_id': 'producer_hotspot_aqua'}
# Message published successfully. Data: {'latitude': -37.982, 'longitude': 143.6422, 'confidence': 56.0, 'surface_temperature_celcius': 42.0, 'created_time': '2019-01-15T20:35:49', 'producer_id': 'producer_hotspot_aqua'}
# Message published successfully. Data: {'latitude': -38.3871, 'longitude': 146.3082, 'confidence': 78.0, 'surface_temperature_celcius': 51.0, 'created_time': '2019-01-16T01:45:50', 'producer_id': 'producer_hotspot_aqua'}
# Message published successfully. Data: {'latitude': -37.175, 'longitude': 148.9347, 'confidence': 51.0, 'surface_temperature_celcius': 40.0, 'created_time': '2019-01-16T04:02:06', 'producer_id': 'producer_hotspot_aqua'}
# Message published successfully. Data: {'latitude': -37.2185, 'longitude': 147.4402, 'confidence': 100.0, 'surface_temperature_celcius': 106.0, 'created_time': '2019-01-16T11:45:12', 'producer_id': 'producer_hotspot_aqua'}
# Message published successfully. Data: {'latitude': -36.0765, 'longitude': 146.4896, 'confidence': 69.0, 'surface_temperature_celcius': 46.0, 'created_time': '2019-01-16T12:39:59', 'producer_id': 'producer_hotspot_aqua'}
# Message published successfully. Data: {'latitude': -38.2583, 'longitude': 143.9717, 'confidence': 62.0, 'surface_temperature_celcius': 41.0, 'created_time': '2019-01-16T21:06:12', 'producer_id': 'producer_hotspot_aqua'}
# Message published successfully. Data: {'latitude': -38.0525, 'longitude': 143.64, 'confidence': 65.0, 'surface_temperature_celcius': 43.0, 'created_time': '2019-01-17T03:43:55', 'producer_id': 'producer_hotspot_aqua'}
# Message published successfully. Data: {'latitude': -36.3638, 'longitude': 143.9086, 'confidence': 71.0, 'surface_temperature_celcius': 46.0, 'created_time': '2019-01-17T06:03:57', 'producer_id': 'producer_hotspot_aqua'}
# Message published successfully. Data: {'latitude': -36.8081, 'longitude': 142.8665, 'confidence': 70.0, 'surface_temperature_celcius': 45.0, 'created_time': '2019-01-17T08:09:15', 'producer_id': 'producer_hotspot_aqua'}
# Message published successfully. Data: {'latitude': -36.0097, 'longitude': 141.7625, 'confidence': 85.0, 'surface_temperature_celcius': 60.0, 'created_time': '2019-01-17T15:00:43', 'producer_id': 'producer_hotspot_aqua'}
# Message published successfully. Data: {'latitude': -37.8641, 'longitude': 143.4276, 'confidence': 100.0, 'surface_temperature_celcius': 51.0, 'created_time': '2019-01-17T22:18:30', 'producer_id': 'producer_hotspot_aqua'}
# Message published successfully. Data: {'latitude': -36.1586, 'longitude': 145.6666, 'confidence': 99.0, 'surface_temperature_celcius': 85.0, 'created_time': '2019-01-18T02:27:23', 'producer_id': 'producer_hotspot_aqua'}
# Message published successfully. Data: {'latitude': -38.127, 'longitude': 143.82, 'confidence': 96.0, 'surface_temperature_celcius': 77.0, 'created_time': '2019-01-18T04:30:30', 'producer_id': 'producer_hotspot_aqua'}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-07b45f857aee> in <module>
#      77         publish_message(producer, topic, selected_data)
#      78
# ---> 79         sleep(2)
#
# KeyboardInterrupt:
